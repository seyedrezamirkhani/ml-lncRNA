# %% [markdown]
# latitude
#
# longitude
#
# author_name
#
# affiliation / organization
#
# paper_title

# %%
import pandas as pd
import pickle
import time
from scholarly import scholarly
import folium

# %%
DATA_FOLDER = '../../data/'

# %% [markdown]
# # Plot Organizations

# %%
author_organizations_df = pd.read_parquet(f'{DATA_FOLDER}author_organizations.parquet')

# %%
author_organizations_df
# Out:
#         author_id                           organization
# 0    zkBXb_kAAAAJ                 Biomedical Informatics
# 1    zkBXb_kAAAAJ                    Shandong University
# 2    EHvA-IUAAAAJ                     Tianjin University
# 3    EHvA-IUAAAAJ                    Tsinghua University
# 4    EHvA-IUAAAAJ           City University of Hong Kong
# ..            ...                                    ...
# 111  1wloHDIAAAAJ           City University of Hong Kong
# 112  Tc_U_9YAAAAJ                             Amazon.com
# 113  jV50Ks8AAAAJ  Biostatistics, University of Michigan
# 114  QVJvfz8AAAAJ        Computer Science and Engineeing
# 115  BP702PgAAAAJ                      Monash University
#
# [116 rows x 2 columns]

# %%
organizations_df = pd.read_pickle(f'{DATA_FOLDER}organizations_with_location.pickle')

# %%
organizations_df
# Out:
#                               organization  \
# 0                   Biomedical Informatics
# 1                      Shandong University
# 2                       Tianjin University
# 3                      Tsinghua University
# 4             City University of Hong Kong
# ..                                     ...
# 105                         Data Scientist
# 106                             Amazon.com
# 107  Biostatistics, University of Michigan
# 108        Computer Science and Engineeing
# 109                      Monash University
#
#                                               location
# 0    (Health & Biomedical Informatics Centre, 202-2...
# 1    (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...
# 2    (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...
# 3    (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...
# 4    (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# ..                                                 ...
# 105                                               None
# 106  (Amazon.com Doppler, 2021, 7th Avenue, Central...
# 107                                               None
# 108                                               None
# 109  (Monash University, Mile Lane, International H...
#
# [110 rows x 2 columns]

# %% [markdown]
# ### Inspect organizations where the location is missing

# %%
sum(organizations_df['location'].isna())
# Out:
# 31

# %%
organizations_df[organizations_df['location'].isna()]
# Out:
#                                           organization location
# 11                                    GrainGenes / Adj     None
# 15                 College of  Mechanics and Materials     None
# 17                       Bioinformatics Research Group     None
# 19    zhujiang hospital of southern medical university     None
# 22                               Department of Thyroid     None
# 28   Obstetrics and Gynecology Hospital of Fudan Un...     None
# 30       University of Science and Technology Liaoning     None
# 31   Shanghai University of Medicine and Health Sci...     None
# 33                    Biochemistry, Clemson University     None
# 36                            Central South University     None
# 39   Department of Computer Science, Old Dominion U...     None
# 47      Computer Engineering & Artificial Intelligence     None
# 52   City University of Hong Kong - BWH/Harvard Med...     None
# 68   School of Computing Technologies, RMIT University     None
# 70                             Lecturer, IT Department     None
# 72                 Bioinformatics, Zhejiang University     None
# 74                           UMass Chan Medical School     None
# 75   Medicine, University of Massachusetts Medical ...     None
# 77    Department of Genomics and Computational Biology     None
# 80                        Cardiovascular Research Unit     None
# 81                      Luxembourg Institute of Health     None
# 82   Royan Institute/Shahid Beheshti University of ...     None
# 83   Immunology Department School of Medicine Tehra...     None
# 85                             PhD Biological Sciences     None
# 88                International University of Sarajevo     None
# 89    College of Bioinformatics Science and Technology     None
# 98      Bioinformatics/Computational Physics/Chemistry     None
# 100                                     MSA University     None
# 105                                     Data Scientist     None
# 107              Biostatistics, University of Michigan     None
# 108                    Computer Science and Engineeing     None

# %% [markdown]
# The records without a location can be summarised into three groups:

# %% [markdown]
# 1. Records that are not organizations e.g. Data Scientist

# %% [markdown]
# 2. Records which are departments e.g. Computer Science and Engineeing

# %% [markdown]
# 3. Record that contains both the department and organization e.g. Biostatistics, University of Michigan

# %% [markdown]
# At this stage the records with missing locations will be dropped, adding data cleaning further up the processing pipeline will address this in the future

# %%
organizations_df.dropna(subset=['location'], inplace=True)

# %% [markdown]
# Plot organizations

# %%
def plot_organizations(organizations, locations):
    # Create a map
    affiliation_map = folium.Map(location=[0, 0], zoom_start=2)
    
    for org, loc in zip(organizations, locations):
        folium.Marker(
            [loc.latitude, loc.longitude],
            popup=f'{org}'
        ).add_to(affiliation_map)
    
    return affiliation_map

map_object = plot_organizations(organizations_df.organization.values, organizations_df.location.values)
map_object.save('organizations_map.html')  # Save to an HTML file

# %%
organizations_df['location'][0]
# Out:
# Location(Health & Biomedical Informatics Centre, 202-206, Berkeley Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia, (-37.8006938, 144.9588263, 0.0))

# %%
organizations_df['organization'][0]
# Out:
# 'Biomedical Informatics'

# %%
dir(organizations_df['location'][0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_address',
#  '_point',
#  '_raw',
#  '_tuple',
#  'address',
#  'altitude',
#  'latitude',
#  'longitude',
#  'point',
#  'raw']

# %%
organizations_df['location'][0].address
# Out:
# 'Health & Biomedical Informatics Centre, 202-206, Berkeley Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia'

# %% [markdown]
# ### Lets add the authors to organizations

# %%
author_organizations_df = pd.read_parquet(f'{DATA_FOLDER}author_organizations.parquet')

# %%
author_organizations_df
# Out:
#         author_id                           organization
# 0    zkBXb_kAAAAJ                 Biomedical Informatics
# 1    zkBXb_kAAAAJ                    Shandong University
# 2    EHvA-IUAAAAJ                     Tianjin University
# 3    EHvA-IUAAAAJ                    Tsinghua University
# 4    EHvA-IUAAAAJ           City University of Hong Kong
# ..            ...                                    ...
# 111  1wloHDIAAAAJ           City University of Hong Kong
# 112  Tc_U_9YAAAAJ                             Amazon.com
# 113  jV50Ks8AAAAJ  Biostatistics, University of Michigan
# 114  QVJvfz8AAAAJ        Computer Science and Engineeing
# 115  BP702PgAAAAJ                      Monash University
#
# [116 rows x 2 columns]

# %%
# inner join
df = pd.merge(organizations_df, author_organizations_df, on='organization', how='inner')

# %%
df
# Out:
#                     organization  \
# 0         Biomedical Informatics
# 1            Shandong University
# 2             Tianjin University
# 3            Tsinghua University
# 4   City University of Hong Kong
# ..                           ...
# 79        Sun Yat-sen University
# 80              jilin university
# 81                        Amazon
# 82                    Amazon.com
# 83             Monash University
#
#                                              location     author_id
# 0   (Health & Biomedical Informatics Centre, 202-2...  zkBXb_kAAAAJ
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...  zkBXb_kAAAAJ
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...  EHvA-IUAAAAJ
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...  EHvA-IUAAAAJ
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...  EHvA-IUAAAAJ
# ..                                                ...           ...
# 79  (中山大学广州校区南校园, 135, 新港西路, 旧凤凰, 新港街道, 海珠区, 广州市, ...  pu5CdXoAAAAJ
# 80  (吉林大学（朝阳校区）, 西朝阳南胡同, 清和街道, 朝阳区, 长春市, 绿园区, 吉林省,...  MeSogXgAAAAJ
# 81  (Amazon, Careiro da Várzea, Região Geográfica ...  7PVmb8MAAAAJ
# 82  (Amazon.com Doppler, 2021, 7th Avenue, Central...  Tc_U_9YAAAAJ
# 83  (Monash University, Mile Lane, International H...  BP702PgAAAAJ
#
# [84 rows x 3 columns]

# %%
with open(f'{DATA_FOLDER}authors.pickle', 'rb') as handle:
    authors = pickle.load(handle)

# %%
authors_df = pd.DataFrame(authors)

# %%
authors_df
# Out:
#         author_id                                  name  \
# 0    zkBXb_kAAAAJ                          Zhi-Ping Liu
# 1    EHvA-IUAAAAJ                             Pufeng Du
# 2    5RoxYhkAAAAJ                           Jianjun Tan
# 3    ap3FfWEAAAAJ                    Caitlin Simopoulos
# 4    uxiJL_cAAAAJ                          Hibah Shaath
# ..            ...                                   ...
# 104  jV50Ks8AAAAJ                           Zongrui Dai
# 105  clJGV9UAAAAJ                  Marwa  Matboli Sayed
# 106  AEaAOCQAAAAJ                      Faroza Shamsheem
# 107  QVJvfz8AAAAJ  TUNGA ARUNDHATHI Assistant Professor
# 108  BP702PgAAAAJ                Yashpal Ramakrishnaiah
#
#                                            affiliation
# 0    Professor of Biomedical Informatics, Shandong ...
# 1    Tianjin University; Tsinghua University; City ...
# 2                                               北京工业大学
# 3                                                Roche
# 4                         Hamad Bin Khalifa University
# ..                                                 ...
# 104  Master Student in Biostatistics, University of...
# 105  Professor of medical biochemistry and molecula...
# 106                                Assistant professor
# 107  Assistant Professor in Computer Science and En...
# 108                Research Student, Monash University
#
# [109 rows x 3 columns]

# %%
df = pd.merge(df, authors_df, on='author_id', how='inner')

# %%
df
# Out:
#                     organization  \
# 0         Biomedical Informatics
# 1            Shandong University
# 2             Tianjin University
# 3            Tsinghua University
# 4   City University of Hong Kong
# ..                           ...
# 79        Sun Yat-sen University
# 80              jilin university
# 81                        Amazon
# 82                    Amazon.com
# 83             Monash University
#
#                                              location     author_id  \
# 0   (Health & Biomedical Informatics Centre, 202-2...  zkBXb_kAAAAJ
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...  zkBXb_kAAAAJ
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...  EHvA-IUAAAAJ
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...  EHvA-IUAAAAJ
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...  EHvA-IUAAAAJ
# ..                                                ...           ...
# 79  (中山大学广州校区南校园, 135, 新港西路, 旧凤凰, 新港街道, 海珠区, 广州市, ...  pu5CdXoAAAAJ
# 80  (吉林大学（朝阳校区）, 西朝阳南胡同, 清和街道, 朝阳区, 长春市, 绿园区, 吉林省,...  MeSogXgAAAAJ
# 81  (Amazon, Careiro da Várzea, Região Geográfica ...  7PVmb8MAAAAJ
# 82  (Amazon.com Doppler, 2021, 7th Avenue, Central...  Tc_U_9YAAAAJ
# 83  (Monash University, Mile Lane, International H...  BP702PgAAAAJ
#
#                       name                                        affiliation
# 0             Zhi-Ping Liu  Professor of Biomedical Informatics, Shandong ...
# 1             Zhi-Ping Liu  Professor of Biomedical Informatics, Shandong ...
# 2                Pufeng Du  Tianjin University; Tsinghua University; City ...
# 3                Pufeng Du  Tianjin University; Tsinghua University; City ...
# 4                Pufeng Du  Tianjin University; Tsinghua University; City ...
# ..                     ...                                                ...
# 79              Yunfang Yu  Sun Yat-sen Memorial Hospital, Sun Yat-sen Uni...
# 80          Nan Sheng (盛楠)                                   jilin university
# 81   Rujira Achawanantakun                         Research Scientist, Amazon
# 82              Yuan Zhang              Applied Science Manager at Amazon.com
# 83  Yashpal Ramakrishnaiah                Research Student, Monash University
#
# [84 rows x 5 columns]

# %%
df.rename(columns={'name': 'author_name'}, inplace=True)

# %%
df
# Out:
#                     organization  \
# 0         Biomedical Informatics
# 1            Shandong University
# 2             Tianjin University
# 3            Tsinghua University
# 4   City University of Hong Kong
# ..                           ...
# 79        Sun Yat-sen University
# 80              jilin university
# 81                        Amazon
# 82                    Amazon.com
# 83             Monash University
#
#                                              location     author_id  \
# 0   (Health & Biomedical Informatics Centre, 202-2...  zkBXb_kAAAAJ
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...  zkBXb_kAAAAJ
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...  EHvA-IUAAAAJ
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...  EHvA-IUAAAAJ
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...  EHvA-IUAAAAJ
# ..                                                ...           ...
# 79  (中山大学广州校区南校园, 135, 新港西路, 旧凤凰, 新港街道, 海珠区, 广州市, ...  pu5CdXoAAAAJ
# 80  (吉林大学（朝阳校区）, 西朝阳南胡同, 清和街道, 朝阳区, 长春市, 绿园区, 吉林省,...  MeSogXgAAAAJ
# 81  (Amazon, Careiro da Várzea, Região Geográfica ...  7PVmb8MAAAAJ
# 82  (Amazon.com Doppler, 2021, 7th Avenue, Central...  Tc_U_9YAAAAJ
# 83  (Monash University, Mile Lane, International H...  BP702PgAAAAJ
#
#                author_name                                        affiliation
# 0             Zhi-Ping Liu  Professor of Biomedical Informatics, Shandong ...
# 1             Zhi-Ping Liu  Professor of Biomedical Informatics, Shandong ...
# 2                Pufeng Du  Tianjin University; Tsinghua University; City ...
# 3                Pufeng Du  Tianjin University; Tsinghua University; City ...
# 4                Pufeng Du  Tianjin University; Tsinghua University; City ...
# ..                     ...                                                ...
# 79              Yunfang Yu  Sun Yat-sen Memorial Hospital, Sun Yat-sen Uni...
# 80          Nan Sheng (盛楠)                                   jilin university
# 81   Rujira Achawanantakun                         Research Scientist, Amazon
# 82              Yuan Zhang              Applied Science Manager at Amazon.com
# 83  Yashpal Ramakrishnaiah                Research Student, Monash University
#
# [84 rows x 5 columns]

# %% [markdown]
# ### Add paper_titles

# %%
import geopandas as gpd
import folium
from geopy.geocoders import Nominatim

#def geocode_affiliations(papers):
#    geolocator = Nominatim(user_agent="lncRNA-map")
#    locations = []

#    for paper in papers:
#        for author in paper["authors"]:
#            affiliation = author.get("affiliation")
#            if affiliation and affiliation != "Unknown":
#                location = geolocator.geocode(affiliation)
#                if location:
#                    locations.append({
#                        "paper_title": paper["title"],
#                        "author_name": author["name"],
#                        "affiliation": affiliation,
#                        "latitude": location.latitude,
#                        "longitude": location.longitude
#                    })
#    return locations



def plot_affiliations(locations):
    # Create a map
    affiliation_map = folium.Map(location=[0, 0], zoom_start=2)
    
    for loc in locations:
        folium.Marker(
            [loc["latitude"], loc["longitude"]],
            popup=f"{loc['author_name']} ({loc['affiliation']})<br>{loc['paper_title']}"
        ).add_to(affiliation_map)
    
    return affiliation_map

# Example usage
locations = geocode_affiliations(papers)
map_object = plot_affiliations(locations)
map_object.save("affiliations_map.html")  # Save to an HTML file

# %%
def search_papers(query, limit=5):
    search_query = scholarly.search_pubs(query)
    papers = []

    for _ in range(limit):
        try:
            paper = next(search_query)
                        
            papers.append({
                "title": paper.get("bib", {}).get("title"),
                "abstract": paper.get("bib", {}).get("abstract"),
                "year": paper.get("bib", {}).get("pub_year"),
                "url": paper.get("eprint_url", "Unknown"),
                "author_id": paper.get("author_id", [])
            })
        except StopIteration:
            break
        except Exception as e:
            print(f"Error processing paper : {e}")
            continue

    return papers

# %%
def search_authors(papers):
    author_ids = list()
    authors = list()
    for paper in papers:
        print
        if len(author_ids) > 10:
            break
        if "author_id" in paper:
            for author_id in paper["author_id"]:
                if author_id: # check the author_id is not empty
                    #time.sleep(2)  # Introduce delay
                    if author_id not in author_ids: # avoids duplicate searches                        
                        try:
                            print(f'Searching for author with id {author_id}...')
                            author = scholarly.search_author_id(author_id)
                            #author = scholarly.fill(scholarly.search_author_id(author_id), sections=['basics'])
                            authors.append({
                                "author_id": author_id,
                                "name": author.get("name"),
                                "affiliation": author.get("affiliation", "Unknown")
                            })
                            author_ids.append(author_id)
                        except Exception as e:
                            print(f"Error processing author with id {author_id}: {e}")
    return authors

# %%
papers[0]['title']
# Out:
# 'Predicting lncRNA-protein interactions by machine learning methods: a review'

# %% [markdown]
# # Search for papers and save the results to disk

# %%
query = "Machine Learning lncRNA"

# %%
papers = search_papers(query, limit=100)

# %%
with open(f'{DATA_FOLDER}papers.pickle', 'wb') as handle:
    pickle.dump(papers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Search for authors associated with papers and save the results to disk

# %%
# %%timeit
authors = search_authors(papers)
# Out:
# Searching for author with id zkBXb_kAAAAJ...
# Searching for author with id EHvA-IUAAAAJ...
# Searching for author with id 5RoxYhkAAAAJ...
# Searching for author with id ap3FfWEAAAAJ...
# Searching for author with id uxiJL_cAAAAJ...
# Searching for author with id QV_7inYAAAAJ...
# Searching for author with id JNrJo8cAAAAJ...
# Searching for author with id o70NT8IAAAAJ...
# Searching for author with id ZeGca3cAAAAJ...
# Searching for author with id o3DdNZMAAAAJ...
# Searching for author with id Ydo9ResAAAAJ...
# Searching for author with id 4IRe3WYAAAAJ...
# Searching for author with id zkBXb_kAAAAJ...
# Searching for author with id EHvA-IUAAAAJ...
# Searching for author with id 5RoxYhkAAAAJ...
# Searching for author with id ap3FfWEAAAAJ...
# Searching for author with id uxiJL_cAAAAJ...
# Searching for author with id QV_7inYAAAAJ...
# Searching for author with id JNrJo8cAAAAJ...
# Searching for author with id o70NT8IAAAAJ...
# Searching for author with id ZeGca3cAAAAJ...
# Searching for author with id o3DdNZMAAAAJ...
# Searching for author with id Ydo9ResAAAAJ...
# Searching for author with id 4IRe3WYAAAAJ...
# Searching for author with id zkBXb_kAAAAJ...
# Searching for author with id EHvA-IUAAAAJ...
# Searching for author with id 5RoxYhkAAAAJ...
# Searching for author with id ap3FfWEAAAAJ...
# Searching for author with id uxiJL_cAAAAJ...
# Searching for author with id QV_7inYAAAAJ...
# Searching for author with id JNrJo8cAAAAJ...
# Searching for author with id o70NT8IAAAAJ...
# Searching for author with id ZeGca3cAAAAJ...
# Searching for author with id o3DdNZMAAAAJ...
# Searching for author with id Ydo9ResAAAAJ...
# Searching for author with id 4IRe3WYAAAAJ...
# Searching for author with id zkBXb_kAAAAJ...
# Searching for author with id EHvA-IUAAAAJ...
# Searching for author with id 5RoxYhkAAAAJ...
# Searching for author with id ap3FfWEAAAAJ...
# Searching for author with id uxiJL_cAAAAJ...
# Searching for author with id QV_7inYAAAAJ...
# Searching for author with id JNrJo8cAAAAJ...
# Searching for author with id o70NT8IAAAAJ...
# Searching for author with id ZeGca3cAAAAJ...
# Searching for author with id o3DdNZMAAAAJ...
# Searching for author with id Ydo9ResAAAAJ...
# Searching for author with id 4IRe3WYAAAAJ...
# Searching for author with id zkBXb_kAAAAJ...
# Searching for author with id EHvA-IUAAAAJ...
# Searching for author with id 5RoxYhkAAAAJ...
# Searching for author with id ap3FfWEAAAAJ...
# Searching for author with id uxiJL_cAAAAJ...
# Searching for author with id QV_7inYAAAAJ...
# Searching for author with id JNrJo8cAAAAJ...
# Searching for author with id o70NT8IAAAAJ...
# Searching for author with id ZeGca3cAAAAJ...
# Searching for author with id o3DdNZMAAAAJ...
# Searching for author with id Ydo9ResAAAAJ...
# Searching for author with id 4IRe3WYAAAAJ...
# Searching for author with id zkBXb_kAAAAJ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 get_ipython().run_cell_magic('timeit', '', 'authors = search_authors(papers)\n')
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/IPython/core/magics/execution.py:1189, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1186         if time_number >= 0.2:
#    1187             break
# -> 1189 all_runs = timer.repeat(repeat, number)
#    1190 best = min(all_runs) / number
#    1191 worst = max(all_runs) / number
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/timeit.py:208, in Timer.repeat(self, repeat, number)
#     206 r = []
#     207 for i in range(repeat):
# --> 208     t = self.timeit(number)
#     209     r.append(t)
#     210 return r
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/IPython/core/magics/execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# Cell In[27], line 15, in search_authors(papers)
#      13 print(f'Searching for author with id {author_id}...')
#      14 #author = scholarly.fill(scholarly.search_author_id(author_id))
# ---> 15 author = scholarly.fill(scholarly.search_author_id(author_id), sections=['basics'])
#      16 authors.append({
#      17     "author_id": author_id,
#      18     "name": author.get("name"),
#      19     "affiliation": author.get("affiliation", "Unknown")
#      20 })
#      21 author_ids.append(author_id)
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_scholarly.py:349, in _Scholarly.search_author_id(self, id, filled, sortby, publication_limit)
#     322 def search_author_id(self, id: str, filled: bool = False, sortby: str = "citedby", publication_limit: int = 0)->Author:
#     323     """Search by author id and return a single Author object
#     324     :param sortby: select the order of the citations in the author page. Either by 'citedby' or 'year'. Defaults to 'citedby'.
#     325     :type sortby: string
#    (...)
#     347              'url_picture': 'https://scholar.googleusercontent.com/citations?view_op=view_photo&user=EmD_lTEAAAAJ&citpid=3'}
#     348     """
# --> 349     return self.__nav.search_author_id(id, filled, sortby, publication_limit)
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:316, in Navigator.search_author_id(self, id, filled, sortby, publication_limit)
#     314     res = author_parser.fill(res, sortby=sortby, publication_limit=publication_limit)
#     315 else:
# --> 316     res = author_parser.fill(res, sections=['basics'], sortby=sortby, publication_limit=publication_limit)
#     317 return res
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/author_parser.py:441, in AuthorParser.fill(self, author, sections, sortby, publication_limit)
#     439 url_citations += sortby_str
#     440 url = '{0}&pagesize={1}'.format(url_citations, _PAGESIZE)
# --> 441 soup = self.nav._get_soup(url)
#     443 # Update scholar_id
#     444 scholar_id = re.findall(_CITATIONAUTHRE, soup.find("link", rel="canonical").get('href', ""))[0]
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:239, in Navigator._get_soup(self, url)
#     237 def _get_soup(self, url: str) -> BeautifulSoup:
#     238     """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 239     html = self._get_page('https://scholar.google.com{0}'.format(url))
#     240     html = html.replace(u'\xa0', u' ')
#     241     res = BeautifulSoup(html, 'html.parser')
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:113, in Navigator._get_page(self, pagerequest, premium)
#     111 try:
#     112     w = random.uniform(1,2)
# --> 113     time.sleep(w)
#     114     resp = session.get(pagerequest, timeout=timeout)
#     115     if premium is False:  # premium methods may contain sensitive information
#
# KeyboardInterrupt:

# %%
authors
# Out:
# [{'author_id': 'zkBXb_kAAAAJ',
#   'name': 'Zhi-Ping Liu',
#   'affiliation': 'Professor of Biomedical Informatics, Shandong University'},
#  {'author_id': 'EHvA-IUAAAAJ',
#   'name': 'Pufeng Du',
#   'affiliation': 'Tianjin University; Tsinghua University; City University of Hong Kong'},
#  {'author_id': '5RoxYhkAAAAJ', 'name': 'Jianjun Tan', 'affiliation': '北京工业大学'},
#  {'author_id': 'ap3FfWEAAAAJ',
#   'name': 'Caitlin Simopoulos',
#   'affiliation': 'Roche'},
#  {'author_id': 'uxiJL_cAAAAJ',
#   'name': 'Hibah Shaath',
#   'affiliation': 'Hamad Bin Khalifa University'},
#  {'author_id': 'QV_7inYAAAAJ',
#   'name': 'Vishnubalaji radhakrishnan',
#   'affiliation': 'HBKU-QBRI, Qatar Foundation'},
#  {'author_id': 'JNrJo8cAAAAJ',
#   'name': 'Ramesh Elango',
#   'affiliation': 'QBRI, Hamad bin Khalifa University'},
#  {'author_id': 'o70NT8IAAAAJ', 'name': 'Qiqi Xie', 'affiliation': 'IUB'},
#  {'author_id': 'ZeGca3cAAAAJ',
#   'name': 'Halise Busra Cagirici',
#   'affiliation': 'Stanford University'},
#  {'author_id': 'o3DdNZMAAAAJ',
#   'name': 'Sergio Galvez Rojas',
#   'affiliation': 'Profesor de Informática. Universidad de Málaga. Spain'},
#  {'author_id': 'Ydo9ResAAAAJ',
#   'name': 'Taner Sen',
#   'affiliation': 'Research Scientist, USDA-ARS, GrainGenes / Adj. Prof., UC Berkeley'},
#  {'author_id': '4IRe3WYAAAAJ',
#   'name': 'Hikmet Budak',
#   'affiliation': 'Arizona Western College'}]

# %%
x = scholarly.search_author_id('4IRe3WYAAAAJ')

# %%
x
# Out:
# {'container_type': 'Author',
#  'filled': ['basics'],
#  'scholar_id': '4IRe3WYAAAAJ',
#  'source': <AuthorSource.AUTHOR_PROFILE_PAGE: 'AUTHOR_PROFILE_PAGE'>,
#  'name': 'Hikmet Budak',
#  'url_picture': 'https://scholar.googleusercontent.com/citations?view_op=view_photo&user=4IRe3WYAAAAJ&citpid=10',
#  'affiliation': 'Arizona Western College',
#  'interests': ['wheat genomics',
#   'wheat genetics',
#   'wheat',
#   'gene editing',
#   'miRNA'],
#  'email_domain': '@unl.edu',
#  'homepage': 'https://loop.frontiersin.org/people/59677/overview',
#  'citedby': 36995}

# %%
y = scholarly.fill(x, sections=['basics'])

# %%
y
# Out:
# {'container_type': 'Author',
#  'filled': ['basics'],
#  'scholar_id': '4IRe3WYAAAAJ',
#  'source': <AuthorSource.AUTHOR_PROFILE_PAGE: 'AUTHOR_PROFILE_PAGE'>,
#  'name': 'Hikmet Budak',
#  'url_picture': 'https://scholar.googleusercontent.com/citations?view_op=view_photo&user=4IRe3WYAAAAJ&citpid=10',
#  'affiliation': 'Arizona Western College',
#  'interests': ['wheat genomics',
#   'wheat genetics',
#   'wheat',
#   'gene editing',
#   'miRNA'],
#  'email_domain': '@unl.edu',
#  'homepage': 'https://loop.frontiersin.org/people/59677/overview',
#  'citedby': 36995}

# %%
import pandas as pd

# %% [markdown]
# 1. Search for articles by keywords
# 2. Save article and associated author in separate dataframes

# %% [markdown]
# Create empty dataframes

# %% [markdown]
# pd.DataFrame()

# %%
sq = scholarly.search_pubs("Machine Learning lncRNA")

# %%
p = next(sq)

# %%
p
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.PUBLICATION_SEARCH_SNIPPET: 'PUBLICATION_SEARCH_SNIPPET'>,
#  'bib': {'title': 'Predicting lncRNA-protein interactions by machine learning methods: a review',
#   'author': ['ZP Liu'],
#   'pub_year': '2020',
#   'venue': 'Current Bioinformatics',
#   'abstract': 'Here, we aim to provide a review of machine-learning-based methods for predicting lncRNA  of predicting lncRNA-protein interactions into a general framework of machine learning. We'},
#  'filled': False,
#  'gsrank': 1,
#  'pub_url': 'https://www.ingentaconnect.com/content/ben/cbio/2020/00000015/00000008/art00005',
#  'author_id': ['zkBXb_kAAAAJ'],
#  'url_scholarbib': '/scholar?hl=en&q=info:wfC5OKxQqHMJ:scholar.google.com/&output=cite&scirp=0&hl=en',
#  'url_add_sclib': '/citations?hl=en&xsrf=&continue=/scholar%3Fq%3DMachine%2BLearning%2BlncRNA%26hl%3Den%26as_sdt%3D0,33&citilm=1&update_op=library_add&info=wfC5OKxQqHMJ&ei=NyxfZ_frIcyR6rQPhb_isQU&json=',
#  'num_citations': 16,
#  'citedby_url': '/scholar?cites=8333999811065409729&as_sdt=5,33&sciodt=0,33&hl=en',
#  'url_related_articles': '/scholar?q=related:wfC5OKxQqHMJ:scholar.google.com/&scioq=Machine+Learning+lncRNA&hl=en&as_sdt=0,33'}

# %%
list(p.keys())
# Out:
# ['container_type',
#  'source',
#  'bib',
#  'filled',
#  'gsrank',
#  'pub_url',
#  'author_id',
#  'url_scholarbib',
#  'url_add_sclib',
#  'num_citations',
#  'citedby_url',
#  'url_related_articles']

# %%
author_id = 'zkBXb_kAAAAJ'
author = scholarly.fill(scholarly.search_author_id(author_id))

# %%
author
# Out:
# {'container_type': 'Author',
#  'filled': ['basics',
#   'indices',
#   'counts',
#   'coauthors',
#   'publications',
#   'public_access'],
#  'scholar_id': 'zkBXb_kAAAAJ',
#  'source': <AuthorSource.AUTHOR_PROFILE_PAGE: 'AUTHOR_PROFILE_PAGE'>,
#  'name': 'Zhi-Ping Liu',
#  'affiliation': 'Professor of Biomedical Informatics, Shandong University',
#  'organization': 16033752023248436093,
#  'interests': ['Bioinformatics',
#   'Computational Biology',
#   'Systems Biomedicine',
#   'Machine Learning',
#   'Operations Research'],
#  'email_domain': '@sdu.edu.cn',
#  'citedby': 5975,
#  'citedby5y': 3478,
#  'hindex': 37,
#  'hindex5y': 28,
#  'i10index': 75,
#  'i10index5y': 62,
#  'cites_per_year': {2011: 34,
#   2012: 109,
#   2013: 261,
#   2014: 328,
#   2015: 378,
#   2016: 407,
#   2017: 458,
#   2018: 442,
#   2019: 432,
#   2020: 445,
#   2021: 577,
#   2022: 685,
#   2023: 621,
#   2024: 713},
#  'coauthors': [{'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'Uoqv8rkAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Luonan Chen',
#    'affiliation': 'Professor of Shanghai Institute of Biochemistry and Cell Biology, Chinese Academy of Sciences'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '_KWHrHYAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Xiang-Sun Zhang',
#    'affiliation': 'Academy of Mathematics and Systems Science, Chinese Academy of Sciences '},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'M0fnh30AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Yong Wang',
#    'affiliation': 'Academy of Mathematics and Systems Science, Chinese Academy of Sciences'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'FQ1eHlUAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Ling-Yun Wu',
#    'affiliation': 'Professor of Academy of Mathematics and Systems Science, Chinese Academy of Sciences'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'OIWfp-QAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Jiguang Wang',
#    'affiliation': 'Hong Kong University of Science and Technology'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'o66S6gUAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Xing-Ming Zhao',
#    'affiliation': 'Fudan University'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '6k2WBGIAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Jin-Kao Hao',
#    'affiliation': 'Professor of Computer Science, University of Angers, France'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'RE9PF_YAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Katsuhisa Horimoto',
#    'affiliation': 'National Institute of Advanced Industrial Science and Technology'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '_VToyMIAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Shuang Wu',
#    'affiliation': 'University of Rochester'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': '98-GozcAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Jean-Michel Richer',
#    'affiliation': "LERIA (Laboratoire d'Etudes et de Recherche en Informatique d'Angers)"},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'hKenL84AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Martin S. Zand',
#    'affiliation': 'University of Rochester Medical Center'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'j0Ldb18AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Alicia Henn',
#    'affiliation': 'Chief Scientific Officer, BioSpherix, Ltd.'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'twM8v8YAAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'Kun He',
#    'affiliation': 'Bayer Crop Sciences'},
#   {'container_type': 'Author',
#    'filled': [],
#    'scholar_id': 'a82BHa8AAAAJ',
#    'source': <AuthorSource.CO_AUTHORS_LIST: 'CO_AUTHORS_LIST'>,
#    'name': 'hulin wu',
#    'affiliation': 'Professor of Biostatistics, University of Texas Health Science Center at Houston'}],
#  'publications': [{'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Detecting early-warning signals for sudden deterioration of complex diseases by dynamical network biomarkers',
#     'pub_year': '2012',
#     'citation': 'Scientific reports 2 (1), 342, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:u5HHmVD_uO8C',
#    'num_citations': 597,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=822718048413748926',
#    'cites_id': ['822718048413748926']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'RNA exosome-regulated long non-coding RNA transcription controls super-enhancer activity',
#     'pub_year': '2015',
#     'citation': 'Cell 161 (4), 774-789, 2015'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:6ZxmRoH8BuwC',
#    'num_citations': 472,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11807495112794293634',
#    'cites_id': ['11807495112794293634']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'RegNetwork: an integrated database of transcriptional and post-transcriptional regulatory networks in human and mouse',
#     'pub_year': '2015',
#     'citation': 'Database 2015, bav095, 2015'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:GFxP56DSvIMC',
#    'num_citations': 450,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3310545668391948275',
#    'cites_id': ['3310545668391948275']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Inferring gene regulatory networks from gene expression data by path consistency algorithm based on conditional mutual information',
#     'pub_year': '2012',
#     'citation': 'Bioinformatics 28 (1), 98-104, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:2osOgNQ5qMEC',
#    'num_citations': 365,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17302511170980557191',
#    'cites_id': ['17302511170980557191']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Type 1 interferons induce changes in core metabolism that are critical for immune function',
#     'pub_year': '2016',
#     'citation': 'Immunity 44 (6), 1325-1336, 2016'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:6H908wyzF9cC',
#    'num_citations': 312,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7926734966678005279',
#    'cites_id': ['7926734966678005279']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Multiple-resource and multiple-depot emergency response problem considering secondary disasters',
#     'pub_year': '2012',
#     'citation': 'Expert Systems with Applications 39 (12), 11066-11071, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:Tyk-4Ss8FVUC',
#    'num_citations': 204,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1261211900064029459',
#    'cites_id': ['1261211900064029459']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying critical transitions and their leading biomolecular networks in complex diseases',
#     'pub_year': '2012',
#     'citation': 'Scientific reports 2 (1), 813, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:Y0pCki6q_DkC',
#    'num_citations': 187,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14072027656890208378',
#    'cites_id': ['14072027656890208378']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Prediction of protein–RNA binding sites by a random forest method with combined features',
#     'pub_year': '2010',
#     'citation': 'Bioinformatics 26 (13), 1616-1622, 2010'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:u-x6o8ySG0sC',
#    'num_citations': 181,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12220506767797395459',
#    'cites_id': ['12220506767797395459']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'NARROMI: a noise and redundancy reduction technique improves accuracy of gene regulatory network inference',
#     'pub_year': '2013',
#     'citation': 'Bioinformatics 29 (1), 106-113, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:_FxGoFyzp5QC',
#    'num_citations': 161,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13190110849281246275',
#    'cites_id': ['13190110849281246275']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Prevention of aortic dissection and aneurysm via an ALDH2-mediated switch in vascular smooth muscle cell phenotype',
#     'pub_year': '2020',
#     'citation': 'European Heart Journal 41 (26), 2442-2453, 2020'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:FOZckGct7WUC',
#    'num_citations': 139,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15266247883587356595',
#    'cites_id': ['15266247883587356595']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying dysregulated pathways in cancers from pathway interaction networks',
#     'pub_year': '2012',
#     'citation': 'BMC bioinformatics 13, 1-11, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:zYLM7Y9cAGgC',
#    'num_citations': 139,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3461133751766214740',
#    'cites_id': ['3461133751766214740']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'NOA: a novel Network Ontology Analysis method',
#     'pub_year': '2011',
#     'citation': 'Nucleic acids research 39 (13), e87-e87, 2011'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:d1gkVwhDpl0C',
#    'num_citations': 123,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5488624493603336988',
#    'cites_id': ['5488624493603336988']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'De novo prediction of RNA–protein interactions from sequence information',
#     'pub_year': '2013',
#     'citation': 'Molecular BioSystems 9 (1), 133-142, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:hqOjcs7Dif8C',
#    'num_citations': 118,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8199788761932183165',
#    'cites_id': ['8199788761932183165']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying disease genes and module biomarkers by differential interactions',
#     'pub_year': '2012',
#     'citation': 'Journal of the American Medical Informatics Association 19 (2), 241-248, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:UeHWp8X0CEIC',
#    'num_citations': 116,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=753197524434283232',
#    'cites_id': ['753197524434283232']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Coexpression network analysis in chronic hepatitis B and C hepatic lesions reveals distinct patterns of disease progression to hepatocellular carcinoma',
#     'pub_year': '2012',
#     'citation': 'Journal of Molecular Cell Biology 4 (3), 140-152, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:qjMakFHDy7sC',
#    'num_citations': 111,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7446240869883394558',
#    'cites_id': ['7446240869883394558']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Network-based analysis of complex diseases',
#     'pub_year': '2012',
#     'citation': 'IET Systems Biology 6 (1), 22-33, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:IjCSPb-OGe4C',
#    'num_citations': 99,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5195679120237605668',
#    'cites_id': ['5195679120237605668']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Identifying dysfunctional crosstalk of pathways in various regions of Alzheimer's disease brains",
#     'pub_year': '2010',
#     'citation': 'BMC Systems Biology 4, 1-12, 2010'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:9yKSN-GCB0IC',
#    'num_citations': 98,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2562962189663801765',
#    'cites_id': ['2562962189663801765']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Reverse engineering of genome-wide gene regulatory networks from gene expression data',
#     'pub_year': '2015',
#     'citation': 'Current Genomics 16 (1), 3-22, 2015'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:_Re3VWB3Y0AC',
#    'num_citations': 89,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4248208124184151629',
#    'cites_id': ['4248208124184151629']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'High-resolution temporal response patterns to influenza vaccine reveal a distinct human plasma cell gene signature',
#     'pub_year': '2013',
#     'citation': 'Scientific reports 3 (1), 2327, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:SeFeTyx0c_EC',
#    'num_citations': 80,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7359557505508048862',
#    'cites_id': ['7359557505508048862']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Prediction of hot spots in protein interfaces using a random forest model with hybrid features',
#     'pub_year': '2012',
#     'citation': 'Protein Engineering, Design & Selection 25 (3), 119-126, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:LkGwnXOMwfcC',
#    'num_citations': 75,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1753015608895167692',
#    'cites_id': ['1753015608895167692']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Linear discriminant analysis',
#     'pub_year': '1957',
#     'citation': 'Virginia Polytechnic Institute, 1957'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:4TOpqqG69KYC',
#    'num_citations': 71,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=143691351935505239',
#    'cites_id': ['143691351935505239']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Spatio-temporal analysis of type 2 diabetes mellitus based on differential expression networks',
#     'pub_year': '2013',
#     'citation': 'Scientific reports 3 (1), 2268, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:8k81kl-MbHgC',
#    'num_citations': 69,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=904110642550217162',
#    'cites_id': ['904110642550217162']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'An integrated approach to identify causal network modules of complex diseases with application to colorectal cancer',
#     'pub_year': '2013',
#     'citation': 'Journal of the American Medical Informatics Association 20 (4), 659-667, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:eQOLeE2rZwMC',
#    'num_citations': 68,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5361544476624317043',
#    'cites_id': ['5361544476624317043']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Prediction of cardiovascular diseases by integrating multi-modal features with machine learning methods',
#     'pub_year': '2021',
#     'citation': 'Biomedical Signal Processing and Control 66, 102474, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:gyFZhc6YOh8C',
#    'num_citations': 66,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14891346568154343898',
#    'cites_id': ['14891346568154343898']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Predicting coastal algal blooms with environmental factors by machine learning methods',
#     'pub_year': '2021',
#     'citation': 'Ecological Indicators 123, 107334, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:LyOydA3uxaIC',
#    'num_citations': 63,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8882029350941996444',
#    'cites_id': ['8882029350941996444']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identification of dysfunctional modules and disease genes in congenital heart disease by a network-based approach',
#     'pub_year': '2011',
#     'citation': 'BMC genomics 12, 1-16, 2011'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:YsMSGLbcyi4C',
#    'num_citations': 63,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5709933943950943128',
#    'cites_id': ['5709933943950943128']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Community structure detection based on Potts model and network's spectral characterization",
#     'pub_year': '2012',
#     'citation': 'Europhysics Letters 97 (4), 48005, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:3s1wT3WcHBgC',
#    'num_citations': 58,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16513444912420432296',
#    'cites_id': ['16513444912420432296']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Bridging protein local structures and protein functions',
#     'pub_year': '2008',
#     'citation': 'Amino acids 35, 627-650, 2008'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:W7OEmFMy1HYC',
#    'num_citations': 50,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18037923572253336599',
#    'cites_id': ['18037923572253336599']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Proteome-wide prediction of protein-protein interactions from high-throughput data',
#     'pub_year': '2012',
#     'citation': 'Protein & cell 3 (7), 508-520, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:0EnyYjriUFMC',
#    'num_citations': 46,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12627572968499059310',
#    'cites_id': ['12627572968499059310']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Mechanism of noncoding RNA-associated N6-methyladenosine recognition by an RNA processing complex during IgH DNA recombination',
#     'pub_year': '2021',
#     'citation': 'Molecular cell 81 (19), 3949-3964. e7, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:rR1SM4wcGAYC',
#    'num_citations': 45,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11334747309468749514',
#    'cites_id': ['11334747309468749514']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying network-based biomarkers of complex diseases from high-throughput data',
#     'pub_year': '2016',
#     'citation': 'Biomarkers in Medicine 10 (6), 633-650, 2016'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:P7Ujq4OLJYoC',
#    'num_citations': 45,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7510122889192068206',
#    'cites_id': ['7510122889192068206']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying overlapping communities in social networks using multi-scale local information expansion',
#     'pub_year': '2012',
#     'citation': 'The European Physical Journal B 85, 1-9, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:vDijr-p_gm4C',
#    'num_citations': 41,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10229008587160023120',
#    'cites_id': ['10229008587160023120']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Noncoding RNA transcription alters chromosomal topology to promote isotype-specific class switch recombination',
#     'pub_year': '2020',
#     'citation': 'Science Immunology 5 (44), eaay5864, 2020'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:ouq6-fJ2VSQC',
#    'num_citations': 40,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10153885699872916037',
#    'cites_id': ['10153885699872916037']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Detecting diagnostic biomarkers of Alzheimer's disease by integrating gene expression data in six brain regions",
#     'pub_year': '2019',
#     'citation': 'Frontiers in genetics 10, 157, 2019'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:MkYP4vM-iK8C',
#    'num_citations': 40,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8812174525927831851',
#    'cites_id': ['8812174525927831851']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Graph attention network for link prediction of gene regulations from single-cell RNA-sequencing data',
#     'pub_year': '2022',
#     'citation': 'Bioinformatics 38 (19), 4522-4529, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:KjbfwUOO_FMC',
#    'num_citations': 39,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11334424612432981198',
#    'cites_id': ['11334424612432981198']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Systematic identification of transcriptional and post-transcriptional regulations in human respiratory epithelial cells during influenza A virus infection',
#     'pub_year': '2014',
#     'citation': 'BMC bioinformatics 15, 1-18, 2014'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:olpn-zPbct0C',
#    'num_citations': 39,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17631655879380290007',
#    'cites_id': ['17631655879380290007']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Robust biomarker screening from gene expression data by stable machine learning-recursive feature elimination methods',
#     'pub_year': '2022',
#     'citation': 'Computational Biology and Chemistry 100, 107747, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:CUz-cjXBMXMC',
#    'num_citations': 38,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4196469143491871483',
#    'cites_id': ['4196469143491871483']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Modeling genome-wide dynamic regulatory network in mouse lungs with influenza infection using high-dimensional ordinary differential equations',
#     'pub_year': '2014',
#     'citation': 'PloS one 9 (5), e95276, 2014'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:yD5IFk8b50cC',
#    'num_citations': 36,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1267482821481062453',
#    'cites_id': ['1267482821481062453']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'DIPOS: database of interacting proteins in Oryza sativa',
#     'pub_year': '2011',
#     'citation': 'Molecular BioSystems 7 (9), 2615-2621, 2011'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:5nxA0vEk-isC',
#    'num_citations': 36,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8594907585420111539',
#    'cites_id': ['8594907585420111539']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Detecting thermophilic proteins through selecting amino acid and dipeptide composition features',
#     'pub_year': '2012',
#     'citation': 'Amino Acids 42, 1947-1953, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:rO6llkc54NcC',
#    'num_citations': 35,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1936394572069176337',
#    'cites_id': ['1936394572069176337']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Analysis of topological parameters of complex disease genes reveals the importance of location in a biomolecular network',
#     'pub_year': '2019',
#     'citation': 'Genes 10 (2), 143, 2019'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:gqw4OU68NNkC',
#    'num_citations': 34,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5789333853903199026',
#    'cites_id': ['5789333853903199026']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Detecting and analyzing differentially activated pathways in brain regions of Alzheimer's disease patients",
#     'pub_year': '2011',
#     'citation': 'Molecular BioSystems 7 (5), 1441-1452, 2011'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:roLk4NBRz8UC',
#    'num_citations': 34,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3857168892567035906',
#    'cites_id': ['3857168892567035906']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Macrophage ALDH2 (aldehyde dehydrogenase 2) stabilizing Rac2 is required for efferocytosis internalization and reduction of atherosclerosis development',
#     'pub_year': '2022',
#     'citation': 'Arteriosclerosis, Thrombosis, and Vascular Biology 42 (6), 700-716, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:L3c5sqbRKa8C',
#    'num_citations': 30,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6285549720934857345',
#    'cites_id': ['6285549720934857345']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Quantifying gene regulatory relationships with association measures: A comparative study',
#     'pub_year': '2017',
#     'citation': 'Frontiers in Genetics 8, 96, 2017'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:ax16qXk-rEQC',
#    'num_citations': 30,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13166032812111928759',
#    'cites_id': ['13166032812111928759']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying module biomarker in type 2 diabetes mellitus by discriminative area of functional activity',
#     'pub_year': '2015',
#     'citation': 'BMC Bioinformatics 16, 1-10, 2015'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:-_dYPAW6P2MC',
#    'num_citations': 29,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5338642760436646158',
#    'cites_id': ['5338642760436646158']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Network screening of Goto-Kakizaki rat liver microarray data during diabetic progression',
#     'pub_year': '2011',
#     'citation': 'BMC Systems Biology 5, 1-15, 2011'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:ufrVoPGSRksC',
#    'num_citations': 29,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8545739787540887941',
#    'cites_id': ['8545739787540887941']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Biomarker discovery for predicting spontaneous preterm birth from gene expression data by regularized logistic regression',
#     'pub_year': '2020',
#     'citation': 'Computational and Structural Biotechnology Journal 18, 3434-3446, 2020'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:0KrOiVmbFBYC',
#    'num_citations': 27,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3862438457449936542',
#    'cites_id': ['3862438457449936542']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Predicting gene ontology functions from protein's regional surface structures",
#     'pub_year': '2007',
#     'citation': 'BMC Bioinformatics 8, 1-13, 2007'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:WF5omc3nYNoC',
#    'num_citations': 27,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11575755117869881691',
#    'cites_id': ['11575755117869881691']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Robust biomarker discovery for hepatocellular carcinoma from high-throughput data by multiple feature selection methods',
#     'pub_year': '2021',
#     'citation': 'BMC Medical Genomics 14, 1-12, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:MagRZZew-58C',
#    'num_citations': 26,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9421928574815894421',
#    'cites_id': ['9421928574815894421']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Network-based prioritization of cancer genes by integrative ranks from multi-omics data',
#     'pub_year': '2020',
#     'citation': 'Computers in Biology and Medicine 119, 103692, 2020'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:2Km5FFimHwEC',
#    'num_citations': 25,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10289262189872186855',
#    'cites_id': ['10289262189872186855']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Inferring a protein interaction map of Mycobacterium tuberculosis based on sequences and interologs',
#     'pub_year': '2012',
#     'citation': 'BMC bioinformatics 13, 1-10, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:kNdYIx-mwKoC',
#    'num_citations': 24,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17506752267508783198',
#    'cites_id': ['17506752267508783198']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Detecting prognostic biomarkers of breast cancer by regularized Cox proportional hazards models',
#     'pub_year': '2021',
#     'citation': 'Journal of translational medicine 19, 1-20, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:UOgPUojWnykC',
#    'num_citations': 23,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5896315806874255459',
#    'cites_id': ['5896315806874255459']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'PST-PRNA: prediction of RNA-binding sites using protein surface topography and deep learning',
#     'pub_year': '2022',
#     'citation': 'Bioinformatics 38 (8), 2162-2168, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:sRzLl6AghiAC',
#    'num_citations': 21,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4468905325071372955',
#    'cites_id': ['4468905325071372955']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'CMIP: a software package capable of reconstructing genome-wide regulatory networks using gene expression data',
#     'pub_year': '2016',
#     'citation': 'BMC Bioinformatics 17, 137-144, 2016'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:VsjxJ5V0Y48C',
#    'num_citations': 21,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16617884796078954398',
#    'cites_id': ['16617884796078954398']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A sequence-based computational approach to predicting PDZ domain-peptide interactions',
#     'pub_year': '2014',
#     'citation': 'Biochimica et Biophysica Acta (BBA)-Proteins and Proteomics 1844 (1), 165-170, 2014'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:evX43VCCuoAC',
#    'num_citations': 21,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1991547260331470837',
#    'cites_id': ['1991547260331470837']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Gaussian graphical model for identifying significantly responsive regulatory networks from time course high‐throughput data',
#     'pub_year': '2013',
#     'citation': 'IET Systems Biology 7 (5), 143-152, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:KlAtU1dfN6UC',
#    'num_citations': 21,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5291881699766662995',
#    'cites_id': ['5291881699766662995']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Detecting pathway biomarkers of diabetic progression with differential entropy',
#     'pub_year': '2018',
#     'citation': 'Journal of Biomedical Informatics 82, 143-153, 2018'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:B9zx5l6rxUEC',
#    'num_citations': 20,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17822855730929229201',
#    'cites_id': ['17822855730929229201']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Nerve injury-induced neuronal PAP-I maintains neuropathic pain by activating spinal microglia',
#     'pub_year': '2020',
#     'citation': 'Journal of Neuroscience 40 (2), 297-310, 2020'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:iINcni2fUZgC',
#    'num_citations': 19,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11253479299547185712',
#    'cites_id': ['11253479299547185712']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'GeoBind: segmentation of nucleic acid binding interface on protein surface with geometric deep learning',
#     'pub_year': '2023',
#     'citation': 'Nucleic Acids Research 51 (10), e60-e60, 2023'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:FQnhRx9bfrkC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=887379840717659116',
#    'cites_id': ['887379840717659116']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A connected network-regularized logistic regression model for feature selection',
#     'pub_year': '2022',
#     'citation': 'Applied Intelligence 52 (10), 11672-11702, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:n94QCav8jycC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2191066656794147200',
#    'cites_id': ['2191066656794147200']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Predicting multiple types of MicroRNA-disease associations based on tensor factorization and label propagation',
#     'pub_year': '2022',
#     'citation': 'Computers in Biology and Medicine 146, 105558, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:_Nt1UvVys9QC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10564492680673100325',
#    'cites_id': ['10564492680673100325']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying biomarkers for breast cancer by gene regulatory network rewiring',
#     'pub_year': '2022',
#     'citation': 'BMC Bioinformatics 22 (Suppl 12), 308, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:n35PH7pn8T4C',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12385426601060882216',
#    'cites_id': ['12385426601060882216']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Predicting lncRNA-protein interactions by machine learning methods: a review',
#     'pub_year': '2020',
#     'citation': 'Current Bioinformatics 15 (8), 831-840, 2020'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:tVzLobxzA7YC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8333999811065409729',
#    'cites_id': ['8333999811065409729']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Prioritizing type 2 diabetes genes by weighted PageRank on bilayer heterogeneous networks',
#     'pub_year': '2019',
#     'citation': 'IEEE/ACM Transactions on Computational Biology and Bioinformatics 18 (1 …, 2019'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:yG35QFzCZWcC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11817917803257918318',
#    'cites_id': ['11817917803257918318']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A computational procedure for identifying master regulator candidates: a case study on diabetes progression in Goto-Kakizaki rats',
#     'pub_year': '2012',
#     'citation': 'BMC Systems Biology 6, 1-10, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:MXK_kJrjxJIC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7485723565232859850',
#    'cites_id': ['7485723565232859850']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Network analysis reveals roles of inflammatory factors in different phenotypes of kidney transplant patients',
#     'pub_year': '2014',
#     'citation': 'Journal of Theoretical Biology 362, 62-68, 2014'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:HoB7MX3m0LUC',
#    'num_citations': 15,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4633761776951233991',
#    'cites_id': ['4633761776951233991']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Dynamically dysfunctional protein interactions in the development of Alzheimer's disease",
#     'pub_year': '2009',
#     'citation': '2009 IEEE International Conference on Systems, Man and Cybernetics, 4262-4267, 2009'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:Se3iqnhoufwC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7109186826008322620',
#    'cites_id': ['7109186826008322620']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'LogBTF: gene regulatory network inference using Boolean threshold network model from single-cell gene expression data',
#     'pub_year': '2023',
#     'citation': 'Bioinformatics 39 (5), btad256, 2023'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:sK9NQJKSZRcC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10491821644955351098',
#    'cites_id': ['10491821644955351098']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Prediction of protein-RNA interactions using sequence and structure descriptors',
#     'pub_year': '2016',
#     'citation': 'Neurocomputing 206, 28-34, 2016'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:nZcligLrVowC',
#    'num_citations': 13,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5420258001473583819',
#    'cites_id': ['5420258001473583819']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Network-based prioritization of cancer biomarkers by phenotype-driven module detection and ranking',
#     'pub_year': '2022',
#     'citation': 'Computational and Structural Biotechnology Journal 20, 206-217, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:ShM3enpx8HwC',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4935989545238342190',
#    'cites_id': ['4935989545238342190']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Structure alignment-based classification of RNA-binding pockets reveals regional RNA recognition motifs on protein surfaces',
#     'pub_year': '2017',
#     'citation': 'BMC bioinformatics 18, 1-13, 2017'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:x-IcQEm-ju4C',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5792878479321421819',
#    'cites_id': ['5792878479321421819']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Analysis of protein surface patterns by pocket similarity network',
#     'pub_year': '2008',
#     'citation': 'Protein and Peptide Letters 15 (5), 448-455, 2008'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:UebtZRa9Y70C',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14164272582723471472',
#    'cites_id': ['14164272582723471472']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'High-dimensional ordinary differential equation models for reconstructing genome-wide dynamic regulatory networks',
#     'pub_year': '2013',
#     'citation': 'Topics in Applied Statistics: 2012 Symposium of the International Chinese …, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:35r97b3x0nAC',
#    'num_citations': 11,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16407102639489933549',
#    'cites_id': ['16407102639489933549']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying responsive modules by mathematical programming: an application to budding yeast cell cycle',
#     'pub_year': '2012',
#     'citation': 'PLoS one 7 (7), e41854, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:b0M2c_1WBrUC',
#    'num_citations': 11,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12359137616495277516',
#    'cites_id': ['12359137616495277516']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying cancer biomarkers from high-throughput RNA sequencing data by machine learning',
#     'pub_year': '2019',
#     'citation': 'Intelligent Computing Theories and Application: 15th International …, 2019'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:rv71eUSj1K8C',
#    'num_citations': 10,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4528966652895143781',
#    'cites_id': ['4528966652895143781']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A new framework for host-pathogen interaction research',
#     'pub_year': '2022',
#     'citation': 'Frontiers in Immunology 13, 1066733, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:ooaom_WTAwIC',
#    'num_citations': 9,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5909768528755171092',
#    'cites_id': ['5909768528755171092']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Evaluating gene regulatory network activity from dynamic expression data by regularized constraint programming',
#     'pub_year': '2022',
#     'citation': 'IEEE Journal of Biomedical and Health Informatics 26 (11), 5738-5749, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:adgdM4TzidAC',
#    'num_citations': 8,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15429337399663569734',
#    'cites_id': ['15429337399663569734']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
# ...
#    'cites_id': ['15218988705345278502']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'MuToN Quantifies Binding Affinity Changes upon Protein Mutations by Geometric Deep Learning',
#     'pub_year': '2024',
#     'citation': 'Advanced Science 11 (35), 2402918, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:jhmUvTrEinIC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2622960678889452807',
#    'cites_id': ['2622960678889452807']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'LogicGep: Boolean networks inference using symbolic regression from time-series transcriptomic profiling data',
#     'pub_year': '2024',
#     'citation': 'Briefings in Bioinformatics 25 (4), bbae286, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:uk0w_JccWH8C',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2067834652006778820',
#    'cites_id': ['2067834652006778820']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'MOFNet: A Deep Learning Framework of Integrating Multi-omics Data for Breast Cancer Diagnosis',
#     'pub_year': '2023',
#     'citation': 'International Conference on Intelligent Computing, 727-738, 2023'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:yDGX1xMBWXcC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3209182122347693011',
#    'cites_id': ['3209182122347693011']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Detecting Autism Spectrum Disorder from Functional Magnetic Resonance Imaging Data with an Ensemble Machine Learning Method',
#     'pub_year': '2023',
#     'citation': '2023 5th International Conference on Intelligent Medicine and Image …, 2023'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:DejRBzv9GVYC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17231056392697116927',
#    'cites_id': ['17231056392697116927']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A Comparison Study of Predicting lncRNA-Protein Interactions via Representative Network Embedding Methods',
#     'pub_year': '2022',
#     'citation': 'International Conference on Intelligent Computing, 3-13, 2022'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:UX7E2m6xpKUC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3150977865750018576',
#    'cites_id': ['3150977865750018576']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A semi-supervised learning algorithm for predicting MiRNA-disease association',
#     'pub_year': '2021',
#     'citation': '2021 IEEE International Conference on Bioinformatics and Biomedicine (BIBM …, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:W26WQ4UGDhEC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7627031323126310577',
#    'cites_id': ['7627031323126310577']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Inference of gene regulatory network from time series expression data by combining local geometric similarity and multivariate regression',
#     'pub_year': '2021',
#     'citation': 'Intelligent Computing Theories and Application: 17th International …, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:cKQgJgBA5EIC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13063997054865907432',
#    'cites_id': ['13063997054865907432']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A Severity Diagnosis Method for Heart Disease based on Fusion Rough Sets',
#     'pub_year': '2020',
#     'citation': 'Proceedings of the 2020 2nd International Conference on Intelligent Medicine …, 2020'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:8k3R5ScbChQC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1916954488082909367',
#    'cites_id': ['1916954488082909367']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Multiscale modeling biological systems: Selected papers from the 8th International Conference on Systems Biology and the 4th International Translation Bioinformatics Conference …',
#     'pub_year': '2016',
#     'citation': 'IET Systems Biology 10 (1), 1-1, 2016'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:BJbdYPG6LGMC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1364993583555634772',
#    'cites_id': ['1364993583555634772']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Construction and analysis of single nucleotide polymorphism–single nucleotide polymorphism interaction networks',
#     'pub_year': '2013',
#     'citation': 'IET Systems Biology 7 (5), 170-181, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:bFFifWiqnPAC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4764181498812361798',
#    'cites_id': ['4764181498812361798']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identification of overlapping communities in protein interaction networks using multi-scale local information expansion',
#     'pub_year': '2012',
#     'citation': 'Proceedings of the 10th World Congress on Intelligent Control and Automation …, 2012'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:LqrXEw5M15gC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5037211944241039024',
#    'cites_id': ['5037211944241039024']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Protein interaction prediction for mouse PDZ domains using dipeptide composition features',
#     'pub_year': '2011',
#     'citation': '2011 IEEE International Conference on Systems Biology (ISB), 129-132, 2011'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:9KdEqzwCTsEC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9792064685271089808',
#    'cites_id': ['9792064685271089808']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identification of master regulator candidates for diabetes progression in Goto-Kakizaki Rat by a computational procedure',
#     'pub_year': '2011',
#     'citation': '2011 IEEE International Conference on Systems Biology (ISB), 197-202, 2011'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:j8SEvjWlNXcC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8785384369118799946',
#    'cites_id': ['8785384369118799946']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'An approach for clustering protein pockets into similar groups',
#     'pub_year': '2007',
#     'citation': 'Optimization and systems biology. Lecture Notes in Operations Research 7 …, 2007'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:YOwf2qJgpHMC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10011429445727124738',
#    'cites_id': ['10011429445727124738']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Discovering explainable biomarkers for breast cancer anti-PD1 response via network Shapley value analysis',
#     'pub_year': '2024',
#     'citation': 'Computer Methods and Programs in Biomedicine 257, 108481, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:4givWmz5LegC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'SpaGRA: Graph augmentation facilitates domain identification for spatially resolved transcriptomics',
#     'pub_year': '2024',
#     'citation': 'Journal of Genetics and Genomics, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:TAkmkrPVePIC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Network biology approach unveils transcriptomic alterations triggered by particle radiation',
#     'pub_year': '2024',
#     'citation': 'Molecular Therapy-Nucleic Acids 35 (3), 102294, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:H4IpxOyCX80C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'TopMarker: Computational Screening Biomarkers of Hepatocellular Carcinoma from Transcriptome and Interactome Based on Differential Network Topological Parameters',
#     'pub_year': '2024',
#     'citation': 'Computational Biology and Chemistry 112, 108166, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:8Rip7PbZ7AYC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Predicting Drug-Target Affinity Using Protein Pocket and Graph Convolution Network',
#     'pub_year': '2024',
#     'citation': 'International Symposium on Bioinformatics Research and Applications, 1-12, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:sJRvXmEhuqoC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Drug-target Affinity Prediction by Molecule Secondary Structure Representation Network.',
#     'pub_year': '2024',
#     'citation': 'Current Medicinal Chemistry, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:Dqu_ECg3lNoC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Network Activity Evaluation Reveals Significant Gene Regulatory Architectures during SARS-CoV-2 Viral Infection from Dynamic scRNA-seq Data',
#     'pub_year': '2024',
#     'citation': 'IEEE Journal of Biomedical and Health Informatics 28 (4), 2373-2384, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:mN77zE6YZBUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Spatial Transcriptomic Study Reveals Heterogeneous Metabolic Adaptation and a Role of Pericentral PPARα/CAR/Ces2a Axis During Fasting in Mouse Liver',
#     'pub_year': '2024',
#     'citation': 'Advanced Science, 2405240, 2024'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:VoB_afVdn6EC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Insights in integrative bioinformatics–2021',
#     'pub_year': '2023',
#     'citation': 'Frontiers in Bioinformatics 3, 1267370, 2023'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:_hb0F9yZ3cgC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Drug-target Affinity Prediction Based on Deep Learning and Multi-layered Information Fusion',
#     'pub_year': '2021',
#     'citation': 'China Biotechnology 41 (11), 40-47, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:xEh6bupSuykC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying Biomarkers of HCV-induced Dysplasia and Hepatocellular Carcinoma Based on Network Centrality',
#     'pub_year': '2021',
#     'citation': '2021 3rd International Conference on Intelligent Medicine and Image …, 2021'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:WhXzBXCJJjMC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'iNOA: An Improvement of Network Ontology Analysis with GO Semantic Similarity',
#     'pub_year': '2020',
#     'citation': 'Proceedings of the 5th International Conference on Biomedical Signal and …, 2020'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:SuREjsGmJT0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Selected papers from The 7th IEEE International Conference on Systems Biology (ISB 2013)',
#     'pub_year': '2014',
#     'citation': 'IET Systems Biology 8 (4), 127-128, 2014'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:2KloaMYe4IUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Prediction of RNA Binding Sites in Proteins',
#     'pub_year': '2013',
#     'citation': 'Algorithmic and Artificial Intelligence Methods for Protein Bioinformatics …, 2013'},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:xyhAN3YsZoYC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Crosstalk of Dysfunctional Pathways in Alzheimer’s Disease Brains',
#     'pub_year': '2009',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:e6AMIDGT8rIC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Analysis of domain interactions among gamma-secretase substrates',
#     'pub_year': '2008',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:aqlVkmm33-oC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Construction of Transcriptional Regulatory Network during Rice Anther Development',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:scjTk0LcRdsC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Identifying functional motifs on protein surfaces by structural alignment with sequence information',
#     'citation': ''},
#    'filled': False,
#    'author_pub_id': 'zkBXb_kAAAAJ:qxL8FJ1GzNcC',
#    'num_citations': 0}],
#  'public_access': {'available': 55, 'not_available': 22}}

# %% [markdown]
# ----

# %%
p2 = next(sq)

# %%
p2
# Out:
# {'container_type': 'Publication',
#  'source': <PublicationSource.PUBLICATION_SEARCH_SNIPPET: 'PUBLICATION_SEARCH_SNIPPET'>,
#  'bib': {'title': 'Recent advances in predicting protein-lncRNA interactions using machine learning methods',
#   'author': ['H Yu', 'ZA Shen', 'YK Zhou', 'PF Du'],
#   'pub_year': '2022',
#   'venue': 'Current Gene Therapy',
#   'abstract': 'classified into the deep learning-based method, the ensemble learning-based method,  and  learning methods. We summarized the state-of-the-art methods in predicting lncRNA-protein'},
#  'filled': False,
#  'gsrank': 2,
#  'pub_url': 'https://www.ingentaconnect.com/content/ben/cgt/2022/00000022/00000003/art00005',
#  'author_id': ['', '', '', 'EHvA-IUAAAAJ'],
#  'url_scholarbib': '/scholar?hl=en&q=info:WeRErDw2Ap8J:scholar.google.com/&output=cite&scirp=1&hl=en',
#  'url_add_sclib': '/citations?hl=en&xsrf=&continue=/scholar%3Fq%3DMachine%2BLearning%2BlncRNA%26hl%3Den%26as_sdt%3D0,33&citilm=1&update_op=library_add&info=WeRErDw2Ap8J&ei=NyxfZ_frIcyR6rQPhb_isQU&json=',
#  'num_citations': 21,
#  'citedby_url': '/scholar?cites=11457780036200096857&as_sdt=5,33&sciodt=0,33&hl=en',
#  'url_related_articles': '/scholar?q=related:WeRErDw2Ap8J:scholar.google.com/&scioq=Machine+Learning+lncRNA&hl=en&as_sdt=0,33'}

# %%
for a in p2['author_id']:
    if a:
        print(a)
# Out:
# EHvA-IUAAAAJ

# %% [markdown]
# ----

# %%
import spacy

# Load the spaCy language model
nlp = spacy.load("en_core_web_sm")

def extract_organizations(affiliation):
    """Extracts organization names from a affiliation value of an author record."""
    organizations = []
    
    doc = nlp(affiliation)
    # Extract entities labeled as ORG (organization)
    for ent in doc.ents:
        if ent.label_ == "ORG":
            organizations.append(ent.text)
    return organizations

# %%
for paper in papers:
    print(f"Title: {paper['title']}")
    print(f"Abstract: {paper['abstract']}")
    print(f"Year: {paper['year']}")
    print(f"URL: {paper['url']}")
    print("Authors:")
    for author in paper["authors"]:
        print(f"  - {author['name']}: {author['affiliation']}")
    print("-" * 80)
# Out:
# Title: Predicting lncRNA-protein interactions by machine learning methods: a review
# Abstract: Here, we aim to provide a review of machine-learning-based methods for predicting lncRNA  of predicting lncRNA-protein interactions into a general framework of machine learning. We
# Year: 2020
# URL: Unknown
# Authors:
#   - Zhi-Ping Liu: Professor of Biomedical Informatics, Shandong University
# --------------------------------------------------------------------------------
# Title: Recent advances in predicting protein-lncRNA interactions using machine learning methods
# Abstract: classified into the deep learning-based method, the ensemble learning-based method,  and  learning methods. We summarized the state-of-the-art methods in predicting lncRNA-protein
# Year: 2022
# URL: Unknown
# Authors:
#   - Pufeng Du: Tianjin University; Tsinghua University; City University of Hong Kong
# --------------------------------------------------------------------------------
# Title: Recent advances in machine learning methods for predicting LncRNA and disease associations
# Abstract: machine learning prediction models of LDAs. Finally, we discuss the potential limitations of  machine learning- This paper focuses on some advanced machine learning-based LDAs
# Year: 2022
# URL: https://www.frontiersin.org/articles/10.3389/fcimb.2022.1071972/full
# Authors:
#   - Jianjun Tan: 北京工业大学
# --------------------------------------------------------------------------------
# Title: Prediction of plant lncRNA by ensemble machine learning classifiers
# Abstract: Multiple machine learning approaches to lncRNA prediction were compared to  machine  learning based tool for lncRNA prediction, we have used only empirically validated lncRNAs
# Year: 2018
# URL: https://link.springer.com/article/10.1186/s12864-018-4665-2
# Authors:
#   - Caitlin Simopoulos: Roche
# --------------------------------------------------------------------------------
# Title: Machine learning-based integration develops an immune-derived lncRNA signature for improving outcomes in colorectal cancer
# Abstract: related lncRNAs remains largely unexplored. In this study, we develope a machine  learning-based integrative procedure for constructing a consensus immune-related lncRNA
# Year: 2022
# URL: https://www.nature.com/articles/s41467-022-28421-6
# Authors:
# --------------------------------------------------------------------------------
# Title: Integrative analysis from multi-center studies identities a consensus machine learning-derived lncRNA signature for stage II/III colorectal cancer
# Abstract: We comprehensively identified 27 stably recurrence-related lncRNAs from multi-center  cohorts. According to these lncRNAs, a consensus machine learning-derived lncRNA signature (
# Year: 2022
# URL: https://www.thelancet.com/journals/ebiom/article/PIIS2352-3964(21)00544-2/fulltext
# Authors:
# --------------------------------------------------------------------------------
# Title: Development of a machine learning-based autophagy-related lncRNA signature to improve prognosis prediction in osteosarcoma patients
# Abstract: machine learning algorithms to establish an autophagy-related long non-coding RNA (lncRNA  (HADb) and identified autophagy-related lncRNAs by co-expression analyses. Gene
# Year: 2021
# URL: https://www.frontiersin.org/articles/10.3389/fmolb.2021.615084/full
# Authors:
# --------------------------------------------------------------------------------
# Title: Long non-coding RNA and RNA-binding protein interactions in cancer: experimental and machine learning approaches
# Abstract: interplay between lncRNAs and  lncRNAs and RBPs interact and exert their biological  functions. In addition, current state-of-the-art knowledge, facilitated by machine and deep learning
# Year: 2022
# URL: https://www.sciencedirect.com/science/article/pii/S1044579X22001249
# Authors:
#   - Hibah Shaath: Hamad Bin Khalifa University
#   - Vishnubalaji radhakrishnan: HBKU-QBRI, Qatar Foundation
#   - Ramesh Elango: QBRI, Hamad bin Khalifa University
# --------------------------------------------------------------------------------
# Title: A four-methylated LncRNA signature predicts survival of osteosarcoma patients based on machine learning
# Abstract: In order to identify the optimal prognostic signature for methylation regulated lncRNAs, we   methylation-regulated lncRNAs to screen out methylation-regulated lncRNAs related to OS
# Year: 2021
# URL: https://www.sciencedirect.com/science/article/pii/S0888754320319698
# Authors:
#   - Qiqi Xie: IUB
# --------------------------------------------------------------------------------
# Title: Developing a prognostic model using machine learning for disulfidptosis related lncRNA in lung adenocarcinoma
# Abstract: Leveraging these lncRNAs, we constructed a predictive model employing an ensemble of  machine learning techniques, with the ensemble model (Supplementary Table 2) achieving a
# Year: 2024
# URL: https://www.nature.com/articles/s41598-024-63949-1
# Authors:
# --------------------------------------------------------------------------------

# %%
for paper in papers:
    print(f"Title: {paper['title']}")
#    print(f"Abstract: {paper['abstract']}")
#    print(f"Year: {paper['year']}")
#    print(f"URL: {paper['url']}")
    print("Authors:")
    for author in paper["authors"]:
        organizations = extract_organizations(author['affiliation'])
        org = ""
        if len(organizations) > 0:
            org = organizations[0]
            
        print(f"  - {author['name']}: {author['affiliation']}: {organizations}")
        #print(f"  - {author['name']}: {org}")
    print("-" * 80)
# Out:
# Title: Predicting lncRNA-protein interactions by machine learning methods: a review
# Authors:
#   - Zhi-Ping Liu: Professor of Biomedical Informatics, Shandong University: ['Biomedical Informatics', 'Shandong University']
# --------------------------------------------------------------------------------
# Title: Recent advances in predicting protein-lncRNA interactions using machine learning methods
# Authors:
#   - Pufeng Du: Tianjin University; Tsinghua University; City University of Hong Kong: ['Tianjin University', 'Tsinghua University', 'City University of Hong Kong']
# --------------------------------------------------------------------------------
# Title: Recent advances in machine learning methods for predicting LncRNA and disease associations
# Authors:
#   - Jianjun Tan: 北京工业大学: []
# --------------------------------------------------------------------------------
# Title: Prediction of plant lncRNA by ensemble machine learning classifiers
# Authors:
#   - Caitlin Simopoulos: Roche: ['Roche']
# --------------------------------------------------------------------------------
# Title: Machine learning-based integration develops an immune-derived lncRNA signature for improving outcomes in colorectal cancer
# Authors:
# --------------------------------------------------------------------------------
# Title: Integrative analysis from multi-center studies identities a consensus machine learning-derived lncRNA signature for stage II/III colorectal cancer
# Authors:
# --------------------------------------------------------------------------------
# Title: Development of a machine learning-based autophagy-related lncRNA signature to improve prognosis prediction in osteosarcoma patients
# Authors:
# --------------------------------------------------------------------------------
# Title: Long non-coding RNA and RNA-binding protein interactions in cancer: experimental and machine learning approaches
# Authors:
#   - Hibah Shaath: Hamad Bin Khalifa University: []
#   - Vishnubalaji radhakrishnan: HBKU-QBRI, Qatar Foundation: ['Qatar Foundation']
#   - Ramesh Elango: QBRI, Hamad bin Khalifa University: []
# --------------------------------------------------------------------------------
# Title: A four-methylated LncRNA signature predicts survival of osteosarcoma patients based on machine learning
# Authors:
#   - Qiqi Xie: IUB: ['IUB']
# --------------------------------------------------------------------------------
# Title: Developing a prognostic model using machine learning for disulfidptosis related lncRNA in lung adenocarcinoma
# Authors:
# --------------------------------------------------------------------------------

# %%
import geopandas as gpd
import folium
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="lncRNA-map")

# %%
geolocator.geocode("IUB")
# Out:
# Location(Iub, Dollo, ሶማሌ ክልል / Somali, ኢትዮጵያ, (8.23333, 45.68333, 0.0))

# %%
author
# Out:
# {'name': 'Zhi-Ping Liu',
#  'affiliation': 'Professor of Biomedical Informatics, Shandong University'}

# %%
import geopandas as gpd
import folium
from geopy.geocoders import Nominatim

def geocode_affiliations(papers):
    geolocator = Nominatim(user_agent="lncRNA-map")
    locations = []

    for paper in papers:
        for author in paper["authors"]:
            affiliation = author.get("affiliation")
            if affiliation and affiliation != "Unknown":
                location = geolocator.geocode(affiliation)
                if location:
                    locations.append({
                        "paper_title": paper["title"],
                        "author_name": author["name"],
                        "affiliation": affiliation,
                        "latitude": location.latitude,
                        "longitude": location.longitude
                    })
    return locations

def plot_affiliations(locations):
    # Create a map
    affiliation_map = folium.Map(location=[0, 0], zoom_start=2)
    
    for loc in locations:
        folium.Marker(
            [loc["latitude"], loc["longitude"]],
            popup=f"{loc['author_name']} ({loc['affiliation']})<br>{loc['paper_title']}"
        ).add_to(affiliation_map)
    
    return affiliation_map

# Example usage
locations = geocode_affiliations(papers)
map_object = plot_affiliations(locations)
map_object.save("affiliations_map.html")  # Save to an HTML file

# %%
geolocator.geocode("Shandong University")
# Out:
# Location(山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市, 山东省, 266200, 中国, (36.36553935, 120.68458591160784, 0.0))

# %%
geolocator.geocode("Professor of Biomedical Informatics, Shandong University")

# %% [markdown]
# TODO:
#
# Need to extract the named entity of organization/university from the affilication field

# %%
import arxiv

def search_papers_arxiv(query, limit=20):
    """
    Search for papers on arXiv based on a query using the updated Client.results method.
    
    Args:
        query (str): Search query for arXiv (e.g., "Machine Learning lncRNA").
        limit (int): Maximum number of results to retrieve.
    
    Returns:
        List[Dict]: A list of dictionaries containing paper metadata.
    """
    client = arxiv.Client(
        page_size=limit  # Defines the number of results per API call
    )
    search = arxiv.Search(
        query=query,
        max_results=limit,
        sort_by=arxiv.SortCriterion.Relevance
    )
    
    papers = []
    for result in client.results(search):
        papers.append({
            "title": result.title,
            "abstract": result.summary,
            "institution": result.authors[0].affiliation if result.authors and result.authors[0].affiliation else "Unknown",
            "year": result.published.year,
            "url": result.entry_id
        })
    
    return papers

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
model_keywords = ["SVM", "Random Forest", "Neural Network", "Deep Learning", "Gradient Boosting"]

def categorize_papers(papers):
    for paper in papers:
        doc = nlp(paper["abstract"])
        paper["ml_model"] = [
            keyword for keyword in model_keywords if keyword in doc.text
        ]
    return papers

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="geoapi")

def geocode_institution(papers):
    for paper in papers:
        location = geolocator.geocode(paper["institution"])
        if location:
            paper["latitude"] = location.latitude
            paper["longitude"] = location.longitude
    return papers

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

def create_geodataframe(papers):
    df = pd.DataFrame(papers)
    geometry = [Point(xy) for xy in zip(df["longitude"], df["latitude"])]
    gdf = gpd.GeoDataFrame(df, geometry=geometry)
    return gdf

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

def plot_papers_on_map(gdf):
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    ax = world.plot(color="white", edgecolor="black")
    gdf.plot(ax=ax, color="red", markersize=5)
    plt.show()

# %% [raw]
# def main():
#     query = "Machine Learning lncRNA"
#     papers = search_papers(query, limit=50)
#     papers = categorize_papers(papers)
#     papers = geocode_institution(papers)
#     gdf = create_geodataframe(papers)
#     plot_papers_on_map(gdf)
#
# if __name__ == "__main__":
#     main()

# %%
query = "Machine Learning lncRNA"

# %%
papers = search_papers(query, limit=50)

# %%
papers = categorize_papers(papers)

# %% [raw]
# papers = geocode_institution(papers)

# %% [raw]
# df = pd.DataFrame(papers)

# %% [raw]
# df.columns

# %% [raw]
# dir(papers[0]['institution'])

# %% [raw]
# type(papers[0]['institution'].value)

# %%
query = "Machine Learning lncRNA"
papers = search_papers_arxiv(query, limit=10)
for paper in papers:
    print(f"Title: {paper['title']}")
    print(f"Abstract: {paper['abstract']}")
    print(f"Institution: {paper['institution']}")
    print(f"Year: {paper['year']}")
    print(f"URL: {paper['url']}")
    print("-" * 80)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 query = "Machine Learning lncRNA"
# ----> 2 papers = search_papers_arxiv(query, limit=10)
#       3 for paper in papers:
#       4     print(f"Title: {paper['title']}")
#
# Cell In[9], line 28, in search_papers_arxiv(query, limit)
#      23 papers = []
#      24 for result in client.results(search):
#      25     papers.append({
#      26         "title": result.title,
#      27         "abstract": result.summary,
# ---> 28         "institution": result.authors[0].affiliation if result.authors and result.authors[0].affiliation else "Unknown",
#      29         "year": result.published.year,
#      30         "url": result.entry_id
#      31     })
#      33 return papers
#
# AttributeError: 'Author' object has no attribute 'affiliation'
