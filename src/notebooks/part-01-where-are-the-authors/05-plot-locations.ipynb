# %%
import numpy as np
import pandas as pd
import pickle
import time
from scholarly import scholarly
import folium
import spacy

import seaborn as sns
import matplotlib.pyplot as plt

import json

import urllib.parse

# %%
DATA_FOLDER = '../../../data/'

# %% [markdown]
# # Plot Organizations

# %%
author_organizations_df = pd.read_parquet(f'{DATA_FOLDER}author_organizations.parquet')

# %%
author_organizations_df
# Out:
#         author_id                           organization
# 0    zkBXb_kAAAAJ                 Biomedical Informatics
# 1    zkBXb_kAAAAJ                    Shandong University
# 2    EHvA-IUAAAAJ                     Tianjin University
# 3    EHvA-IUAAAAJ                    Tsinghua University
# 4    EHvA-IUAAAAJ           City University of Hong Kong
# ..            ...                                    ...
# 111  1wloHDIAAAAJ           City University of Hong Kong
# 112  Tc_U_9YAAAAJ                             Amazon.com
# 113  jV50Ks8AAAAJ  Biostatistics, University of Michigan
# 114  QVJvfz8AAAAJ        Computer Science and Engineeing
# 115  BP702PgAAAAJ                      Monash University
#
# [116 rows x 2 columns]

# %%
organizations_df = pd.read_pickle(f'{DATA_FOLDER}organizations_with_location.pickle')

# %%
organizations_df
# Out:
#                               organization  \
# 0                   Biomedical Informatics
# 1                      Shandong University
# 2                       Tianjin University
# 3                      Tsinghua University
# 4             City University of Hong Kong
# ..                                     ...
# 105                         Data Scientist
# 106                             Amazon.com
# 107  Biostatistics, University of Michigan
# 108        Computer Science and Engineeing
# 109                      Monash University
#
#                                               location
# 0    (Health & Biomedical Informatics Centre, 202-2...
# 1    (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...
# 2    (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...
# 3    (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...
# 4    (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# ..                                                 ...
# 105                                               None
# 106  (Amazon.com Doppler, 2021, 7th Avenue, Central...
# 107                                               None
# 108                                               None
# 109  (Monash University, Mile Lane, International H...
#
# [110 rows x 2 columns]

# %% [markdown]
# ## Inspect organizations where the location is missing

# %%
sum(organizations_df['location'].isna())
# Out:
# 31

# %%
organizations_df[organizations_df['location'].isna()]
# Out:
#                                           organization location
# 11                                    GrainGenes / Adj     None
# 15                 College of  Mechanics and Materials     None
# 17                       Bioinformatics Research Group     None
# 19    zhujiang hospital of southern medical university     None
# 22                               Department of Thyroid     None
# 28   Obstetrics and Gynecology Hospital of Fudan Un...     None
# 30       University of Science and Technology Liaoning     None
# 31   Shanghai University of Medicine and Health Sci...     None
# 33                    Biochemistry, Clemson University     None
# 36                            Central South University     None
# 39   Department of Computer Science, Old Dominion U...     None
# 47      Computer Engineering & Artificial Intelligence     None
# 52   City University of Hong Kong - BWH/Harvard Med...     None
# 68   School of Computing Technologies, RMIT University     None
# 70                             Lecturer, IT Department     None
# 72                 Bioinformatics, Zhejiang University     None
# 74                           UMass Chan Medical School     None
# 75   Medicine, University of Massachusetts Medical ...     None
# 77    Department of Genomics and Computational Biology     None
# 80                        Cardiovascular Research Unit     None
# 81                      Luxembourg Institute of Health     None
# 82   Royan Institute/Shahid Beheshti University of ...     None
# 83   Immunology Department School of Medicine Tehra...     None
# 85                             PhD Biological Sciences     None
# 88                International University of Sarajevo     None
# 89    College of Bioinformatics Science and Technology     None
# 98      Bioinformatics/Computational Physics/Chemistry     None
# 100                                     MSA University     None
# 105                                     Data Scientist     None
# 107              Biostatistics, University of Michigan     None
# 108                    Computer Science and Engineeing     None

# %% [markdown]
# The records without a location can be summarised into three groups:

# %% [markdown]
# 1. Records that are not organizations e.g. Data Scientist

# %% [markdown]
# 2. Records which are departments e.g. Computer Science and Engineeing

# %% [markdown]
# 3. Record that contains both the department and organization e.g. Biostatistics, University of Michigan

# %% [markdown]
# At this stage the records with missing locations will be dropped, adding data cleaning further up the processing pipeline will address this in the future

# %%
organizations_df.dropna(subset=['location'], inplace=True)

# %% [markdown]
# ## Plot organizations

# %%
def plot_organizations(organizations, locations):
    # Create a map
    affiliation_map = folium.Map(location=[0, 0], zoom_start=2)
    
    for org, loc in zip(organizations, locations):
        folium.Marker(
            [loc.latitude, loc.longitude],
            popup=f'<details><summary>{org}</summary><p>{loc.address}</p></details>'
        ).add_to(affiliation_map)
    
    return affiliation_map

# %%
map_object = plot_organizations(organizations_df.organization.values, organizations_df.location.values)
map_object.save('organizations_map.html')  # Save to an HTML file

# %%
map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0273a9fe3b731bc500e492387c19c51a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0273a9fe3b731bc500e492387c19c51a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0273a9fe3b731bc500e492387c19c51a = L.map(
#                 &quot;map_0273a9fe3b731bc500e492387c19c51a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_214fb94691b5b99fb50df43797eb6989 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_214fb94691b5b99fb50df43797eb6989.addTo(map_0273a9fe3b731bc500e492387c19c51a);
#
#
#             var marker_de029ab8c668b1db5d62954c10a643e3 = L.marker(
#                 [-37.8006938, 144.9588263],
#                 {
# }
#             ).addTo(map_0273a9fe3b731bc500e492387c19c51a);
#
#
#         var popup_98e39838723b2f33fba21c083f32f53c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1225b56f2af4cfc86291c33b85c0c613 = $(`&lt;div id=&quot;html_1225b56f2af4cfc86291c33b85c0c613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Biomedical Informatics&lt;/summary&gt;&lt;p&gt;Health &amp; Biomedical Informatics Centre, 202-206, Berkeley Street, Carlton, Melbourne, City of Melbourne, Victoria, 3053, Australia&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_98e39838723b2f33fba21c083f32f53c.setContent(html_1225b56f2af4cfc86291c33b85c0c613);
#
#
#
#         marker_de029ab8c668b1db5d62954c10a643e3.bindPopup(popup_98e39838723b2f33fba21c083f32f53c)
#         ;
#
#
#
#
#             var marker_10d00862ac7339ad897eff32f80c1b7b = L.marker(
#                 [36.36553935, 120.68458591160784],
#                 {
# }
#             ).addTo(map_0273a9fe3b731bc500e492387c19c51a);
#
#
#         var popup_5f764d242f917ecdcc18991691139d05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f008adc26d1cb428e1b10a0e835e31b = $(`&lt;div id=&quot;html_9f008adc26d1cb428e1b10a0e835e31b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Shandong University&lt;/summary&gt;&lt;p&gt;山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市, 山东省, 266200, 中国&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_5f764d242f917ecdcc18991691139d05.setContent(html_9f008adc26d1cb428e1b10a0e835e31b);
#
#
#
#         marker_10d00862ac7339ad897eff32f80c1b7b.bindPopup(popup_5f764d242f917ecdcc18991691139d05)
#         ;
#
#
#
#
#             var marker_9c17dcaeb7b673b1041fc318ac3b97a5 = L.marker(
#                 [39.107253299999996, 117.17789778037583],
#                 {
# }
#             ).addTo(map_0273a9fe3b731bc500e492387c19c51a);
#
#
#         var popup_746a73f66391856a40d64479dffafdf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1740101418df1f64abcac83ee536c78a = $(`&lt;div id=&quot;html_1740101418df1f64abcac83ee536c78a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Tianjin University&lt;/summary&gt;&lt;p&gt;天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 300051, 中国&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_746a73f66391856a40d64479dffafdf9.setContent(html_1740101418df1f64abcac83ee536c78a);
#
#
#
#         marker_9c17dcaeb7b673b1041fc318ac3b97a5.bindPopup(popup_746a73f66391856a40d64479dffafdf9)
#         ;
#
#
#
#
#             var marker_eeb65da01b4ec541397efc4d0a852d4f = L.marker(
#                 [40.002290450000004, 116.3209629696906],
#                 {
# }
#             ).addTo(map_0273a9fe3b731bc500e492387c19c51a);
#
#
#         var popup_c27393b5cf6bd5203677aa0f99d9d1a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c29c1940dce7f84ce4455b72a77a591d = $(`&lt;div id=&quot;html_c29c1940dce7f84ce4455b72a77a591d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Tsinghua University&lt;/summary&gt;&lt;p&gt;清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_c27393b5cf6bd5203677aa0f99d9d1a2.setContent(html_c29c1940dce7f84ce4455b72a77a591d);
#
#
#
#         marker_eeb65da01b4ec541397efc4d0a852d4f.bindPopup(popup_c27393b5cf6bd5203677aa0f99d9d1a2)
#         ;
#
#
#
#
#             var marker_2affbc9ae3e5d830c8ccb3dfbe38a740 = L.marker(
#                 [22.3400204, 114.16971664362887],
#                 {
# }
#             ).addTo(map_0273a9fe3b731bc500e492387c19c51a);
#
#
#         var popup_7f426f354045c0091d3

# %% [markdown]
# ## Plot organizations and show authors

# %%
author_organizations_df = pd.read_parquet(f'{DATA_FOLDER}author_organizations.parquet')

# %%
author_organizations_df
# Out:
#         author_id                           organization
# 0    zkBXb_kAAAAJ                 Biomedical Informatics
# 1    zkBXb_kAAAAJ                    Shandong University
# 2    EHvA-IUAAAAJ                     Tianjin University
# 3    EHvA-IUAAAAJ                    Tsinghua University
# 4    EHvA-IUAAAAJ           City University of Hong Kong
# ..            ...                                    ...
# 111  1wloHDIAAAAJ           City University of Hong Kong
# 112  Tc_U_9YAAAAJ                             Amazon.com
# 113  jV50Ks8AAAAJ  Biostatistics, University of Michigan
# 114  QVJvfz8AAAAJ        Computer Science and Engineeing
# 115  BP702PgAAAAJ                      Monash University
#
# [116 rows x 2 columns]

# %%
# inner join
merged_df = pd.merge(organizations_df, author_organizations_df, on='organization', how='inner')

# %%
merged_df
# Out:
#                     organization  \
# 0         Biomedical Informatics
# 1            Shandong University
# 2             Tianjin University
# 3            Tsinghua University
# 4   City University of Hong Kong
# ..                           ...
# 79        Sun Yat-sen University
# 80              jilin university
# 81                        Amazon
# 82                    Amazon.com
# 83             Monash University
#
#                                              location     author_id
# 0   (Health & Biomedical Informatics Centre, 202-2...  zkBXb_kAAAAJ
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...  zkBXb_kAAAAJ
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...  EHvA-IUAAAAJ
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...  EHvA-IUAAAAJ
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...  EHvA-IUAAAAJ
# ..                                                ...           ...
# 79  (中山大学广州校区南校园, 135, 新港西路, 旧凤凰, 新港街道, 海珠区, 广州市, ...  pu5CdXoAAAAJ
# 80  (吉林大学（朝阳校区）, 西朝阳南胡同, 清和街道, 朝阳区, 长春市, 绿园区, 吉林省,...  MeSogXgAAAAJ
# 81  (Amazon, Careiro da Várzea, Região Geográfica ...  7PVmb8MAAAAJ
# 82  (Amazon.com Doppler, 2021, 7th Avenue, Central...  Tc_U_9YAAAAJ
# 83  (Monash University, Mile Lane, International H...  BP702PgAAAAJ
#
# [84 rows x 3 columns]

# %%
with open(f'{DATA_FOLDER}authors.pickle', 'rb') as handle:
    authors = pickle.load(handle)

# %%
authors_df = pd.DataFrame(authors)

# %%
authors_df
# Out:
#         author_id                                  name  \
# 0    zkBXb_kAAAAJ                          Zhi-Ping Liu
# 1    EHvA-IUAAAAJ                             Pufeng Du
# 2    5RoxYhkAAAAJ                           Jianjun Tan
# 3    ap3FfWEAAAAJ                    Caitlin Simopoulos
# 4    uxiJL_cAAAAJ                          Hibah Shaath
# ..            ...                                   ...
# 104  jV50Ks8AAAAJ                           Zongrui Dai
# 105  clJGV9UAAAAJ                  Marwa  Matboli Sayed
# 106  AEaAOCQAAAAJ                      Faroza Shamsheem
# 107  QVJvfz8AAAAJ  TUNGA ARUNDHATHI Assistant Professor
# 108  BP702PgAAAAJ                Yashpal Ramakrishnaiah
#
#                                            affiliation
# 0    Professor of Biomedical Informatics, Shandong ...
# 1    Tianjin University; Tsinghua University; City ...
# 2                                               北京工业大学
# 3                                                Roche
# 4                         Hamad Bin Khalifa University
# ..                                                 ...
# 104  Master Student in Biostatistics, University of...
# 105  Professor of medical biochemistry and molecula...
# 106                                Assistant professor
# 107  Assistant Professor in Computer Science and En...
# 108                Research Student, Monash University
#
# [109 rows x 3 columns]

# %%
merged_df = pd.merge(merged_df, authors_df, on='author_id', how='inner')

# %%
merged_df
# Out:
#                     organization  \
# 0         Biomedical Informatics
# 1            Shandong University
# 2             Tianjin University
# 3            Tsinghua University
# 4   City University of Hong Kong
# ..                           ...
# 79        Sun Yat-sen University
# 80              jilin university
# 81                        Amazon
# 82                    Amazon.com
# 83             Monash University
#
#                                              location     author_id  \
# 0   (Health & Biomedical Informatics Centre, 202-2...  zkBXb_kAAAAJ
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...  zkBXb_kAAAAJ
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...  EHvA-IUAAAAJ
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...  EHvA-IUAAAAJ
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...  EHvA-IUAAAAJ
# ..                                                ...           ...
# 79  (中山大学广州校区南校园, 135, 新港西路, 旧凤凰, 新港街道, 海珠区, 广州市, ...  pu5CdXoAAAAJ
# 80  (吉林大学（朝阳校区）, 西朝阳南胡同, 清和街道, 朝阳区, 长春市, 绿园区, 吉林省,...  MeSogXgAAAAJ
# 81  (Amazon, Careiro da Várzea, Região Geográfica ...  7PVmb8MAAAAJ
# 82  (Amazon.com Doppler, 2021, 7th Avenue, Central...  Tc_U_9YAAAAJ
# 83  (Monash University, Mile Lane, International H...  BP702PgAAAAJ
#
#                       name                                        affiliation
# 0             Zhi-Ping Liu  Professor of Biomedical Informatics, Shandong ...
# 1             Zhi-Ping Liu  Professor of Biomedical Informatics, Shandong ...
# 2                Pufeng Du  Tianjin University; Tsinghua University; City ...
# 3                Pufeng Du  Tianjin University; Tsinghua University; City ...
# 4                Pufeng Du  Tianjin University; Tsinghua University; City ...
# ..                     ...                                                ...
# 79              Yunfang Yu  Sun Yat-sen Memorial Hospital, Sun Yat-sen Uni...
# 80          Nan Sheng (盛楠)                                   jilin university
# 81   Rujira Achawanantakun                         Research Scientist, Amazon
# 82              Yuan Zhang              Applied Science Manager at Amazon.com
# 83  Yashpal Ramakrishnaiah                Research Student, Monash University
#
# [84 rows x 5 columns]

# %%
merged_df.rename(columns={'name': 'author_name'}, inplace=True)

# %%
organization_author_df = merged_df[['organization', 'author_id', 'author_name']].drop_duplicates()

# %%
def plot_organizations_authors(organizations, locations):
    # Create a map
    m = folium.Map(location=[0, 0], zoom_start=2)
    
    for org, loc in zip(organizations, locations):
        authors = organization_author_df.query(f'organization == "{org}"')['author_name'].values
        authors_html = ""
        for auth in authors:
            authors_html += f'{auth}<br>'
        
        folium.Marker(
            [loc.latitude, loc.longitude],
            popup=f'<details><summary>{org}</summary><p>{authors_html}</p></details>'
        ).add_to(m)
    
    return m

# %%
map_object  = plot_organizations_authors(organizations_df.organization.values, organizations_df.location.values)

# %%
map_object.save('organizations_authors_map.html')  # Save to an HTML file

# %%
map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a21e35f1abf7b7ab4c043457c455c1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a21e35f1abf7b7ab4c043457c455c1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a21e35f1abf7b7ab4c043457c455c1f = L.map(
#                 &quot;map_3a21e35f1abf7b7ab4c043457c455c1f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe7710346fe702bc53324a3cec814c22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe7710346fe702bc53324a3cec814c22.addTo(map_3a21e35f1abf7b7ab4c043457c455c1f);
#
#
#             var marker_ca0894ed9fbfa38ea8024fa702f5d312 = L.marker(
#                 [-37.8006938, 144.9588263],
#                 {
# }
#             ).addTo(map_3a21e35f1abf7b7ab4c043457c455c1f);
#
#
#         var popup_7bddb227cffc5f8f4749c20286ac4fcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb900db09f056aa03fb102e5927268b5 = $(`&lt;div id=&quot;html_eb900db09f056aa03fb102e5927268b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Biomedical Informatics&lt;/summary&gt;&lt;p&gt;Zhi-Ping Liu&lt;br&gt;&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_7bddb227cffc5f8f4749c20286ac4fcd.setContent(html_eb900db09f056aa03fb102e5927268b5);
#
#
#
#         marker_ca0894ed9fbfa38ea8024fa702f5d312.bindPopup(popup_7bddb227cffc5f8f4749c20286ac4fcd)
#         ;
#
#
#
#
#             var marker_4c393bff635f6873672ea5748300ac40 = L.marker(
#                 [36.36553935, 120.68458591160784],
#                 {
# }
#             ).addTo(map_3a21e35f1abf7b7ab4c043457c455c1f);
#
#
#         var popup_d65527169de82b644e34d9db7d2748e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd47a6f8cdd87d9e98aa72de2f965642 = $(`&lt;div id=&quot;html_bd47a6f8cdd87d9e98aa72de2f965642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Shandong University&lt;/summary&gt;&lt;p&gt;Zhi-Ping Liu&lt;br&gt;&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_d65527169de82b644e34d9db7d2748e7.setContent(html_bd47a6f8cdd87d9e98aa72de2f965642);
#
#
#
#         marker_4c393bff635f6873672ea5748300ac40.bindPopup(popup_d65527169de82b644e34d9db7d2748e7)
#         ;
#
#
#
#
#             var marker_2a1b5406bd56a497500dd57d49c25510 = L.marker(
#                 [39.107253299999996, 117.17789778037583],
#                 {
# }
#             ).addTo(map_3a21e35f1abf7b7ab4c043457c455c1f);
#
#
#         var popup_0d4b1c886ca88415caf62357452ec898 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85267b4734bd8cfb289fd6cd446bdfb5 = $(`&lt;div id=&quot;html_85267b4734bd8cfb289fd6cd446bdfb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Tianjin University&lt;/summary&gt;&lt;p&gt;Pufeng Du&lt;br&gt;&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_0d4b1c886ca88415caf62357452ec898.setContent(html_85267b4734bd8cfb289fd6cd446bdfb5);
#
#
#
#         marker_2a1b5406bd56a497500dd57d49c25510.bindPopup(popup_0d4b1c886ca88415caf62357452ec898)
#         ;
#
#
#
#
#             var marker_e142f8c91bc5722d7bf9ca4367194b67 = L.marker(
#                 [40.002290450000004, 116.3209629696906],
#                 {
# }
#             ).addTo(map_3a21e35f1abf7b7ab4c043457c455c1f);
#
#
#         var popup_d3df79c7a404232a32c729a8daee95e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d02a8e2aa4257791b56d98a651b8b5fa = $(`&lt;div id=&quot;html_d02a8e2aa4257791b56d98a651b8b5fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Tsinghua University&lt;/summary&gt;&lt;p&gt;Pufeng Du&lt;br&gt;&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_d3df79c7a404232a32c729a8daee95e5.setContent(html_d02a8e2aa4257791b56d98a651b8b5fa);
#
#
#
#         marker_e142f8c91bc5722d7bf9ca4367194b67.bindPopup(popup_d3df79c7a404232a32c729a8daee95e5)
#         ;
#
#
#
#
#             var marker_09ada7e62dc3e304f87033efd58a9c50 = L.marker(
#                 [22.3400204, 114.16971664362887],
#                 {
# }
#             ).addTo(map_3a21e35f1abf7b7ab4c043457c455c1f);
#
#
#         var popup_000e769a22d6a76145092510dfff3bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_593f9cb09cac70d10c932d3bddc9e6f3 = $(`&lt;div id=&quot;html_593f9cb09cac70d10c932d3b

# %% [markdown]
# ## Plot organizations and show papers

# %%
with open(f'{DATA_FOLDER}papers.pickle', 'rb') as handle:
    papers = pickle.load(handle)

# %%
papers_df = pd.DataFrame(papers)

# %%
papers_df
# Out:
#                                                 title  \
# 0   Predicting lncRNA-protein interactions by mach...
# 1   Recent advances in predicting protein-lncRNA i...
# 2   Recent advances in machine learning methods fo...
# 3   Prediction of plant lncRNA by ensemble machine...
# 4   Machine learning-based integration develops an...
# ..                                                ...
# 95  Machine-Learning-Based identification of key f...
# 96  Prediction of ncRNA from RNA-Seq data using ma...
# 97  A classification model for lncRNA and mRNA bas...
# 98  Integrating multiple machine learning algorith...
# 99  Linc2function: A Comprehensive Pipeline and We...
#
#                                              abstract  year  \
# 0   Here, we aim to provide a review of machine-le...  2020
# 1   classified into the deep learning-based method...  2022
# 2   machine learning prediction models of LDAs. Fi...  2022
# 3   Multiple machine learning approaches to lncRNA...  2018
# 4   related lncRNAs remains largely unexplored. In...  2022
# ..                                                ...   ...
# 95  330500) was used to assess the differential ex...  2024
# 96  ncRNAs or lncRNAs. By classifying coding and l...  2023
# 97  For these four machine learning algorithms, we...  2019
# 98  from TCGA-STAD, we identified 26 prognostic ln...  2023
# 99  We propose that understanding the mechanisms o...  2023
#
#                                                   url  \
# 0                                             Unknown
# 1                                             Unknown
# 2   https://www.frontiersin.org/articles/10.3389/f...
# 3   https://link.springer.com/article/10.1186/s128...
# 4   https://www.nature.com/articles/s41467-022-284...
# ..                                                ...
# 95                                            Unknown
# 96                                            Unknown
# 97  https://link.springer.com/article/10.1186/s128...
# 98  https://www.frontiersin.org/articles/10.3389/f...
# 99              https://www.mdpi.com/2075-4655/7/3/22
#
#                            author_id
# 0                     [zkBXb_kAAAAJ]
# 1               [, , , EHvA-IUAAAAJ]
# 2               [5RoxYhkAAAAJ, , , ]
# 3                 [ap3FfWEAAAAJ, , ]
# 4                       [, , , , , ]
# ..                               ...
# 95              [clJGV9UAAAAJ, , , ]
# 96      [AEaAOCQAAAAJ, QVJvfz8AAAAJ]
# 97                      [, , , , , ]
# 98                    [, , , , , , ]
# 99  [BP702PgAAAAJ, , , Bew0NN8AAAAJ]
#
# [100 rows x 5 columns]

# %% [markdown]
# author_id is a list in papers_df so we generate a author to paper map

# %%
def generate_author_paper_map(titles, author_ids):
    title_lst = list()
    author_id_lst = list()
    for title, authors in zip(titles, author_ids):        
        if not all('' == s or s.isspace() for s in authors): # list does not contains only empty values
            for auth in authors:
                if auth != "":
                    title_lst.append(title)
                    author_id_lst.append(auth)

    data = {
        'title': title_lst,
        'author_id': author_id_lst
    }
    
    return pd.DataFrame.from_dict(data)

# %%
author_paper_df = generate_author_paper_map(papers_df['title'].values, papers_df['author_id'].values)

# %%
author_paper_df
# Out:
#                                                  title     author_id
# 0    Predicting lncRNA-protein interactions by mach...  zkBXb_kAAAAJ
# 1    Recent advances in predicting protein-lncRNA i...  EHvA-IUAAAAJ
# 2    Recent advances in machine learning methods fo...  5RoxYhkAAAAJ
# 3    Prediction of plant lncRNA by ensemble machine...  ap3FfWEAAAAJ
# 4    Long non-coding RNA and RNA-binding protein in...  uxiJL_cAAAAJ
# ..                                                 ...           ...
# 112  Machine-Learning-Based identification of key f...  clJGV9UAAAAJ
# 113  Prediction of ncRNA from RNA-Seq data using ma...  AEaAOCQAAAAJ
# 114  Prediction of ncRNA from RNA-Seq data using ma...  QVJvfz8AAAAJ
# 115  Linc2function: A Comprehensive Pipeline and We...  BP702PgAAAAJ
# 116  Linc2function: A Comprehensive Pipeline and We...  Bew0NN8AAAAJ
#
# [117 rows x 2 columns]

# %% [markdown]
# Check for duplicates

# %%
sum(author_paper_df.duplicated())
# Out:
# 0

# %% [markdown]
# Good there aren't any

# %%
organization_author_df
# Out:
#                     organization     author_id             author_name
# 0         Biomedical Informatics  zkBXb_kAAAAJ            Zhi-Ping Liu
# 1            Shandong University  zkBXb_kAAAAJ            Zhi-Ping Liu
# 2             Tianjin University  EHvA-IUAAAAJ               Pufeng Du
# 3            Tsinghua University  EHvA-IUAAAAJ               Pufeng Du
# 4   City University of Hong Kong  EHvA-IUAAAAJ               Pufeng Du
# ..                           ...           ...                     ...
# 79        Sun Yat-sen University  pu5CdXoAAAAJ              Yunfang Yu
# 80              jilin university  MeSogXgAAAAJ          Nan Sheng (盛楠)
# 81                        Amazon  7PVmb8MAAAAJ   Rujira Achawanantakun
# 82                    Amazon.com  Tc_U_9YAAAAJ              Yuan Zhang
# 83             Monash University  BP702PgAAAAJ  Yashpal Ramakrishnaiah
#
# [84 rows x 3 columns]

# %%
def plot_organizations_papers(organizations, locations):
    # Create a map
    m = folium.Map(location=[0, 0], zoom_start=2)
    
    for org, loc in zip(organizations, locations):
        authors = organization_author_df.query(f'organization == "{org}"')['author_id'].values

        papers = list()
        for author_id in authors:
            title = author_paper_df.query(f'author_id == "{author_id}"')['title'].values[0]
            url = papers_df.query(f'title == "{title}"')['url'].values[0]
            if url == 'Unknown':
                # don't have a url for the paper so don't show a link
                encoded_title = urllib.parse.quote(title)

                # Create the full Google Scholar search URL
                search_url = f"https://scholar.google.com/scholar?q={encoded_title}"
                
                #papers = papers + [title]
                papers = papers + [f'<a href="{search_url}" target="_blank">{title}</a>']
            else:
                papers = papers + [f'<a href="{url}" target="_blank">{title}</a>']
            
            #papers = papers + author_paper_df.query(f'author_id == "{author_id}"')['title'].values.tolist()

        # drop duplicate values
        papers = list(set(papers))
        
        papers_html = ""
        for paper in papers:
            papers_html += f'{paper}<br>'
        
        folium.Marker(
            [loc.latitude, loc.longitude],
            popup=f'<details><summary>{org}</summary><p>{papers_html}</p></details>'
        ).add_to(m)
    
    return m

# %%
map_object  = plot_organizations_papers(organizations_df.organization.values, organizations_df.location.values)

# %%
map_object.save('organizations_papers_map.html')  # Save to an HTML file

# %%
map_object
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b9f2fc4903cdf7a2ea0f207db2974ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b9f2fc4903cdf7a2ea0f207db2974ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b9f2fc4903cdf7a2ea0f207db2974ca = L.map(
#                 &quot;map_9b9f2fc4903cdf7a2ea0f207db2974ca&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f1a345d39a4f573054e4d18c65639fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f1a345d39a4f573054e4d18c65639fa.addTo(map_9b9f2fc4903cdf7a2ea0f207db2974ca);
#
#
#             var marker_3854f1c3a6a5225972fc6253cad37a4b = L.marker(
#                 [-37.8006938, 144.9588263],
#                 {
# }
#             ).addTo(map_9b9f2fc4903cdf7a2ea0f207db2974ca);
#
#
#         var popup_77e85ebda7b9380853bd591f1b4d554a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd685718fab0f3073bd648095ca7d4b2 = $(`&lt;div id=&quot;html_dd685718fab0f3073bd648095ca7d4b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Biomedical Informatics&lt;/summary&gt;&lt;p&gt;&lt;a href=&quot;https://scholar.google.com/scholar?q=Predicting%20lncRNA-protein%20interactions%20by%20machine%20learning%20methods%3A%20a%20review&quot; target=&quot;_blank&quot;&gt;Predicting lncRNA-protein interactions by machine learning methods: a review&lt;/a&gt;&lt;br&gt;&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_77e85ebda7b9380853bd591f1b4d554a.setContent(html_dd685718fab0f3073bd648095ca7d4b2);
#
#
#
#         marker_3854f1c3a6a5225972fc6253cad37a4b.bindPopup(popup_77e85ebda7b9380853bd591f1b4d554a)
#         ;
#
#
#
#
#             var marker_3a434e4bcc292a198982b076958e23b7 = L.marker(
#                 [36.36553935, 120.68458591160784],
#                 {
# }
#             ).addTo(map_9b9f2fc4903cdf7a2ea0f207db2974ca);
#
#
#         var popup_75e8158a54de89a80235b56944c3a849 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34113f83c8c04e45de920d72620cdb0f = $(`&lt;div id=&quot;html_34113f83c8c04e45de920d72620cdb0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Shandong University&lt;/summary&gt;&lt;p&gt;&lt;a href=&quot;https://scholar.google.com/scholar?q=Predicting%20lncRNA-protein%20interactions%20by%20machine%20learning%20methods%3A%20a%20review&quot; target=&quot;_blank&quot;&gt;Predicting lncRNA-protein interactions by machine learning methods: a review&lt;/a&gt;&lt;br&gt;&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_75e8158a54de89a80235b56944c3a849.setContent(html_34113f83c8c04e45de920d72620cdb0f);
#
#
#
#         marker_3a434e4bcc292a198982b076958e23b7.bindPopup(popup_75e8158a54de89a80235b56944c3a849)
#         ;
#
#
#
#
#             var marker_d853f1c08e238fe40efd35026a7d1661 = L.marker(
#                 [39.107253299999996, 117.17789778037583],
#                 {
# }
#             ).addTo(map_9b9f2fc4903cdf7a2ea0f207db2974ca);
#
#
#         var popup_564066a4aff6434f1f991376e3a7c1db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23d2026a73af82a91f1781ee29a169be = $(`&lt;div id=&quot;html_23d2026a73af82a91f1781ee29a169be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Tianjin University&lt;/summary&gt;&lt;p&gt;&lt;a href=&quot;https://scholar.google.com/scholar?q=Recent%20advances%20in%20predicting%20protein-lncRNA%20interactions%20using%20machine%20learning%20methods&quot; target=&quot;_blank&quot;&gt;Recent advances in predicting protein-lncRNA interactions using machine learning methods&lt;/a&gt;&lt;br&gt;&lt;/p&gt;&lt;/details&gt;&lt;/div&gt;`)[0];
#                 popup_564066a4aff6434f1f991376e3a7c1db.setContent(html_23d2026a73af82a91f1781ee29a169be);
#
#
#
#         marker_d853f1c08e238fe40efd35026a7d1661.bindPopup(popup_564066a4aff6434f1f991376e3a7c1db)
#         ;
#
#
#
#
#             var marker_8ac3b39aa750d86d35df187cd66fa962 = L.marker(
#                 [40.002290450000004, 116.3209629696906],
#                 {
# }
#             ).addTo(map_9b9f2fc4903cdf7a2ea0f207db2974ca);
#
#
#         var popup_42b740977edf9e0e9a3a75a41e41d210 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_308ed0a6e2ea9f428bea6a8b5009a32b = $(`&lt;div id=&quot;html_308ed0a6e2ea9f428bea6a8b5009a32b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;details&gt;&lt;summary&gt;Tsinghua Univers

# %% [markdown]
# ## Plot papers and show similar papers

# %%
organization_author_location_df = pd.merge(organizations_df, organization_author_df, on='organization', how='inner')

# %%
organization_author_location_df
# Out:
#                     organization  \
# 0         Biomedical Informatics
# 1            Shandong University
# 2             Tianjin University
# 3            Tsinghua University
# 4   City University of Hong Kong
# ..                           ...
# 79        Sun Yat-sen University
# 80              jilin university
# 81                        Amazon
# 82                    Amazon.com
# 83             Monash University
#
#                                              location     author_id  \
# 0   (Health & Biomedical Informatics Centre, 202-2...  zkBXb_kAAAAJ
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...  zkBXb_kAAAAJ
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...  EHvA-IUAAAAJ
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...  EHvA-IUAAAAJ
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...  EHvA-IUAAAAJ
# ..                                                ...           ...
# 79  (中山大学广州校区南校园, 135, 新港西路, 旧凤凰, 新港街道, 海珠区, 广州市, ...  pu5CdXoAAAAJ
# 80  (吉林大学（朝阳校区）, 西朝阳南胡同, 清和街道, 朝阳区, 长春市, 绿园区, 吉林省,...  MeSogXgAAAAJ
# 81  (Amazon, Careiro da Várzea, Região Geográfica ...  7PVmb8MAAAAJ
# 82  (Amazon.com Doppler, 2021, 7th Avenue, Central...  Tc_U_9YAAAAJ
# 83  (Monash University, Mile Lane, International H...  BP702PgAAAAJ
#
#                author_name
# 0             Zhi-Ping Liu
# 1             Zhi-Ping Liu
# 2                Pufeng Du
# 3                Pufeng Du
# 4                Pufeng Du
# ..                     ...
# 79              Yunfang Yu
# 80          Nan Sheng (盛楠)
# 81   Rujira Achawanantakun
# 82              Yuan Zhang
# 83  Yashpal Ramakrishnaiah
#
# [84 rows x 4 columns]

# %%
organization_paper_location_df = pd.merge(author_paper_df, organization_author_location_df, on='author_id', how='inner')

# %%
organization_paper_location_df
# Out:
#                                                 title     author_id  \
# 0   Predicting lncRNA-protein interactions by mach...  zkBXb_kAAAAJ
# 1   Predicting lncRNA-protein interactions by mach...  zkBXb_kAAAAJ
# 2   Recent advances in predicting protein-lncRNA i...  EHvA-IUAAAAJ
# 3   Recent advances in predicting protein-lncRNA i...  EHvA-IUAAAAJ
# 4   Recent advances in predicting protein-lncRNA i...  EHvA-IUAAAAJ
# ..                                                ...           ...
# 87  LncRNA-ID: Long non-coding RNA IDentification ...  1wloHDIAAAAJ
# 88  LncRNA-ID: Long non-coding RNA IDentification ...  Tc_U_9YAAAAJ
# 89  PRPI-SC: an ensemble deep learning model for p...  B6LqguIAAAAJ
# 90  Linc2function: A Comprehensive Pipeline and We...  BP702PgAAAAJ
# 91  Linc2function: A Comprehensive Pipeline and We...  Bew0NN8AAAAJ
#
#                                          organization  \
# 0                              Biomedical Informatics
# 1                                 Shandong University
# 2                                  Tianjin University
# 3                                 Tsinghua University
# 4                        City University of Hong Kong
# ..                                                ...
# 87                       City University of Hong Kong
# 88                                         Amazon.com
# 89  Jomo Kenyatta University of Agriculture and Te...
# 90                                  Monash University
# 91                                               NMBU
#
#                                              location  \
# 0   (Health & Biomedical Informatics Centre, 202-2...
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# ..                                                ...
# 87  (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# 88  (Amazon.com Doppler, 2021, 7th Avenue, Central...
# 89  (Jomo Kenyatta University of Agriculture and T...
# 90  (Monash University, Mile Lane, International H...
# 91  (NMBU Christian Magnus Falsens vei, Ås, Christ...
#
#                   author_name
# 0                Zhi-Ping Liu
# 1                Zhi-Ping Liu
# 2                   Pufeng Du
# 3                   Pufeng Du
# 4                   Pufeng Du
# ..                        ...
# 87                  Yanni Sun
# 88                 Yuan Zhang
# 89  Jael Sanyanda Wekesa, PhD
# 90     Yashpal Ramakrishnaiah
# 91               Melcy Philip
#
# [92 rows x 5 columns]

# %% [markdown]
# This creates multiple records where a paper is authored by multiple people

# %% [markdown]
# To resolve this, we can drop the author related columns, that were necessary to join the paper and organization

# %%
organization_paper_location_df = organization_paper_location_df.drop(columns=['author_name', 'author_id'])

# %%
organization_paper_location_df.drop_duplicates(['title', 'organization'], inplace=True)

# %%
organization_paper_location_df
# Out:
#                                                 title  \
# 0   Predicting lncRNA-protein interactions by mach...
# 1   Predicting lncRNA-protein interactions by mach...
# 2   Recent advances in predicting protein-lncRNA i...
# 3   Recent advances in predicting protein-lncRNA i...
# 4   Recent advances in predicting protein-lncRNA i...
# ..                                                ...
# 87  LncRNA-ID: Long non-coding RNA IDentification ...
# 88  LncRNA-ID: Long non-coding RNA IDentification ...
# 89  PRPI-SC: an ensemble deep learning model for p...
# 90  Linc2function: A Comprehensive Pipeline and We...
# 91  Linc2function: A Comprehensive Pipeline and We...
#
#                                          organization  \
# 0                              Biomedical Informatics
# 1                                 Shandong University
# 2                                  Tianjin University
# 3                                 Tsinghua University
# 4                        City University of Hong Kong
# ..                                                ...
# 87                       City University of Hong Kong
# 88                                         Amazon.com
# 89  Jomo Kenyatta University of Agriculture and Te...
# 90                                  Monash University
# 91                                               NMBU
#
#                                              location
# 0   (Health & Biomedical Informatics Centre, 202-2...
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# ..                                                ...
# 87  (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# 88  (Amazon.com Doppler, 2021, 7th Avenue, Central...
# 89  (Jomo Kenyatta University of Agriculture and T...
# 90  (Monash University, Mile Lane, International H...
# 91  (NMBU Christian Magnus Falsens vei, Ås, Christ...
#
# [89 rows x 3 columns]

# %% [markdown]
# Save Organization/Paper/Location dataframe

# %%
with open(f'{DATA_FOLDER}organization_paper_location_df.pickle', 'wb') as handle:
    pickle.dump(organization_paper_location_df, handle, protocol=pickle.HIGHEST_PROTOCOL)
