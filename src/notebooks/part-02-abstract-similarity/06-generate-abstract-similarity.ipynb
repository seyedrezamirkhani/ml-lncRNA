# %%
import pickle
import spacy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import networkx as nx

# %%
DATA_FOLDER = '../../data/'

# %%
with open(f'{DATA_FOLDER}papers.pickle', 'rb') as handle:
    papers = pickle.load(handle)

# %%
papers_df = pd.DataFrame.from_dict(papers)

# %%
with open(f'{DATA_FOLDER}organization_paper_location_df.pickle', 'rb') as handle:
    organization_paper_location_df = pickle.load(handle)

# %%
organization_paper_location_df
# Out:
#                                                 title  \
# 0   Predicting lncRNA-protein interactions by mach...
# 1   Predicting lncRNA-protein interactions by mach...
# 2   Recent advances in predicting protein-lncRNA i...
# 3   Recent advances in predicting protein-lncRNA i...
# 4   Recent advances in predicting protein-lncRNA i...
# ..                                                ...
# 87  LncRNA-ID: Long non-coding RNA IDentification ...
# 88  LncRNA-ID: Long non-coding RNA IDentification ...
# 89  PRPI-SC: an ensemble deep learning model for p...
# 90  Linc2function: A Comprehensive Pipeline and We...
# 91  Linc2function: A Comprehensive Pipeline and We...
#
#                                          organization  \
# 0                              Biomedical Informatics
# 1                                 Shandong University
# 2                                  Tianjin University
# 3                                 Tsinghua University
# 4                        City University of Hong Kong
# ..                                                ...
# 87                       City University of Hong Kong
# 88                                         Amazon.com
# 89  Jomo Kenyatta University of Agriculture and Te...
# 90                                  Monash University
# 91                                               NMBU
#
#                                              location
# 0   (Health & Biomedical Informatics Centre, 202-2...
# 1   (山东大学（青岛校区）, 72, 滨海公路, 青岛蓝谷高新技术产业开发区, 即墨区, 青岛市...
# 2   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...
# 3   (清华大学, 30, 双清路, 东升镇, 海淀区, 北京市, 100084, 中国, (40...
# 4   (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# ..                                                ...
# 87  (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# 88  (Amazon.com Doppler, 2021, 7th Avenue, Central...
# 89  (Jomo Kenyatta University of Agriculture and T...
# 90  (Monash University, Mile Lane, International H...
# 91  (NMBU Christian Magnus Falsens vei, Ås, Christ...
#
# [89 rows x 3 columns]

# %%
len(organization_paper_location_df['title'])
# Out:
# 89

# %%
organization_paper_location_df['title'].nunique()
# Out:
# 46

# %% [markdown]
# We have duplicate organization/paper records. This is caused by the paper having multiple authors, those authors in turn are associated with different organizations.
#
# The duplicate records will be dropped, however this will lead to papers being associated with organization of authors which might not be the true 1st author. To resolve this, we will need to identify the 1st author of papers in previous data processing.

# %%
organization_paper_location_df.drop_duplicates(['title'], inplace=True)

# %%
organization_paper_location_abstract_df = pd.merge(organization_paper_location_df, papers_df[['title', 'abstract']], on='title', how='inner')

# %%
organization_paper_location_abstract_df = organization_paper_location_abstract_df.dropna(subset=['abstract'])  # Remove entries with missing abstracts

# %%
organization_paper_location_abstract_df
# Out:
#                                                 title  \
# 0   Predicting lncRNA-protein interactions by mach...
# 1   Recent advances in predicting protein-lncRNA i...
# 2   Prediction of plant lncRNA by ensemble machine...
# 3   Long non-coding RNA and RNA-binding protein in...
# 4   A four-methylated LncRNA signature predicts su...
# 5   LncMachine: a machine learning algorithm for l...
# 6   CRlncRC: a machine learning-based method for c...
# 7   Machine learning-based identification of tumor...
# 8   Evaluation of machine learning models that pre...
# 9   Machine learning-based construction of a ferro...
# 10  Identification and validation of cuproptosis-r...
# 11  Prediction of LncRNA subcellular localization ...
# 12  CBIL-VHPLI: a model for predicting viral-host ...
# 13  Machine learning-based tumor-infiltrating immu...
# 14  DMFLDA: a deep learning framework for predicti...
# 15  Significance of cuproptosis‐related lncRNA sig...
# 16  Deep learning approaches for lncrna-mediated m...
# 17  LncRNAnet: long non-coding RNA identification ...
# 18  Machine learning based LncRNA function prediction
# 19  LncDC: a machine learning-based tool for long ...
# 20  LncADeep: an ab initio lncRNA identification a...
# 21  Construction of Immune Infiltration-related Ln...
# 22  Computational prediction of disease related ln...
# 23  Evaluation of deep learning in non-coding RNA ...
# 24  Long noncoding RNA identification: comparing m...
# 25  Prediction of Disease–lncRNA Associations via ...
# 26  Predicting the interaction biomolecule types f...
# 27  A survey of current resources to study lncRNA-...
# 28  lncRNA-MFDL: identification of human long non-...
# 29  A hybrid prediction method for plant lncRNA-pr...
# 30  DeepLGP: a novel deep learning method for prio...
# 31  Flnc: Machine Learning Improves the Identifica...
# 32  Long non-coding RNAs in biomarking COVID-19: a...
# 33  The emerging role of long non-coding RNAs and ...
# 34  Evaluation of lncRNAs as Potential Biomarkers ...
# 35  A comprehensive overview of lncRNA annotation ...
# 36  A new biomarker panel of ultraconserved long n...
# 37  A learning-based method for LncRNA-disease ass...
# 38  LDICDL: LncRNA-disease association identificat...
# 39  LMI-DForest: A deep forest model towards the p...
# 40  Machine learning radiomics of magnetic resonan...
# 41  Multi-feature fusion for deep learning to pred...
# 42  Data resources and computational methods for l...
# 43  LncRNA-ID: Long non-coding RNA IDentification ...
# 44  PRPI-SC: an ensemble deep learning model for p...
# 45  Linc2function: A Comprehensive Pipeline and We...
#
#                                          organization  \
# 0                              Biomedical Informatics
# 1                                  Tianjin University
# 2                                               Roche
# 3                                    Qatar Foundation
# 4                                                 IUB
# 5                                 Stanford University
# 6                                 Columbia University
# 7                      The Second Affiliated Hospital
# 8           Computer Science & Electrical Engineering
# 9                     Beijing Institute of Technology
# 10                    Beijing Institute of Technology
# 11                                           Genetics
# 12                                Liaoning University
# 13                     The Second Affiliated Hospital
# 14         School of Computer Science and Engineering
# 15                                  Nankai University
# 16                                   Korea University
# 17  Seoul National University of Science and Techn...
# 18                            University of Stavanger
# 19                             University of Michigan
# 20                                  Peking University
# 21                       City University of Hong Kong
# 22                                 Comsats University
# 23                       The University of Queensland
# 24                                   Helmholtz Munich
# 25                                                DMI
# 26                       Institute of Cancer Research
# 27                                               NMBU
# 28                   National University of Singapore
# 29  Jomo Kenyatta University of Agriculture and Te...
# 30                     Harbin Institute of Technology
# 31                                       Prof & Chair
# 32                         Tarbiat Modares University
# 33                             University of Limerick
# 34     Shahid Beheshti University of Medical Sciences
# 35                          Harbin Medical University
# 36                               University of Naples
# 37              Northwestern Polytechnical University
# 38                                 Guangxi University
# 39                                   Computer Science
# 40                      Sun Yat-sen Memorial Hospital
# 41  Jomo Kenyatta University of Agriculture and Te...
# 42                                   jilin university
# 43                                             Amazon
# 44  Jomo Kenyatta University of Agriculture and Te...
# 45                                  Monash University
#
#                                              location  \
# 0   (Health & Biomedical Informatics Centre, 202-2...
# 1   (天津医科大学, 22号, 气象台路, 新兴街道, 天津市, 和平区, 天津市, 30005...
# 2   (Roche, La Tour-du-Pin, Isère, Auvergne-Rhône-...
# 3   (المؤسسة القطرية - كابينة 3, شارع 2730, المدين...
# 4   (Iub, Dollo, ሶማሌ ክልል / Somali, ኢትዮጵያ, (8.23333...
# 5   (Stanford University, 408, Panama Mall, Stanfo...
# 6   (Columbia University, Broadway, Manhattan Comm...
# 7   (深圳市第二人民医院, 泥岗西路, 黄木岗社区, 华富街道, 福田区, 深圳市, 广东省, ...
# 8   (Kenneth H Keller Hall, 200, Southeast Union S...
# 9   (北京理工大学, 5, 中关村南大街, 北下关街道, 海淀区, 北京市, 100872, 中...
# 10  (北京理工大学, 5, 中关村南大街, 北下关街道, 海淀区, 北京市, 100872, 中...
# 11  (Genetics, Errigal Road, Crumlin, Crumlin F Wa...
# 12  (辽宁大学（蒲河校区）, 58号, 道义南大街, 道义街道, 沈北新区, 沈阳市, 辽宁省,...
# 13  (深圳市第二人民医院, 泥岗西路, 黄木岗社区, 华富街道, 福田区, 深圳市, 广东省, ...
# 14  (School of Computer Science and Engineering, 日...
# 15  (南开大学八里台校区, 复康路, 水上公园街道, 南开区, 天津市, 300381, 中国,...
# 16  (고려대학교, 세종로, 조치원읍, 세종특별자치시, 30017, 대한민국, (36.6...
# 17  (서울과학기술대학교, 노원로, 공릉동, 공릉2동, 노원구, 서울특별시, 01816,...
# 18  (Universitetet i Stavanger, Draget, Ullandhaug...
# 19  (University of Michigan, 500, South State Stre...
# 20  (北京大学（昌平新校区）, 神牛路, 马池口镇, 昌平区, 北京市, 中国, (40.173...
# 21  (香港城市大學 City University of Hong Kong, 沙田區 Sha ...
# 22  (COMSATS University Islamabad, Sunrise Avenue,...
# 23  (The University of Queensland, Mill Road, St L...
# 24  (Helmholtzstraße, Arnulfpark, Marsfeld, Maxvor...
# 25  (DMI, Aïn Témouchent ⵄⵉⵏ ⵜⵉⵎⵓⵛⴻⵏⵜ عين تموشنت, ...
# 26  (Institute of Cancer Research, Bawtree Close, ...
# 27  (NMBU Christian Magnus Falsens vei, Ås, Christ...
# 28  (National University of Singapore, Clementi Ro...
# 29  (Jomo Kenyatta University of Agriculture and T...
# 30  (哈尔滨工业大学, 教化街, 花园街道, 南岗区, 哈尔滨市, 香坊区, 黑龙江省, 150...
# 31  (Mandale Chair São Paulo, 1161, Avenida Profes...
# 32  (tarbiat modares university, دکتر شهید سیدحسین...
# 33  (University of Limerick, Iona Close, College C...
# 34  (Shahid Beheshti University of Medical Science...
# 35  (哈尔滨医科大学（大庆校区）, Yifeng Rd, 开发区黎明街道, 龙凤区, 大庆市, ...
# 36  (Ave Maria University of Naples, Ötscherlandst...
# 37  (西北工业大学友谊校区, 127号, 友谊西路, 张家村街道, 碑林区, 西安市, 陕西省,...
# 38  (广西大学, 火炬一支路, 西乡塘街道, 西乡塘区, 南宁市, 广西壮族自治区, 53000...
# 39  (Computer Science, 1202, Amsterdam Avenue, Man...
# 40  (孙逸仙纪念医院, 西濠二马路, 人民街道, 越秀区, 广州市, 广东省, 510130, ...
# 41  (Jomo Kenyatta University of Agriculture and T...
# 42  (吉林大学（朝阳校区）, 西朝阳南胡同, 清和街道, 朝阳区, 长春市, 绿园区, 吉林省,...
# 43  (Amazon, Careiro da Várzea, Região Geográfica ...
# 44  (Jomo Kenyatta University of Agriculture and T...
# 45  (Monash University, Mile Lane, International H...
#
#                                              abstract
# 0   Here, we aim to provide a review of machine-le...
# 1   classified into the deep learning-based method...
# 2   Multiple machine learning approaches to lncRNA...
# 3   interplay between lncRNAs and  lncRNAs and RBP...
# 4   In order to identify the optimal prognostic si...
# 5   We evaluated the performance of machine learni...
# 6   learning models on measurements of model sensi...
# 7   lncRNAs lncRNA (TIIClncRNA) in low-grade gliom...
# 8   Our literature survey identified machine learn...
# 9   We have identified lncrna related to iron deat...
# 10  LncRNAs with prognostic value and construct a ...
# 11  In this work, we develop a DeepLncRNA to ident...
# 12  Considering that our model is based only on ln...
# 13  The machine learning method in this study was ...
# 14  lncRNAs and diseases, and traditional machine ...
# 15  In this study, a multiple machine learning (ML...
# 16  In the evolving landscape of machine learning,...
# 17  of a machine learning algorithm for the data n...
# 18  This paper applies machine learning in lncRNA ...
# 19  In addition, lncRNAs that are partially overla...
# 20  lncRNA–protein pairs, we then construct the de...
# 21  the advantages of various machine-learning alg...
# 22  In this study, we have developed a machine lea...
# 23  In this study, we review the progress of ncRNA...
# 24  In this part, we will discuss the machine lear...
# 25  Although a number of approaches for LDAs predi...
# 26  lncRNA. For this purpose, we first investigate...
# 27  long non-coding RNA (lncRNA) category of ncRNA...
# 28  of lncRNAs, in this study, we developed a new ...
# 29  While lncRNA-protein interaction has been stud...
# 30  to infer lncRNA-related diseases. These method...
# 31  a machine learning (ML)-based method to distin...
# 32  Considering the important roles of lncRNAs in ...
# 33  A supervised method was used to construct the ...
# 34  to explore candidate lncRNAs that correlate wi...
# 35  To extract knowledge from big data in bioinfor...
# 36  a methodology, based on machine learning techn...
# 37  are the beginning of machine learning applicat...
# 38  between new lncRNA (or disease) and diseases (...
# 39  learning  for lncRNA-miRNA interaction dataset...
# 40  that machine learning radiomics of MRI can eff...
# 41  Machine learning (ML) techniques have been ext...
# 42  into 5 groups, including machine learning-base...
# 43  made to distinguish between lncRNA and protein...
# 44  Therefore, machine learning has extensively be...
# 45  We propose that understanding the mechanisms o...

# %%
with open(f'{DATA_FOLDER}organization_paper_location_abstract_df.pickle', 'wb') as handle:
    pickle.dump(organization_paper_location_abstract_df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Generate abstract similarity using spacy

# %%
# Extract abstracts
abstracts = organization_paper_location_abstract_df['abstract'].tolist()

# %%
# Load spaCy model
nlp = spacy.load("en_core_web_md")

# %%
# Compute similarity matrix
docs = [nlp(abstract) for abstract in abstracts]
n = len(docs)
similarity_matrix = np.zeros((n, n))

# %%
for i in range(n):
    for j in range(n):
        similarity_matrix[i, j] = docs[i].similarity(docs[j])

# %%
with open(f'{DATA_FOLDER}similarity_matrix.pickle', 'wb') as handle:
    pickle.dump(similarity_matrix, handle, protocol=pickle.HIGHEST_PROTOCOL)
