# %% [markdown]
# 1. Find papers matching the ML search term
# 2. Download first five available files

# %%
import pandas as pd

#import spacy
#from spacy.matcher import PhraseMatcher

from scholarly import scholarly
import time

import requests
import mimetypes
import os

import uuid

#import PyPDF2

# %%
ROOT_FOLDER = '../../../'

# %%
DATA_FOLDER = '../../../data/'

# %%
DETECT_ML_MODEL_FILES_FOLDER = '../../../detect_ml_model_files/'

# %%
model_df = pd.read_excel(f'{ROOT_FOLDER}ML-Model-Categorization.ods', sheet_name='Sheet1', usecols=['MODEL'])

# %%
model_df
# Out:
#                                       MODEL
# 0                         Linear Regression
# 1                     Polynomial Regression
# 2                          Ridge Regression
# 3                          Lasso Regression
# 4                    Elastic Net Regression
# ..                                      ...
# 97                                   Claude
# 98                                    LLaMA
# 99   Contrastive Language-Image Pretraining
# 100                                  DALL-E
# 101                        Stable Diffusion
#
# [102 rows x 1 columns]

# %%
def search_and_download_papers(query, limit, output_dir):
    search_query = scholarly.search_pubs(query)
    papers = []
    counter = 0

    while(counter < limit):
        try:
            time.sleep(2)  # Introduce delay
            paper = next(search_query)
            paper_info = {
                "title": paper.get("bib", {}).get("title"),
                "abstract": paper.get("bib", {}).get("abstract"),
                "year": paper.get("bib", {}).get("pub_year"),
                "url": paper.get("eprint_url", ""),
                "author_id": paper.get("author_id", []),
                "query": query,
                "file_name": "",
                "file_path": None
            }

            # lets download the file if the url exists
            if paper_info['url']:
                url = paper_info['url']
                try:
                    # Download the file if a link is available
                    response = requests.get(url, stream=True)
                    content_type = response.headers.get('Content-Type', '')
                    # Check if the content type is PDF
                    if 'application/pdf' in content_type or mimetypes.guess_extension(content_type) == '.pdf':
                        unique_filename = str(uuid.uuid4()) + '.pdf'
                        file_path = os.path.join(output_dir, unique_filename)

                        with open(file_path, "wb") as file:
                            for chunk in response.iter_content(chunk_size=8192):
                                file.write(chunk)
                        
                        print(f"Downloaded: {file_path}")                            
                        paper_info['file_name'] = unique_filename
                        paper_info['file_path'] = file_path
                        counter += 1
                    else:
                        print(f"non-PDF content: {url}")             
                except Exception as e:
                    print(f"Error occurred while processing {url}: {e}")                                
            papers.append(paper_info)
        except StopIteration:
            break
        except Exception as e:
            print(f"Error processing paper : {e}")
            continue

    return papers

# %%
models = model_df['MODEL'].values.tolist()

# %%
search_results = list()

for model in models:
    print(f"Searching for: {model}")    
    papers = search_and_download_papers(query=model, limit=5, output_dir=DETECT_ML_MODEL_FILES_FOLDER)
    search_results.append(papers)
# Out:
# Searching for: Linear Regression
# Downloaded: ../../../detect_ml_model_files/7cedd2b0-ac03-49fb-9ef1-398b1a5d7fe1.pdf
# Downloaded: ../../../detect_ml_model_files/91374318-7135-4f51-a3bc-720ececd88de.pdf
# Downloaded: ../../../detect_ml_model_files/6d3627b9-6b0b-423c-8898-3185837a7617.pdf
# Downloaded: ../../../detect_ml_model_files/c7fed73c-8e13-4770-a589-67708aab0b7e.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S
pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S2211335521001650
# non-PDF content: https://academic.oup.com/ofid/article/9/12/ofac640/6845426
# Downloaded: ../../../detect_ml_model_files/8c556269-9176-4881-91a1-4ed2b44f93cf.pdf
# Searching for: Bayesian Linear Regression
# Downloaded: ../../../detect_ml_model_files/0e59bd4f-6756-4b5c-a007-3185be197a23.pdf
# Downloaded: ../../../detect_ml_model_files/44d8b0b7-4b41-4911-a5f6-46cbad746e4a.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/am/pii/S0888327020301564
# Error occurred while processing https://www2.stat.duke.edu/courses/Fall05/sta395/joelucas1.pdf: HTTPSConnectionPool(host='www2.stat.duke.edu', port=443): Max retries exceeded with url: /courses/Fall05/sta395/joelucas1.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Downloaded: ../../../detect_ml_model_files/b6071088-34bd-4500-b912-f52a8f9b0b59.pdf
# Downloaded: ../../../detect_ml_model_files/eb121b6c-cb52-45cd-b1b9-f925a11f70a1.pdf
# Error occurred while processing https://www.stat.washington.edu/~raftery/Research/PDF/rmh1997.pdf: HTTPSConnectionPool(host='www.stat.washington.edu', port=443): Max retries exceeded with url: /~raftery/Research/PDF/rmh1997.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1877050918315126/pdf?md5=ec517e4276d8db72140f45b0328e0499&pid=1-s2.0-S1877050918315126-main.pdf
# non-PDF content: https://link.springer.com/article/10.3758/s13428-021-01552-2
# Downloaded: ../../../detect_ml_model_files/48a68b68-e2f8-4c63-a100-cdd11f384d89.pdf
# Searching for: Quantile Regression
# non-PDF content: https://pubs.aeaweb.org/doi/pdf/10.1257/jep.15.4.143
# non-PDF content: https://www.econstor.eu/bitstream/10419/189752/1/CWP361717.pdf
# Downloaded: ../../../detect_ml_model_files/4a7f293f-ffeb-4f65-b9c5-2a3e259cc4ce.pdf
# Downloaded: ../../../detect_ml_model_files/a73cd4bf-f511-4406-9271-15f0e1bd2584.pdf
# non-PDF content: https://academic.oup.com/aje/article/180/3/330/2739270
# Downloaded: ../../../detect_ml_model_files/e3527254-8fed-4a0f-af4d-3bdcfc1f2c5e.pdf
# non-PDF content: https://www.sebastianbuhai.com/papers/publications/quantile_regressions.pdf
# Downloaded: ../../../detect_ml_model_files/64335bca-f093-4708-a63b-8389b95d6032.pdf
# Downloaded: ../../../detect_ml_model_files/4fba869a-a10d-4871-90a7-a355400296d5.pdf
# Searching for: Support Vector Regression
# non-PDF content: https://link.springer.com/chapter/10.1007/978-1-4302-5990-9_4
# Downloaded: ../../../detect_ml_model_files/3f18cb51-a16d-4df3-b3f1-3a217f3ce9d7.pdf
# non-PDF content: https://www.researchgate.net/profile/Mohamed-Mourad-Lafifi/post/Hi-could-anyone-tell-how-the-Epsilon-SVR-perform-the-regression-in-Support-Vector-Machines-SVM/attachment/59d6467c79197b80779a181a/AS%3A458289034076160%401486276028968/download/Review+Support+Vector+Regression.pdf
# Downloaded: ../../../detect_ml_model_files/37d8a91c-4111-48f4-adea-a84397535fd3.pdf
# Downloaded: ../../../detect_ml_model_files/a00f633d-eaf6-4dd4-89b2-2fa65297e2c7.pdf
# Downloaded: ../../../detect_ml_model_files/50053fea-b360-458c-9380-603c1258371f.pdf
# Downloaded: ../../../detect_ml_model_files/a9a7c186-4bcc-490e-8a26-e2c118f4e0d4.pdf
# Searching for: Logistic Regression
# non-PDF content: https://www.ahajournals.org/doi/full/10.1161/Circulationaha.106.682658
# non-PDF content: https://www.researchgate.net/profile/Douglas-Mahoney/publication/5402488_Linear_Mixed_Effects_Models/links/57e560bf08ae9227da964db4/Linear-Mixed-Effects-Models.pdf#page=278
# non-PDF content: https://www.researchgate.net/profile/Andrew-Cucchiara/publication/261659875_Applied_Logistic_Regression/links/542c7eff0cf277d58e8c811e/Applied-Logistic-Regression.pdf
# Downloaded: ../../../detect_ml_model_files/1e0aac1c-41e5-4d09-8242-7854eb0a525f.pdf
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1111/j.1553-2712.2011.01185.x
# Downloaded: ../../../detect_ml_model_files/9e49320d-9087-4832-a6d5-8406cb625f06.pdf
# Downloaded: ../../../detect_ml_model_files/b1c94a57-c0c7-4629-add9-9343db838378.pdf
# Downloaded: ../../../detect_ml_model_files/fa93978f-26c5-432c-a1d6-a4d3574fb585.pdf
# non-PDF content: https://www.academia.edu/download/48686357/applied_logistic_regression.pdf
# Downloaded: ../../../detect_ml_model_files/a41d00fd-2905-41ad-ba69-d197ad2bc471.pdf
# Searching for: Support Vector Machines
# Downloaded: ../../../detect_ml_model_files/e42b2ba9-ab50-4a27-baab-a6064571317c.pdf
# non-PDF content: https://www.academia.edu/download/45694827/wics.4920160517-26685-10le7kw.pdf
# Downloaded: ../../../detect_ml_model_files/95cfc1a8-8313-4b77-aef9-84211c4c6edf.pdf
# Downloaded: ../../../detect_ml_model_files/8055324a-0e10-41d6-be49-5109c7c4afb6.pdf
# non-PDF content: https://www.researchgate.net/profile/Vojislav-Kecman/publication/226743605_Support_Vector_Machines_-_An_Introduction/links/02e7e52971b20615e7000000/Support-Vector-Machines-An-Introduction.pdf
# Downloaded: ../../../detect_ml_model_files/6ebb94f0-e2d2-4672-8e82-335a11e10a8a.pdf
# non-PDF content: https://www.academia.edu/download/45176192/Support_vector_machines_in_engineering_a20160428-18392-1qenwwi.pdf
# non-PDF content: https://www.researchgate.net/profile/Thorsten-Joachims/publication/243763293_SVMLight_Support_Vector_Machine/links/5b0eb5c2a6fdcc80995ac3d5/SVMLight-Support-Vector-Machine.pdf
# non-PDF content: https://journals.sagepub.com/doi/full/10.1177/1536867X1601600407
# non-PDF content: https://www.academia.edu/download/43282568/SVM_Explained.pdf
# Downloaded: ../../../detect_ml_model_files/a9419f3e-024f-4d9e-8301-cf23d7bd2d5d.pdf
# Searching for: k-Nearest Neighbors
# non-PDF content: http://scholarpedia.org/article/K-Nearest_Neighbor
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC
# Downloaded: ../../../detect_ml_model_files/c627f2c9-71e6-4723-b979-4a8c88f6be0a.pdf
# Downloaded: ../../../detect_ml_model_files/1b751a17-4c02-4301-a6fe-f69a66074668.pdf
# Searching for: XGBoost
# Downloaded: ../../../detect_ml_model_files/7fcd59ff-41bb-4666-8e63-dd745f25c6b8.pdf
# Downloaded: ../../../detect_ml_model_files/9b90f78e-8810-48a9-b964-abc3a0527346.pdf
# Downloaded: ../../../detect_ml_model_files/6727f7fd-2b2a-455c-b05a-894552200837.pdf
# Downloaded: ../../../detect_ml_model_files/87924be0-7b35-4d84-a693-fa706a65e61b.pdf
# non-PDF content: https://www.researchgate.net/profile/Shatadeep-Banerjee/publication/318132203_Experimenting_XGBoost_Algorithm_for_Prediction_and_Classification_of_Different_Datasets/links/595b89b0458515117741a571/Experimenting-XGBoost-Algorithm-for-Prediction-and-Classification-of-Different-Datasets.pdf
# non-PDF content: https://www.mdpi.com/2078-2489/9/7/149
# non-PDF content: https://peerj.com/articles/cs-127/
# non-PDF content: https://www.frontiersin.org/articles/10.3389/fgene.2019.01077/full
# non-PDF content: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4029398
# Downloaded: ../../../detect_ml_model_files/79ab4611-4356-4818-9c29-17a2d4054642.pdf
# Searching for: LightGBM
# Downloaded: ../../../detect_ml_model_files/5ad18f55-e570-4e14-b570-d783458439ac.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/am/pii/S016974391930262X
# non-PDF content: https://link.springer.com/article/10.1186/s13059-021-02492-y
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/09284642.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S0960077922001977
# non-PDF content: https://authors.library.caltech.edu/105910/1/09210509.pdf
# non-PDF content: https://www.mdpi.com/2075-4418/11/9/1714
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/08653826.pdf
# non-PDF content: https://journals.plos.org/digitalhealth/article?id=10.1371/journal.pdig.0000299
# non-PDF content: https://www.mdpi.com/2073-8994/12/9/1458
# non-PDF content: https://www.mdpi.com/2227-7390/8/5/765
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2019/3761203
# non-PDF content: https://www.mdpi.com/2077-1312/9/5/496
# Downloaded: ../../../detect_ml_model_files/30cc8b2e-475b-4036-b133-9d9d2130ea89.pdf
# non-PDF content: https://www.mdpi.com/2076-3417/10/9/3227
# non-PDF content: https://ietresearch.onlinelibrary.wiley.com/doi/full/10.1049/iet-its.2020.0396
# Downloaded: ../../../detect_ml_model_files/2e2661dd-fbe4-4eab-9f91-8bb896985e17.pdf
# non-PDF content: https://www.degruyter.com/document/doi/10.1515/jisys-2022-0036/html
# non-PDF content: https://www.mdpi.com/2075-5309/12/9/1309
# Downloaded: ../../../detect_ml_model_files/79c3f10a-1a1a-4510-8367-177421f5001c.pdf
# non-PDF content: https://academic.oup.com/bioinformatics/article/37/8/1135/5942084
# non-PDF content: https://xuebao.neu.edu.cn/natural/EN/article/downloadArticleFile.do?attachType=PDF&id=11623
# non-PDF content: https://www.mdpi.com/1996-1073/13/4/807
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2021/8128879
# non-PDF content: https://www.mdpi.com/2227-9717/12/1/221
# Downloaded: ../../../detect_ml_model_files/46647af5-8e95-41b1-b55b-8b2f20203c5b.pdf
# Searching for: CatBoost
# non-PDF content: https://link.springer.com/article/10.1186/s40537-020-00369-8
# Downloaded: ../../../detect_ml_model_files/023c435c-1e73-49ab-bc5d-1b88f707a901.pdf
# non-PDF content: https://www.mdpi.com/1999-4907/12/2/216
# non-PDF content: https://pdfs.semanticscholar.org/948c/ae886bd76ab222f3be431ab0a71e6aa03286.pdf
# Downloaded: ../../../detect_ml_model_files/7ad2ba6f-166d-4305-927f-ebad1f40efcb.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S2352484721004716
# non-PDF content: https://www.mdpi.com/1424-8220/23/4/1811
# non-PDF content: https://www.mdpi.com/2220-9964/12/10/416
# non-PDF content: https://www.nature.com/articles/s41598-024-77058-6
# non-PDF content: https://pdfs.semanticscholar.org/72cc/f61c3a1da9c743694c363ee58e36dda5bb7e.pdf
# non-PDF content: https://www.mdpi.com/2077-0472/13/6/1122
# non-PDF content: https://www.nature.com/articles/s41598-024-74417-1
# non-PDF content: https://www.frontiersin.org/articles/10.3389/fbuil.2023.1207193/full
# non-PDF content: https://www.researchgate.net/profile/Ruslan-Safarov/publication/343263399_SOLVING_OF_CLASSIFICATION_PROBLEM_IN_SPATIAL_ANALYSIS_APPLYING_THE_TECHNOLOGY_OF_GRADIENT_BOOSTING_CATBOOST/links/5f20435ea6fdcc9626ba0b65/SOLVING-OF-CLASSIFICATION-PROBLEM-IN-SPATIAL-ANALYSIS-APPLYING-THE-TECHNOLOGY-OF-GRADIENT-BOOSTING-CATBOOST.pdf
# non-PDF content: https://www.researchgate.net/profile/Moolchand-Sharma/publication/355783758_CatBoost-_An_Ensemble_Machine_Learning_Model_for_Prediction_and_Classification_of_Student_Academic_Performance/links/6243fb3057084c718b75ddcb/CatBoost-An-Ensemble-Machine-Learning-Model-for-Prediction-and-Classification-of-Student-Academic-Performance.pdf?_sg%5B0%5D=started_experiment_milestone&origin=journalDetail&_rtd=e30%3D
# non-PDF content: https://www.mdpi.com/2072-6651/15/10/608
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2021/1929137
# non-PDF content: https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0304619
# Downloaded: ../../../detect_ml_model_files/c80fbb9a-72dc-47e9-8df6-f690600f3717.pdf
# non-PDF content: https://www.nature.com/articles/s41598-024-67562-0
# non-PDF content: https://www.mdpi.com/2072-4292/15/14/3510
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S2352484722012033
# non-PDF content: https://www.researchgate.net/profile/Ouail-Ouchetto/publication/344865707_Optimization_of_a_Similarity_Performance_on_Bounded_Content_of_Motion_Histogram_by_Using_Distributed_Model/links/63049fa9eb7b135a0e55a17c/Optimization-of-a-Similarity-Performance-on-Bounded-Content-of-Motion-Histogram-by-Using-Distributed-Model.pdf#page=196
# non-PDF content: https://www.tandfonline.com/doi/full/10.1080/01605682.2020.1843976
# non-PDF content: https://ieeexplore.ieee.org/iel7/4609443/9314330/09368975.pdf
# non-PDF content: https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0262895
# Downloaded: ../../../detect_ml_model_files/02b42a24-aec3-4c26-adab-452129a291f3.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1874778719301746
# Downloaded: ../../../detect_ml_model_files/94106934-fd73-48f5-98cd-7edb1ae380f2.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/am/pii/S074373151830875X
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6679899/
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8330414/
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2018/8019232
# non-PDF content: https://www.mdpi.com/1099-4300/25/7/1065
# Downloaded: ../../../detect_ml_model_files/4b8dc823-f7b5-45ca-ab35-1a90cfbb64c0.pdf
# Downloaded: ../../../detect_ml_model_files/24cce1c3-cfdb-443a-bc80-ddd21893f30c.pdf
# Downloaded: ../../../detect_ml_model_files/0fc326c8-5ec9-4284-b30f-4734fbcbd85d.pdf
# Downloaded: ../../../detect_ml_model_files/9ef37512-a086-4c55-8e3d-841961c90fc9.pdf
# Searching for: Uniform Manifold Approximation and Projection
# Downloaded: ../../../detect_ml_model_files/2ab4f52c-f760-45a5-96a6-a84542cdf271.pdf
# Downloaded: ../../../detect_ml_model_files/e86e4589-1412-425f-9f2f-39b97d66baa6.pdf
# Downloaded: ../../../detect_ml_model_files/ee650522-9776-485c-b157-96c63b75cced.pdf
# Downloaded: ../../../detect_ml_model_files/8f57faa2-26a5-40de-8348-e47f3d72ce18.pdf
# non-PDF content: https://journals.asm.org/doi/full/10.1128/msystems.00691-21
# non-PDF content: https://researchportal.helsinki.fi/files/171964407/1_s2.0_S0048969721074428_main.pdf
# Downloaded: ../../../detect_ml_model_files/6040e70c-7945-4ad5-a08e-195abeedd1a6.pdf
# Searching for: Independent Component Analysis
# Downloaded: ../../../detect_ml_model_files/1a949a8b-b884-4b31-a463-cb1ea12031ac.pdf
# non-PDF content: https://royalsocietypublishing.org/doi/full/10.1098/rsta.2011.0534
# Downloaded: ../../../detect_ml_model_files/0cea315e-f1ef-4df1-82a9-7aa77e956720.pdf
# Downloaded: ../../../detect_ml_model_files/23ade7ad-fbfe-4540-ab79-6e931033c873.pdf
# Downloaded: ../../../detect_ml_model_files/54a6f40f-30ff-47b8-83b6-5c3f6d4a9246.pdf
# Downloaded: ../../../detect_ml_model_files/ef929494-ed75-4855-bbcd-a99a8bf881ce.pdf
# Searching for: Autoencoders
# Downloaded: ../../../detect_ml_model_files/a94ceeb5-8c6f-4ab7-9e47-18b102fd6274.pdf
# Downloaded: ../../../detect_ml_model_files/81b6d356-4c88-41b6-905c-affee3375277.pdf
# Downloaded: ../../../detect_ml_model_files/f8ed63d5-65be-4360-b1f5-51e33a77a450.pdf
# Downloaded: ../../../detect_ml_model_files/5f97d5dd-a85c-4b17-8c8e-a7be69231988.pdf
# Downloaded: ../../../detect_ml_model_files/645866af-2eb5-40d5-9e84-f618f510a380.pdf
# Searching for: Apriori Algorithm
# non-PDF content: https://www.researchgate.net/profile/Markus-Hegland/publication/228524191_The_Apriori_Algorithm-a_Tutorial/links/0deec5239c8d242f51000000/The-Apriori-Algorithm-a-Tutorial.pdf
# Downloaded: ../../../detect_ml_model_files/ecad65fa-c8bd-4e99-b4c9-28e6fefe0f58.pdf
# non-PDF content: https://pubs.aip.org/aip/acp/article-pdf/doi/10.1063/1.4977361/13140827/080005_1_online.pdf
# Downloaded: ../../../detect_ml_model_files/379d1bb0-1792-4db2-826a-b5b62520d5dc.pdf
# Downloaded: ../../../detect_ml_model_files/2f4586de-2d49-4dac-b225-d14bea6b9176.pdf
# non-PDF content: https://www.researchgate.net/profile/K-Dharmarajan/publication/310795314_Analysis_of_FP-Growth_and_Apriori_Algorithms_on_Pattern_Discovery_from_Weblog_Data/links/59dec557aca27247d7946593/Analysis-of-FP-Growth-and-Apriori-Algorithms-on-Pattern-Discovery-from-Weblog-Data.pdf
# Downloaded: ../../../detect_ml_model_files/62c0a959-b05f-4a7d-be4e-b941d108e61d.pdf
# Searching for: Self-Training
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S0925231224016758
# Downloaded: ../../../detect_ml_model_files/315e5cef-5564-4f26-b738-dfba63822426.pdf
# Downloaded: ../../../detect_ml_model_files/f07e60b4-b021-42c6-80ee-451aac17d2ae.pdf
# Downloaded: ../../../detect_ml_model_files/0ba6c3a9-5337-4c02-ba9f-a88727fd3a6b.pdf
# Downloaded: ../../../detect_ml_model_files/e7cb7600-0fb4-43e4-b61a-6d964e0055dd.pdf
# Downloaded: ../../../detect_ml_model_files/8d4b1ea3-f0c2-4d8a-a5f3-6d9d791f299e.pdf
# Searching for: Co-Training
# non-PDF content: https://www.researchgate.net/profile/Xin-Ning-9/publication/350194568_A_review_of_research_on_co-training/links/605709cc299bf17367595145/A-review-of-research-on-co-training.pdf
# Downloaded: ../../../detect_ml_model_files/cf97be26-2502-4001-8c24-66c9df25969e.pdf
# Error occurred while processing https://cs.nju.edu.cn/zhouzh/zhouzh.files/publication/icml10.pdf: HTTPSConnectionPool(host='cs.nju.edu.cn', port=443): Max retries exceeded with url: /zhouzh/zhouzh.files/publication/icml10.pdf (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] ssl/tls alert handshake failure (_ssl.c:1000)')))
# Downloaded: ../../../detect_ml_model_files/c4cc64e6-dc8d-4972-ad07-887c977340d4.pdf
# Downloaded: ../../../detect_ml_model_files/7405c2cb-2671-46c8-a5f5-363f90d399ff.pdf
# Downloaded: ../../../detect_ml_model_files/04ee67e6-af00-47cd-8d3c-bf0625d12339.pdf
# Downloaded: ../../../detect_ml_model_files/571f27f3-0e0c-4e08-ac4e-de85366403fb.pdf
# Searching for: Tri-Training
# Downloaded: ../../../detect_ml_model_files/2d5180ee-1a18-42b7-8a4d-e140a3b65257.pdf
# Downloaded: ../../../detect_ml_model_files/a9def0c3-d9d5-46e1-b2e2-f85717d5449e.pdf
# non-PDF content: https://itiis.org/digital-library/manuscript/file/25101/TIIS%20Vol%2015,%20No%2011-9.pdf
# Downloaded: ../../../detect_ml_model_files/3db03534-8145-4967-9fc7-2070f8d94989.pdf
# Downloaded: ../../../detect_ml_model_files/6e480352-683b-4d4b-8fb2-ada2a9b14bb8.pdf
# Downloaded: ../../../detect_ml_model_files/5d12ec00-63cc-4a90-9375-88af38d699f6.pdf
# Searching for: Pseudo-Labeling
# Downloaded: ../../../detect_ml_model_files/4be8ec24-7342-46bc-9a79-22510d73af00.pdf
# non-PDF content: https://ojs.aaai.org/index.php/AAAI/article/view/16852/16659
# Downloaded: ../../../detect_ml_model_files/902e6bb0-aec6-4a21-b1a0-60c88ba9618e.pdf
# Downloaded: ../../../detect_ml_model_files/883d6689-0e62-4eea-8968-9c77718476ef.pdf
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9767807/
# Downloaded: ../../../detect_ml_model_files/2e70db88-4796-4239-a183-a998534605b3.pdf
# Downloaded: ../../../detect_ml_model_files/76e6b8c1-96b4-44a2-b480-2ace63cd43df.pdf
# Searching for: Graph-Based Learning Models (e.g., Label Propagation)
# non-PDF content: http://aiia.csd.auth.gr/wp-content/uploads/papers/PUBLISHED/JOURNAL/pdf/2015/Graph-based_Label_Propagation_ACS.pdf
# non-PDF content: https://www.researchgate.net/profile/Jun-Long-4/publication/220868048_Graph-Based_Active_Learning_Based_on_Label_Propagation/links/5a68345baca2720266b659dd/Graph-Based-Active-Learning-Based-on-Label-Propagation.pdf
# Downloaded: ../../../detect_ml_model_files/e4881498-e23d-41d7-805a-7562e0599150.pdf
# Downloaded: ../../../detect_ml_model_files/cc0b5186-faad-4d42-95eb-1b2b39538ff6.pdf
# non-PDF content: https://dl.acm.org/doi/fullHtml/10.1145/3490478
# Downloaded: ../../../detect_ml_model_files/f05a5f14-5b1b-4557-9161-b942580f10c8.pdf
# Downloaded: ../../../detect_ml_model_files/eb1089ed-18cc-4b86-9dc2-f8eab6e45591.pdf
# Downloaded: ../../../detect_ml_model_files/b4f65c12-5d53-4da3-abf7-8f784d2218f0.pdf
# Searching for: Generative Models
# Downloaded: ../../../detect_ml_model_files/f364bce7-dd7b-48ba-93ce-14d0ff58b955.pdf
# Downloaded: ../../../detect_ml_model_files/8fea3076-7a43-42f5-afe9-b720b866a840.pdf
# non-PDF content: https://www.researchgate.net/profile/Azeddine-Elhassouny/publication/325026037_Deep_generative_models_Survey/links/5cff3e81a6fdccd13091cfc9/Deep-generative-models-Survey.pdf
# Downloaded: ../../../detect_ml_model_files/09f3f66d-49c5-4af3-ab1e-1790c11263a0.pdf
# Downloaded: ../../../detect_ml_model_files/b5d4925b-9bf2-4684-8525-9b7e1b5c2d62.pdf
# Downloaded: ../../../detect_ml_model_files/d4af183e-87d9-4b31-8481-e8f7292e4804.pdf
# Searching for: Q-Learning
# Downloaded: ../../../detect_ml_model_files/4c4c59a6-22dc-43db-a9a0-4054a37c7426.pdf
# Downloaded: ../../../detect_ml_model_files/cfea5da7-ac7a-4583-b455-f229edd3eec3.pdf
# non-PDF content: https://www.academia.edu/download/35466333/watkins92.pdf
# Downloaded: ../../../detect_ml_model_files/1fce1f69-c636-407d-940e-a304059a42ad.pdf
# Downloaded: ../../../detect_ml_model_files/5655ce62-408e-49e0-ba41-2ad6912164b6.pdf
# Downloaded: ../../../detect_ml_model_files/9d0600ce-fda9-413a-b3d1-15847b41cb87.pdf
# Searching for: Deep Q-Networks
# Downloaded: ../../../detect_ml_model_files/9a3100e2-f650-49f7-a1aa-b0e215d81303.pdf
# Downloaded: ../../../detect_ml_model_files/dcc3c2e2-936a-475e-8a6c-0adfb6ec2fcc.pdf
# Downloaded: ../../../detect_ml_model_files/99d4bb49-8c57-4f77-95a6-8d464ca95530.pdf
# Downloaded: ../../../detect_ml_model_files/446a8bec-c492-4faa-8bab-52a99398a31c.pdf
# Searching for: Trust Region Policy Optimization
# Downloaded: ../../../detect_ml_model_files/4da05bcb-a2fd-4df7-befd-c8f38087cf4c.pdf
# Downloaded: ../../../detect_ml_model_files/bf0579cf-4be0-4364-a68f-177ad4678faa.pdf
# Downloaded: ../../../detect_ml_model_files/1f662af1-124f-4501-9964-6c462d224099.pdf
# non-PDF content: https://ojs.aaai.org/index.php/AAAI/article/download/6021/5877
# Downloaded: ../../../detect_ml_model_files/47e14c06-7ef9-481a-808e-c1606db63974.pdf
# Downloaded: ../../../detect_ml_model_files/db106668-3a57-40c8-874c-6d964693f040.pdf
# Searching for: Deep Deterministic Policy Gradient
# Downloaded: ../../../detect_ml_model_files/75b37894-374d-4a51-98ec-df23c004913e.pdf
# non-PDF content: https://aaai.org/ojs/index.php/AAAI/article/download/4327/4205
# non-PDF content: https://www.cell.com/heliyon/fulltext/S2405-8440(24)06728-8
# Downloaded: ../../../detect_ml_model_files/8c5bd1c7-03fd-49d2-8853-5c5ca7e5d511.pdf
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2022/7739440
# Downloaded: ../../../detect_ml_model_files/2d0aa09d-2d17-4042-ac0f-1fe9ce200bf4.pdf
# non-PDF content: https://www.mdpi.com/1424-8220/22/24/9574
# Downloaded: ../../../detect_ml_model_files/15c74666-6bf2-4fb7-a63f-719d9e9747bc.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S0306261922005025
# non-PDF content: https://drive.google.com/file/d/1ctqyjdxE7YY8K70ljb-4TH9Cnan-q-97/view
# non-PDF content: https://www.mdpi.com/1424-8220/22/9/3579
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2020/4275623
# Downloaded: ../../../detect_ml_model_files/e94438df-7aa0-4f12-b342-ebdc8d819c80.pdf
# Searching for: Twin Delayed DDPG
# non-PDF content: https://www.researchgate.net/profile/Wenfeng-Zheng/publication/341648433_Twin-Delayed_DDPG_A_Deep_Reinforcement_Learning_Technique_to_Model_a_Continuous_Movement_of_an_Intelligent_Robot_Agent/links/5ed9ae3e92851c9c5e816d19/Twin-Delayed-DDPG-A-Deep-Reinforcement-Learning-Technique-to-Model-a-Continuous-Movement-of-an-Intelligent-Robot-Agent.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/9668973/09773098.pdf
# non-PDF content: https://www.mdpi.com/1424-8220/21/23/7793
# Downloaded: ../../../detect_ml_model_files/3fc3fbc2-c5bc-46da-9318-287360fdb5f0.pdf
# Downloaded: ../../../detect_ml_model_files/0b2f1f46-265f-400a-839c-3e399cd55468.pdf
# non-PDF content: https://dl.acm.org/doi/abs/10.23919/ICCAS52745.2021.9649882
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/09721287.pdf
# non-PDF content: https://www.mdpi.com/1996-1073/14/20/6695
# non-PDF content: https://www.mdpi.com/2076-3417/12/16/8189
# Downloaded: ../../../detect_ml_model_files/804f45fc-9e55-4a86-b926-eb89d75852f4.pdf
# Downloaded: ../../../detect_ml_model_files/a79cb9c8-41dd-43e5-8e80-15ea25463a14.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2022/1636203
# non-PDF content: https://www.mdpi.com/2313-433X/9/10/197
# Downloaded: ../../../detect_ml_model_files/44241e23-cf34-4f28-b087-8a6a9941ce5f.pdf
# non-PDF content: https://jamanetwork.com/journals/jamanetworkopen/fullarticle/2813421
# non-PDF content: https://www.jacc.org/doi/full/10.1016/j.jacc.2018.12.042
# non-PDF content: https://peerj.com/articles/7731/
# Downloaded: ../../../detect_ml_model_files/3e9369d8-dc38-4487-ba9a-d429b60b5fbe.pdf
# Downloaded: ../../../detect_ml_model_files/08dab0d1-656d-47f1-b6aa-ea9525e6b902.pdf
# non-PDF content: https://www.academia.edu/download/89076721/s00500-019-04307-620220728-1-93nujn.pdf
# non-PDF content: https://www.mdpi.com/1424-8220/20/6/1693
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/9312710/09631287.pdf
# Downloaded: ../../../detect_ml_model_files/c7dc6494-6e10-4815-8659-6ac6e3a89510.pdf
# Searching for: AlexNet
# /home/reza/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_scholarly.py:312: SyntaxWarning: invalid escape sequence '\d'
#   m = re.search("cites=[\d+,]*", object["citedby_url"])
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 for model in models:
#       4     print(f"Searching for: {model}")
# ----> 5     papers = search_and_download_papers(query=model, limit=5, output_dir=DETECT_ML_MODEL_FILES_FOLDER)
#       6     search_results.append(papers)
#
# Cell In[7], line 2, in search_and_download_papers(query, limit, output_dir)
#       1 def search_and_download_papers(query, limit, output_dir):
# ----> 2     search_query = scholarly.search_pubs(query)
#       3     papers = []
#       4     counter = 0
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_scholarly.py:160, in _Scholarly.search_pubs(self, query, patents, citations, year_low, year_high, sort_by, include_last_year, start_index)
#      97 """Searches by query and returns a generator of Publication objects
#      98
#      99 :param query: terms to be searched
#    (...)
#     155
#     156 """
#     157 url = self._construct_url(_PUBSEARCH.format(requests.utils.quote(query)), patents=patents,
#     158                           citations=citations, year_low=year_low, year_high=year_high,
#     159                           sort_by=sort_by, include_last_year=include_last_year, start_index=start_index)
# --> 160 return self.__nav.search_publications(url)
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:296, in Navigator.search_publications(self, url)
#     288 def search_publications(self, url: str) -> _SearchScholarIterator:
#     289     """Returns a Publication Generator given a url
#     290
#     291     :param url: the url where publications can be found.
#    (...)
#     294     :rtype: {_SearchScholarIterator}
#     295     """
# --> 296     return _SearchScholarIterator(self, url)
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/publication_parser.py:53, in _SearchScholarIterator.__init__(self, nav, url)
#      51 self._pubtype = PublicationSource.PUBLICATION_SEARCH_SNIPPET if "/scholar?" in url else PublicationSource.JOURNAL_CITATION_LIST
#      52 self._nav = nav
# ---> 53 self._load_url(url)
#      54 self.total_results = self._get_total_results()
#      55 self.pub_parser = PublicationParser(self._nav)
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/publication_parser.py:59, in _SearchScholarIterator._load_url(self, url)
#      57 def _load_url(self, url: str):
#      58     # this is temporary until setup json file
# ---> 59     self._soup = self._nav._get_soup(url)
#      60     self._pos = 0
#      61     self._rows = self._soup.find_all('div', class_='gs_r gs_or gs_scl') + self._soup.find_all('div', class_='gsc_mpat_ttl')
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:239, in Navigator._get_soup(self, url)
#     237 def _get_soup(self, url: str) -> BeautifulSoup:
#     238     """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 239     html = self._get_page('https://scholar.google.com{0}'.format(url))
#     240     html = html.replace(u'\xa0', u' ')
#     241     res = BeautifulSoup(html, 'html.parser')
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:190, in Navigator._get_page(self, pagerequest, premium)
#     188     return self._get_page(pagerequest, True)
#     189 else:
# --> 190     raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#
# MaxTriesExceededException: Cannot Fetch from Google Scholar.

# %%
# can do it in one line but is it easier to read?
# flattened_data = [paper for paper in papers for papers in search_results]
flattened_data = list()
for papers in search_results:
    for paper in papers:
        flattened_data.append(paper)

# %%
data_df = pd.DataFrame(flattened_data)

# %%
data_df
# Out:
#                                                  title  \
# 0                                    Linear regression
# 1           Introduction to linear regression analysis
# 2                                    Linear regression
# 3                                    Linear regression
# 4                            Applied linear regression
# ..                                                 ...
# 693  A robust system for road sign detection and cl...
# 694  Rolling-element bearing fault diagnosis using ...
# 695  An improved LeNet-deep neural network model fo...
# 696  Prognostic factors associated with development...
# 697  Comparison of LeNet-5, AlexNet and GoogLeNet m...
#
#                                               abstract  year  \
# 0    Linear regression plays a fundamental role in ...  2012
# 1    Equation (1.2) is called a linear regression m...  2021
# 2    linear regression, a very simple approach for ...  2023
# 3    In linear regression the ordinary least square...  2012
# 4    Applied linear regression Applied linear regre...  2005
# ..                                                 ...   ...
# 693  In this paper, we are reporting a system for d...  2020
# 694  the improved 2D LeNet-5 network and improved 1...  2020
# 695  in LeNet by the concatenated layers. We have a...  2021
# 696  PURPOSE Acute pancreatitis is a potentially li...  2022
# 697  The aim of the study was to compare the accura...  2022
#
#                                                    url  \
# 0    https://www.cs.columbia.edu/~djhsu/coms4771-f2...
# 1    http://sutlib2.sut.ac.th/sut_contents/H133678.pdf
# 2         https://datamineaz.org/readings/ISL_chp3.pdf
# 3
# 4    https://www.stat.cmu.edu/~brian/valerie/617-20...
# ..                                                 ...
# 693  https://www.academia.edu/download/89076721/s00...
# 694           https://www.mdpi.com/1424-8220/20/6/1693
# 695  https://ieeexplore.ieee.org/iel7/6287639/93127...
# 696
# 697  https://ph.pollub.pl/index.php/jcsi/article/do...
#
#                                              author_id              query  \
# 0                       [wcgZZP8AAAAJ, , El-UNYoAAAAJ]  Linear Regression
# 1                       [5PboKNAAAAAJ, , y2eb6cQAAAAJ]  Linear Regression
# 2    [KUIjZqgAAAAJ, bHZf-c8AAAAJ, tQVe-fAAAAAJ, ZpG...  Linear Regression
# 3                                       [vBWC0XIAAAAJ]  Linear Regression
# 4                                       [wlu6jZQAAAAJ]  Linear Regression
# ..                                                 ...                ...
# 693       [s4PPcq8AAAAJ, , DPK9m_YAAAAJ, eBF5ZcwAAAAJ]              LeNet
# 694                               [lGOm9iwNkE4C, , , ]              LeNet
# 695  [zesMrQgAAAAJ, i95DGLQAAAAJ, of-iYjsAAAAJ, QSN...              LeNet
# 696                             [, , , , RPQKmqgAAAAJ]              LeNet
# 697                                   [, bN8PXX4AAAAJ]              LeNet
#
#                                     file_name  \
# 0    7cedd2b0-ac03-49fb-9ef1-398b1a5d7fe1.pdf
# 1    91374318-7135-4f51-a3bc-720ececd88de.pdf
# 2    6d3627b9-6b0b-423c-8898-3185837a7617.pdf
# 3
# 4    c7fed73c-8e13-4770-a589-67708aab0b7e.pdf
# ..                                        ...
# 693
# 694
# 695
# 696
# 697  c7dc6494-6e10-4815-8659-6ac6e3a89510.pdf
#
#                                              file_path
# 0    ../../../detect_ml_model_files/7cedd2b0-ac03-4...
# 1    ../../../detect_ml_model_files/91374318-7135-4...
# 2    ../../../detect_ml_model_files/6d3627b9-6b0b-4...
# 3                                                 None
# 4    ../../../detect_ml_model_files/c7fed73c-8e13-4...
# ..                                                 ...
# 693                                               None
# 694                                               None
# 695                                               None
# 696                                               None
# 697  ../../../detect_ml_model_files/c7dc6494-6e10-4...
#
# [698 rows x 8 columns]

# %%
data_df.to_parquet(f'{DATA_FOLDER}detect_ml_models.parquet')

# %%
data_df = pd.read_parquet(f'{DATA_FOLDER}detect_ml_models.parquet')

# %%
unprocessed_models = list()

processed_models = data_df['query'].unique().tolist()

for model in models:
    if model not in processed_models:
        unprocessed_models.append(model)

# %%
search_results = list()
for model in unprocessed_models:
    print(f"Searching for: {model}")    
    papers = search_and_download_papers(query=model, limit=5, output_dir=DETECT_ML_MODEL_FILES_FOLDER)
    search_results.append(papers)
# Out:
# Searching for: AlexNet
# Downloaded: ../../../detect_ml_model_files/c6bf255b-a845-4b9c-b6c2-bb3d29cbc175.pdf
# Downloaded: ../../../detect_ml_model_files/233078ca-a4c0-49a0-9cce-84fadcadee3e.pdf
# Downloaded: ../../../detect_ml_model_files/f54bed3f-8e74-455e-a1c3-8bee73ab326d.pdf
# non-PDF content: https://ojs.aaai.org/index.php/AAAI/article/view/10171/10030
# Downloaded: ../../../detect_ml_model_files/87740124-3680-4c25-ae86-f7f9e86b5873.pdf
# non-PDF content: https://www.researchgate.net/profile/Ali-Almisreb/publication/327712055_Utilizing_AlexNet_Deep_Transfer_Learning_for_Ear_Recognition/links/5cc7ccd64585156cd7bbc0ab/Utilizing-AlexNet-Deep-Transfer-Learning-for-Ear-Recognition.pdf
# non-PDF content: https://www.researchgate.net/profile/Asad-Ullah-69/publication/378148232_Comparative_Analysis_of_AlexNet_ResNet18_and_SqueezeNet_with_Diverse_Modification_and_Arduous_Implementation/links/65ca0fb734bbff5ba70b4124/Comparative-Analysis-of-AlexNet-ResNet18-and-SqueezeNet-with-Diverse-Modification-and-Arduous-Implementation.pdf
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7573031/
# non-PDF content: https://iopscience.iop.org/article/10.1088/1742-6596/1813/1/012051/pdf
# Downloaded: ../../../detect_ml_model_files/3508cdb1-3743-49d0-86e0-d17833d52c27.pdf
# Searching for: VGGNet
# Downloaded: ../../../detect_ml_model_files/7aeeef2d-4719-4ff5-bd7a-08a0cc80e7a5.pdf
# non-PDF content: https://www.researchgate.net/profile/Shahbaz-Pervez/publication/329315021_Pre-trained_VGGNet_Architecture_for_Remote-Sensing_Image_Scene_Classification/links/5c3a4097299bf12be3c3c65f/Pre-trained-VGGNet-Architecture-for-Remote-Sensing-Image-Scene-Classification.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/09515947.pdf
# non-PDF content: https://www.researchgate.net/profile/Bmg-Prasad/publication/363891123_CNN_Architectures_Alex_Net_Le_Net_VGG_Google_Net_Res_Net/links/66ee8a306b101f6fa4f8a886/CNN-Architectures-Alex-Net-Le-Net-VGG-Google-Net-Res-Net.pdf
# non-PDF content: https://iopscience.iop.org/article/10.1088/1742-6596/1774/1/012043/pdf
# non-PDF content: https://ietresearch.onlinelibrary.wiley.com/doi/pdfdirect/10.1049/iet-ipr.2018.6656
# non-PDF content: https://www.researchgate.net/profile/Xiaofeng-Gao-3/publication/361472279_Deep_convolutional_neural_networks_for_construction_and_demolition_waste_classification_VGGNet_structures_cyclical_learning_rate_and_knowledge_transfer/links/62b5befd6ec05339cca01396/Deep-convolutional-neural-networks-for-construction-and-demolition-waste-classification-VGGNet-structures-cyclical-learning-rate-and-knowledge-transfer.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1319157821001300
# Downloaded: ../../../detect_ml_model_files/2d7e927c-d95d-405c-9eb3-68da887d9f78.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/08305463.pdf
# non-PDF content: https://iopscience.iop.org/article/10.1088/1742-6596/2040/1/012001/pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/10162199.pdf
# Downloaded: ../../../detect_ml_model_files/11073b16-0220-4f8f-942b-efc970243e85.pdf
# non-PDF content: http://joces.nudt.edu.cn/EN/article/downloadArticleFile.do?attachType=PDF&id=16301
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/10044107.pdf
# Downloaded: ../../../detect_ml_model_files/1b7d02f7-5c37-40ff-9563-e76409449715.pdf
# Downloaded: ../../../detect_ml_model_files/0693cb40-7e2b-4401-83ef-b6d188b7288d.pdf
# Searching for: ResNet
# Downloaded: ../../../detect_ml_model_files/65a39d8d-a759-4192-9549-ee1f4b1178ce.pdf
# non-PDF content: https://www.researchgate.net/profile/Zifeng-Wu-2/publication/311222763_Wider_or_Deeper_Revisiting_the_ResNet_Model_for_Visual_Recognition/links/584127b108ae2d217560f418/Wider-or-Deeper-Revisiting-the-ResNet-Model-for-Visual-Recognition.pdf
# Downloaded: ../../../detect_ml_model_files/5a6366ed-2c54-4253-b265-e9cde133abcb.pdf
# Downloaded: ../../../detect_ml_model_files/0c5e025c-ecf6-45d8-8efc-4da63bea4178.pdf
# Downloaded: ../../../detect_ml_model_files/7e095181-c048-4509-beaa-27e84eb819ca.pdf
# non-PDF content: https://ojs.aaai.org/index.php/AAAI/article/download/11231/11090
# Downloaded: ../../../detect_ml_model_files/e4f069a5-19d5-4690-b727-a70f117a1215.pdf
# Searching for: Inception
# /home/reza/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_scholarly.py:312: SyntaxWarning: invalid escape sequence '\d'
#   m = re.search("cites=[\d+,]*", object["citedby_url"])
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 for model in unprocessed_models:
#       3     print(f"Searching for: {model}")
# ----> 4     papers = search_and_download_papers(query=model, limit=5, output_dir=DETECT_ML_MODEL_FILES_FOLDER)
#       5     search_results.append(papers)
#
# Cell In[10], line 2, in search_and_download_papers(query, limit, output_dir)
#       1 def search_and_download_papers(query, limit, output_dir):
# ----> 2     search_query = scholarly.search_pubs(query)
#       3     papers = []
#       4     counter = 0
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_scholarly.py:160, in _Scholarly.search_pubs(self, query, patents, citations, year_low, year_high, sort_by, include_last_year, start_index)
#      97 """Searches by query and returns a generator of Publication objects
#      98
#      99 :param query: terms to be searched
#    (...)
#     155
#     156 """
#     157 url = self._construct_url(_PUBSEARCH.format(requests.utils.quote(query)), patents=patents,
#     158                           citations=citations, year_low=year_low, year_high=year_high,
#     159                           sort_by=sort_by, include_last_year=include_last_year, start_index=start_index)
# --> 160 return self.__nav.search_publications(url)
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:296, in Navigator.search_publications(self, url)
#     288 def search_publications(self, url: str) -> _SearchScholarIterator:
#     289     """Returns a Publication Generator given a url
#     290
#     291     :param url: the url where publications can be found.
#    (...)
#     294     :rtype: {_SearchScholarIterator}
#     295     """
# --> 296     return _SearchScholarIterator(self, url)
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/publication_parser.py:53, in _SearchScholarIterator.__init__(self, nav, url)
#      51 self._pubtype = PublicationSource.PUBLICATION_SEARCH_SNIPPET if "/scholar?" in url else PublicationSource.JOURNAL_CITATION_LIST
#      52 self._nav = nav
# ---> 53 self._load_url(url)
#      54 self.total_results = self._get_total_results()
#      55 self.pub_parser = PublicationParser(self._nav)
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/publication_parser.py:59, in _SearchScholarIterator._load_url(self, url)
#      57 def _load_url(self, url: str):
#      58     # this is temporary until setup json file
# ---> 59     self._soup = self._nav._get_soup(url)
#      60     self._pos = 0
#      61     self._rows = self._soup.find_all('div', class_='gs_r gs_or gs_scl') + self._soup.find_all('div', class_='gsc_mpat_ttl')
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:239, in Navigator._get_soup(self, url)
#     237 def _get_soup(self, url: str) -> BeautifulSoup:
#     238     """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 239     html = self._get_page('https://scholar.google.com{0}'.format(url))
#     240     html = html.replace(u'\xa0', u' ')
#     241     res = BeautifulSoup(html, 'html.parser')
#
# File ~/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/scholarly/_navigator.py:190, in Navigator._get_page(self, pagerequest, premium)
#     188     return self._get_page(pagerequest, True)
#     189 else:
# --> 190     raise MaxTriesExceededException("Cannot Fetch from Google Scholar.")
#
# MaxTriesExceededException: Cannot Fetch from Google Scholar.

# %% [markdown]
# Find terms in file to use as labels

# %%
def search_in_file(pdf_file_path):
    search_results = dict()
    # Extract text from PDF
    with open(pdf_file_path, "rb") as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        for page_num, page in enumerate(pdf_reader.pages):
            # Extract text from the page
            text = page.extract_text()
            if text:
                # Use spaCy to process the text
                doc = nlp(text)
                
                # Detect entities
                for ent in doc.ents:
                    if ent.label_ == "ML_METHOD":
                        if ent.text in search_results:
                            search_results[ent.text].append(page_num + 1)  # Store page number (1-indexed)
                        else:
                            search_results[ent.text] = [page_num + 1]  # Store page number (1-indexed)
    
    # Display search results
    for term, pages in search_results.items():
        if pages:
            print(f"'{term}' found on page(s): {set(pages)}")
        #else:
        #    print(f"'{term}' not found in the document.")

# %%
file_paths = data_df['file_path'].dropna().values.tolist()

# %%
pdf_file_path = file_paths[0]

print(pdf_file_path)
# Out:
# ../../detect_ml_model_files/18d9a07e-aaa5-4cbe-a094-ccc035a96392.pdf

# %%
with open(pdf_file_path, "rb") as pdf_file:
    pdf_reader = PyPDF2.PdfReader(pdf_file)
    for page_num, page in enumerate(pdf_reader.pages):
        # Extract text from the page
        text = page.extract_text()
        break

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent)
# Out:
# Linear regression
# linear regression

# %%
#nlp.add_pipe("sentencizer", before="parser")

# Recreate the Doc object
#doc = nlp(text)

for sentence in doc.sents:
    print(sentence.text)
# Out:
# Linear regression
# Daniel Hsu (COMS 4771)
# Maximum likelihood estimation
# One of the simplest linear regression models is the following: (X1,Y1),..., (Xn,Yn),(X,Y)are iid random
# pairs taking values in Rd×R, and
# Y|X=x∼N(xTw,σ2),x∈Rd.
#
# Here, the vector w∈Rdand scalarσ2>0are the parameters of the model.
# (The marginal distribution of
# Xis unspeciﬁed.)
#
# Thelog-likelihood of(w,σ2)given (Xi,Yi)
# = (xi,yi)fori= 1,...,nis
# n/summationdisplay
# i=1/braceleftBigg
# ln1√
# 2πσ2−(yi−xT
# iw)2
# 2σ2/bracerightBigg
# +T,
# whereTis some quantity that does not depend on (w,σ2).
# Therefore, maximizing the log-likelihood over
# w∈Rd(for anyσ2>0) is the same as minimizing
# 1
# nn/summationdisplay
# i=1(xT
# iw−yi)2.
#
# So, the maximum likelihood estimator (MLE) ofwin this model is
# ˆw∈arg min
# w∈Rd1
# nn/summationdisplay
# i=1(xT
# iw−yi)2.
#
# (It is not necessarily uniquely determined.)
#
# Empirical risk minimization
# LetPnbe the empirical distribution on(x1,y1),..., (xn,yn)∈Rd×R, i.e., the probability distribution over
# Rd×Rwith probability mass function pngiven by
# pn((x,y))
# =1
# nn/summationdisplay
# i=11{(x,y)=(xi,yi)},(x,y)∈Rd×R.
# The distribution assigns probability mass 1/nto each (xi,yi)fori= 1,...,n; no mass is assigned anywhere
# else.
# Now consider (˜X,˜Y)∼Pn.
# The expected squared loss of the linear function w∈Rdon(˜X,˜Y)is
# /hatwideR(w):=E[(˜XTw−˜Y)2] =1
# nn/summationdisplay
# i=1(xT
# iw−yi)2;
# we call this the empirical risk ofwon the data (x1,y1),..., (xn,yn).
#
# 1

# %%
from spacy import displacy

# Render the entities in a Jupyter Notebook or as HTML
# displacy.render(doc, style="ent", jupyter=True)  # Use jupyter=True if in a notebook

options = {"colors": {"ORG": "linear-gradient(90deg, #aa9cfc, #fc9ce7)", "ML_METHOD": "#f6c5be"}}
displacy.render(doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f6c5be; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linear regression
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ML_METHOD</span>
# </mark>
# <br>Daniel Hsu (COMS 4771)<br>Maximum likelihood estimation<br>One of the simplest
# <mark class="entity" style="background: #f6c5be; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     linear regression
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ML_METHOD</span>
# </mark>
#  models is the following: (X1,Y1),..., (Xn,Yn),(X,Y)are iid random<br>pairs taking values in Rd×R, and<br>Y|X=x∼N(xTw,σ2),x∈Rd.<br>Here, the vector w∈Rdand scalarσ2&gt;0are the parameters of the model. (The marginal distribution of<br>Xis unspeciﬁed.)<br>Thelog-likelihood of(w,σ2)given (Xi,Yi) = (xi,yi)fori= 1,...,nis<br>n/summationdisplay<br>i=1/braceleftBigg<br>ln1√<br>2πσ2−(yi−xT<br>iw)2<br>2σ2/bracerightBigg<br>+T,<br>whereTis some quantity that does not depend on (w,σ2). Therefore, maximizing the log-likelihood over<br>w∈Rd(for anyσ2&gt;0) is the same as minimizing<br>1<br>nn/summationdisplay<br>i=1(xT<br>iw−yi)2.<br>So, the maximum likelihood estimator (MLE) ofwin this model is<br>ˆw∈arg min<br>w∈Rd1<br>nn/summationdisplay<br>i=1(xT<br>iw−yi)2.<br>(It is not necessarily uniquely determined.)<br>Empirical risk minimization<br>LetPnbe the empirical distribution on(x1,y1),..., (xn,yn)∈Rd×R, i.e., the probability distribution over<br>Rd×Rwith probability mass function pngiven by<br>pn((x,y)) =1<br>nn/summationdisplay<br>i=11{(x,y)=(xi,yi)},(x,y)∈Rd×R.<br>The distribution assigns probability mass 1/nto each (xi,yi)fori= 1,...,n; no mass is assigned anywhere<br>else. Now consider (˜X,˜Y)∼Pn. The expected squared loss of the linear function w∈Rdon(˜X,˜Y)is<br>/hatwideR(w):=E[(˜XTw−˜Y)2] =1<br>nn/summationdisplay<br>i=1(xT<br>iw−yi)2;<br>we call this the empirical risk ofwon the data (x1,y1),..., (xn,yn).<br>1</div></span>

# %% [markdown]
# Lets only select sentences with a ML_METHOD entity

# %%
# Extract sentences with ML_METHOD entities
filtered_sentences = [
    sentence.text
    for sentence in doc.sents
    if any(ent.label_ == "ML_METHOD" for ent in sentence.ents)
]

# Create a new text containing only those sentences
filtered_text = " ".join(filtered_sentences)

# Create a new Doc object with the filtered text
filtered_doc = nlp(filtered_text)

# Print the filtered sentences
print("Filtered Sentences:")
for sentence in filtered_doc.sents:
    print(sentence.text)
# Out:
# Filtered Sentences:
# Linear regression
# Daniel Hsu (COMS 4771)
# Maximum likelihood estimation
# One of the simplest linear regression models is the following: (X1,Y1),..., (Xn,Yn),(X,Y)are iid random
# pairs taking values in Rd×R, and
# Y|X=x∼N(xTw,σ2),x∈Rd.

# %%
#displacy.render(filtered_doc, style="ent", jupyter=True)  # Use jupyter=True if in a notebook

options = {"colors": {"ML_METHOD": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}}
displacy.render(filtered_doc, style="ent", options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linear regression
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ML_METHOD</span>
# </mark>
# <br>Daniel Hsu (COMS 4771)<br>Maximum likelihood estimation<br>One of the simplest
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     linear regression
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ML_METHOD</span>
# </mark>
#  models is the following: (X1,Y1),..., (Xn,Yn),(X,Y)are iid random<br>pairs taking values in Rd×R, and<br>Y|X=x∼N(xTw,σ2),x∈Rd.<br></div></span>
