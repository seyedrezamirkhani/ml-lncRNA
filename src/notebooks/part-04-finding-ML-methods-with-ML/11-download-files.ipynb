# %% [markdown]
# 1. Recover from previous run
# 2. Find papers matching the ML search term
# 3. Download first five available files
# 4. Save progress

# %%
import pandas as pd

#import spacy
#from spacy.matcher import PhraseMatcher

from scholarly import scholarly
import time

import requests
import mimetypes
import os

import uuid

#import PyPDF2

# %%
ROOT_FOLDER = '../../../'

# %%
DATA_FOLDER = '../../../data/'

# %%
DETECT_ML_MODEL_FILES_FOLDER = '../../../detect_ml_model_files/'

# %%
model_df = pd.read_excel(f'{ROOT_FOLDER}ML-Model-Categorization.ods', sheet_name='Sheet1', usecols=['MODEL'])

# %%
model_df
# Out:
#                                       MODEL
# 0                         Linear Regression
# 1                     Polynomial Regression
# 2                          Ridge Regression
# 3                          Lasso Regression
# 4                    Elastic Net Regression
# ..                                      ...
# 97                                   Claude
# 98                                    LLaMA
# 99   Contrastive Language-Image Pretraining
# 100                                  DALL-E
# 101                        Stable Diffusion
#
# [102 rows x 1 columns]

# %%
models = model_df['MODEL'].values.tolist()

# %%
def search_and_download_papers(query, limit, output_dir):
    search_query = scholarly.search_pubs(query)
    papers = []
    counter = 0

    while(counter < limit):
        try:
            time.sleep(2)  # Introduce delay
            paper = next(search_query)
            paper_info = {
                "title": paper.get("bib", {}).get("title"),
                "abstract": paper.get("bib", {}).get("abstract"),
                "year": paper.get("bib", {}).get("pub_year"),
                "url": paper.get("eprint_url", ""),
                "author_id": paper.get("author_id", []),
                "query": query,
                "file_name": "",
                "file_path": None
            }

            # lets download the file if the url exists
            if paper_info['url']:
                url = paper_info['url']
                try:
                    # Download the file if a link is available
                    response = requests.get(url, stream=True)
                    content_type = response.headers.get('Content-Type', '')
                    # Check if the content type is PDF
                    if 'application/pdf' in content_type or mimetypes.guess_extension(content_type) == '.pdf':
                        unique_filename = str(uuid.uuid4()) + '.pdf'
                        file_path = os.path.join(output_dir, unique_filename)

                        with open(file_path, "wb") as file:
                            for chunk in response.iter_content(chunk_size=8192):
                                file.write(chunk)
                        
                        print(f"Downloaded: {file_path}")                            
                        paper_info['file_name'] = unique_filename
                        paper_info['file_path'] = file_path
                        counter += 1
                    else:
                        print(f"non-PDF content: {url}")             
                except Exception as e:
                    print(f"Error occurred while processing {url}: {e}")                                
            papers.append(paper_info)
        except StopIteration:
            break
        except Exception as e:
            print(f"Error processing paper : {e}")
            continue

    return papers

# %%
merge_with_previous = False

if os.path.isfile(f'{DATA_FOLDER}detect_ml_models.parquet'):
    # recover from previous run
    
    saved_data_df = pd.read_parquet(f'{DATA_FOLDER}detect_ml_models.parquet')

    merge_with_previous = True    
    
    processed_models = saved_data_df['query'].unique().tolist()
    
    unprocessed_models = list()
    
    for model in models:
        if model not in processed_models:
            unprocessed_models.append(model)
else:
    unprocessed_models = models

# %%
search_results = list()
for model in unprocessed_models:
    print(f"Searching for: {model}")    
    papers = search_and_download_papers(query=model, limit=5, output_dir=DETECT_ML_MODEL_FILES_FOLDER)
    search_results.append(papers)
# Out:
# Searching for: AlexNet
# Downloaded: ../../../detect_ml_model_files/d55f2f33-e0a2-43cd-999b-20f8b3cdf9f6.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/09837037.pdf
# Downloaded: ../../../detect_ml_model_files/acacb05f-bde9-4370-a22d-52f9a477a490.pdf
# Downloaded: ../../../detect_ml_model_files/a13052a4-b1b6-43a0-b054-7f7389aa1482.pdf
# Searching for: Recurrent Neural Networks
# non-PDF content: https://www.academia.edu/download/31279335/___Recurrent_Neural_Networks_Design_And_Applicatio(BookFi.org).pdf
# non-PDF content: http://scholarpedia.org/article/Recurrent_neural_network
# Downloaded: ../../../detect_ml_model_files/45fb9693-134c-4a63-ad2c-aaa6cab4e2e4.pdf
# Downloaded: ../../../detect_ml_model_files/81eaf8ac-d0e3-4898-83e9-845ab08dc629.pdf
# Downloaded: ../../../detect_ml_model_files/ec11882c-5e2e-4cc9-92ca-bc9ed257d804.pdf
# Error occurred while processing https://www.cs.bham.ac.uk/~jxb/INC/l12.pdf: HTTPSConnectionPool(host='www.cs.bham.ac.uk', port=443): Max retries exceeded with url: /~jxb/INC/l12.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Downloaded: ../../../detect_ml_model_files/b60f8b2a-4182-4586-be00-8816edf3e4ca.pdf
# Downloaded: ../../../detect_ml_model_files/88f4bc25-602c-4b8b-81cc-83123c6a7376.pdf
# Searching for: Long Short-Term Memory
# Downloaded: ../../../detect_ml_model_files/77a9ce55-ac4f-4e20-b45e-35112214491a.pdf
# Downloaded: ../../../detect_ml_model_files/05ace75d-ff75-4fc7-8506-81b4b376b409.pdf
# Downloaded: ../../../detect_ml_model_files/49c1b2fc-1265-4365-a963-8848941dd2b0.pdf
# non-PDF content: https://documentserver.uhasselt.be/bitstream/1942/31139/3/A_review_on_the_Long_short_term_memory_model.pdf
# Downloaded: ../../../detect_ml_model_files/4675dc35-37d3-4693-8451-71f4a5f49fc4.pdf
# Downloaded: ../../../detect_ml_model_files/61205217-a231-465a-ae08-21122ad18167.pdf
# Searching for: Gated Recurrent Unit
# Downloaded: ../../../detect_ml_model_files/af9f12be-200b-43f5-adc1-f9b10f1f5583.pdf
# non-PDF content: https://arxiv.org/pdf/1412.3555)
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1877050918306781/pdf?md5=8fa8aaa498de3fdd3d072fa88129975b&pid=1-s2.0-S1877050918306781-main.pdf
# non-PDF content: https://www.researchgate.net/profile/Rui-Zhao-33/publication/318798874_Machine_Health_Monitoring_Using_Local_Feature-based_Gated_Recurrent_Unit_Networks/links/5a4749f4458515f6b055de41/Machine-Health-Monitoring-Using-Local-Feature-Based-Gated-Recurrent-Unit-Networks.pdf
# Downloaded: ../../../detect_ml_model_files/59fde444-678e-4103-9697-520d2ccc4401.pdf
# non-PDF content: https://www.mdpi.com/1996-1073/11/8/2163
# Downloaded: ../../../detect_ml_model_files/786b1ae6-cb35-4575-bf57-1cde556aaf59.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/08449272.pdf
# non-PDF content: https://iopscience.iop.org/article/10.1088/1742-6596/1325/1/012089/pdf
# Downloaded: ../../../detect_ml_model_files/687f6076-df20-458c-80c7-ff43129693db.pdf
# Downloaded: ../../../detect_ml_model_files/1c4b3ce1-59da-4040-87d0-ba194591f3a1.pdf
# Searching for: Bidirectional RNNs
# Downloaded: ../../../detect_ml_model_files/a7b7c986-e9cb-45f6-9235-e74f17336034.pdf
# Downloaded: ../../../detect_ml_model_files/88f0e918-d6a9-458f-8f17-2128b26bfc6e.pdf
# Downloaded: ../../../detect_ml_model_files/5fab93f3-125f-4140-a1a8-f3d85be17c43.pdf
# Downloaded: ../../../detect_ml_model_files/5539a0c4-71c5-4b74-a87d-03ded323dd35.pdf
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5119627/
# Downloaded: ../../../detect_ml_model_files/d2a08206-b360-4335-93e4-20f227e3eef8.pdf
# Searching for: Transformer
# Downloaded: ../../../detect_ml_model_files/4cd14658-6155-4aad-92c0-78b1a163b1ec.pdf
# Downloaded: ../../../detect_ml_model_files/fad755bf-911b-4aa3-bd2f-9d8548e00228.pdf
# Downloaded: ../../../detect_ml_model_files/0acc2e62-830f-4dc4-adf4-cbab7b46ef1a.pdf
# Downloaded: ../../../detect_ml_model_files/9b9ab483-1e10-4c77-a0a2-c94a558d02ec.pdf
# Downloaded: ../../../detect_ml_model_files/0a292ef1-aa00-4a93-8eab-3be804593098.pdf
# Searching for: Bidirectional Encoder Representations from Transformers
# Downloaded: ../../../detect_ml_model_files/98576d7c-c982-4799-895c-75786655278a.pdf
# Searching for: Generative Pretrained Transformers
# Downloaded: ../../../detect_ml_model_files/e2ea108e-e6b0-4e43-bd47-37743862e4d9.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/10500411.pdf
# Downloaded: ../../../detect_ml_model_files/ad62caf5-900c-45fc-9371-cb99747c1ac0.pdf
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9796173/
# Downloaded: ../../../detect_ml_model_files/3412671b-d488-40ab-a7bc-c1a49596c779.pdf
# Downloaded: ../../../detect_ml_model_files/d8ec61f8-74b0-4d57-8bb6-f4c59e454d6d.pdf
# Downloaded: ../../../detect_ml_model_files/9e198b0f-df16-4916-8a77-2b28d10ac0be.pdf
# Searching for: Text-to-Text Transfer Transformer
# Downloaded: ../../../detect_ml_model_files/9890ec5a-b422-4590-8815-e8ab2950ba4d.pdf
# Downloaded: ../../../detect_ml_model_files/68c5bf4c-04e1-40d3-815b-e97bcf30cf1e.pdf
# Downloaded: ../../../detect_ml_model_files/518fffae-f1b7-4014-9b79-c753460e9706.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S0957417422014014
# Downloaded: ../../../detect_ml_model_files/a720c2cc-a927-4362-8f3e-eaec97802319.pdf
# Downloaded: ../../../detect_ml_model_files/269ebb41-9d21-440e-aa15-983e3c7fb169.pdf
# Searching for: Vision Transformers
# Downloaded: ../../../detect_ml_model_files/5f9c9fc5-1b7c-40d2-8f86-e136565a7e9a.pdf
# Downloaded: ../../../detect_ml_model_files/21800c4b-03c1-4fe8-862c-daca8628d9e2.pdf
# Downloaded: ../../../detect_ml_model_files/4faea2b7-fb9a-42ff-a62f-44481fd816a5.pdf
# Downloaded: ../../../detect_ml_model_files/dbfe1fa0-8ae7-4ec9-a980-b80522747043.pdf
# Downloaded: ../../../detect_ml_model_files/ffcf3fe2-7541-4095-a1ae-c826d1507783.pdf
# Searching for: Swin Transformer
# Downloaded: ../../../detect_ml_model_files/1acbb9e3-e370-46cc-8b5b-99a204dfd63d.pdf
# Downloaded: ../../../detect_ml_model_files/232ed48d-b1f1-4ce9-b6d6-83d5b9a67b6e.pdf
# Downloaded: ../../../detect_ml_model_files/2d80fe17-a4b8-471a-9acc-5691ce7c6475.pdf
# Downloaded: ../../../detect_ml_model_files/45890e27-bcc3-4343-b044-e0c816bdec19.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S0925231222004179
# Downloaded: ../../../detect_ml_model_files/c9f1fe9f-eec3-4243-b09c-ef52544be903.pdf
# Searching for: Generative Adversarial Networks
# non-PDF content: https://dl.acm.org/doi/fullHtml/10.1145/3422622
# Downloaded: ../../../detect_ml_model_files/5d0b84a2-d7c0-4e95-ba7a-d502c0d56c2d.pdf
# Downloaded: ../../../detect_ml_model_files/2f755716-4de3-40e5-b721-eb5b59f887b5.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6570654/8039012/08039016.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S2667096820300045
# Downloaded: ../../../detect_ml_model_files/c543de28-8400-4154-9f29-7a42b542601b.pdf
# Downloaded: ../../../detect_ml_model_files/41dc3cf0-203d-4fac-8c94-09fba01505e1.pdf
# Downloaded: ../../../detect_ml_model_files/4a94e1d1-0e60-4053-8a30-5d50e1748043.pdf
# Searching for: Variational Autoencoders
# Downloaded: ../../../detect_ml_model_files/dc946e58-09e7-4946-849a-ecc696f838b0.pdf
# Downloaded: ../../../detect_ml_model_files/f5b7d86f-a30a-4bc6-88db-19e764b2946b.pdf
# Downloaded: ../../../detect_ml_model_files/5f11ef1c-336e-4b74-ba70-dbf487ac4448.pdf
# Downloaded: ../../../detect_ml_model_files/f7ec3c64-f34e-4e06-afe7-f3ba511fafb1.pdf
# non-PDF content: https://www.researchgate.net/profile/Jiaming-Song-4/publication/317399341_InfoVAE_Information_Maximizing_Variational_Autoencoders/links/5963f0b90f7e9b819497cf5d/InfoVAE-Information-Maximizing-Variational-Autoencoders.pdf
# non-PDF content: https://dl.acm.org/doi/fullHtml/10.1145/3178876.3186150
# Downloaded: ../../../detect_ml_model_files/15cfac3d-6d1d-4c8c-ab57-ecb79ea289d3.pdf
# Searching for: Normalizing Flows
# Downloaded: ../../../detect_ml_model_files/68e84a27-3375-4322-b051-b03302411ab9.pdf
# Downloaded: ../../../detect_ml_model_files/ff299694-ed5d-4376-af2e-bf3d08f14098.pdf
# Downloaded: ../../../detect_ml_model_files/226d7bb1-4a5c-454a-999e-23998528f04c.pdf
# non-PDF content: https://www.academia.edu/download/77807856/1908.09257v1.pdf
# Downloaded: ../../../detect_ml_model_files/c9e1cf47-1aa9-42b7-8413-f7e51f125566.pdf
# Downloaded: ../../../detect_ml_model_files/488c02f0-99ee-4a8c-919a-b9b60ca909bd.pdf
# Searching for: Diffusion Models
# Downloaded: ../../../detect_ml_model_files/3ae99bf2-f418-418c-895d-4623a1438ba0.pdf
# Downloaded: ../../../detect_ml_model_files/67573c4c-515f-486a-99b9-65025bbd506f.pdf
# Downloaded: ../../../detect_ml_model_files/0f10a50c-ba89-4bc8-82ee-c33ffb6fd89e.pdf
# Downloaded: ../../../detect_ml_model_files/0d124f73-6fb3-4a37-ba0f-e6594bc97bf4.pdf
# Downloaded: ../../../detect_ml_model_files/63a674b0-4b1e-4abe-97e3-b05682fed9ef.pdf
# Searching for: Stable Diffusion
# Downloaded: ../../../detect_ml_model_files/a0f48464-91b5-4042-8367-1fd25787486a.pdf
# Downloaded: ../../../detect_ml_model_files/8fc43240-816a-4c9e-9390-7014153c755a.pdf
# Downloaded: ../../../detect_ml_model_files/30ef4f90-031a-4f87-870f-d037d6df1165.pdf
# Downloaded: ../../../detect_ml_model_files/e83ac769-c99c-44da-bfc8-bcff52202f51.pdf
# Downloaded: ../../../detect_ml_model_files/74bd708d-cb11-47de-b581-103ff776b969.pdf
# Searching for: Denoising Diffusion Probabilistic Models
# Downloaded: ../../../detect_ml_model_files/05dbb63f-b611-4b3f-a7dd-d8d7d1e8de59.pdf
# Downloaded: ../../../detect_ml_model_files/8a742184-34b4-47ed-a868-9dda34f18813.pdf
# Downloaded: ../../../detect_ml_model_files/89ef70c6-2ac5-4dee-8898-dd668bb8a88e.pdf
# Downloaded: ../../../detect_ml_model_files/82b8458e-af42-4a65-baf1-3deafbdd544a.pdf
# Downloaded: ../../../detect_ml_model_files/c01335a9-3d48-4980-8a99-107a4b731182.pdf
# Searching for: Bayesian Networks
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1002/9780470061572.eqr089
# Downloaded: ../../../detect_ml_model_files/3c4dce33-9dcf-4918-916b-752485157f5c.pdf
# non-PDF content: https://www.academia.edu/download/109640965/L-G-0000577632-0002359428.pdf
# Downloaded: ../../../detect_ml_model_files/8a4163b6-f8e5-4d2d-a44f-697d8b6bb261.pdf
# non-PDF content: https://www.academia.edu/download/49772229/bayes.pdf
# Downloaded: ../../../detect_ml_model_files/d7d60aa3-f1ab-492f-af80-d5fa9ba6137c.pdf
# Downloaded: ../../../detect_ml_model_files/fdfca1c0-585f-448f-8810-0eed95096312.pdf
# Downloaded: ../../../detect_ml_model_files/c45a99b7-501a-4eb2-ab66-fd1b86285019.pdf
# Searching for: Markov Chains
# Downloaded: ../../../detect_ml_model_files/3119a81f-f449-4916-86db-8dcec0822f7b.pdf
# Downloaded: ../../../detect_ml_model_files/f4e77bbf-6736-43d9-a0aa-c0e18325d9dc.pdf
# Downloaded: ../../../detect_ml_model_files/ce1b11ec-3b82-4fd5-af80-3f4dec6c5334.pdf
# non-PDF content: https://www.researchgate.net/profile/Sean-Meyn/publication/200111118_Markov_Chains_and_Stochastic_Stability/links/0912f50db2411475d1000000/Markov-Chains-and-Stochastic-Stability.pdf
# Downloaded: ../../../detect_ml_model_files/a983b3d8-9e35-4fe6-b63b-88fc8a1bee24.pdf
# Downloaded: ../../../detect_ml_model_files/7062ffb5-75c2-4a65-8279-e709cd83e632.pdf
# Searching for: Hidden Markov Models
# Downloaded: ../../../detect_ml_model_files/55614503-93fe-4c20-a9c1-9050ca18e27d.pdf
# non-PDF content: https://www.academia.edu/download/31037917/Rabiner1986_An_Introduction_to_Hidden_Markov_Models.pdf
# Downloaded: ../../../detect_ml_model_files/c3cf5448-af44-402c-91cc-3515ec07332c.pdf
# Downloaded: ../../../detect_ml_model_files/bc572a10-3b4a-46ef-bb0e-128f90a2828a.pdf
# non-PDF content: https://academic.oup.com/bioinformatics/article-pdf/14/9/755/48836580/bioinformatics_14_9_755.pdf
# non-PDF content: https://ikcest.org/journal-3027312.htm
# Downloaded: ../../../detect_ml_model_files/ce360620-9371-4a34-8383-0b15b7e3bc7a.pdf
# Downloaded: ../../../detect_ml_model_files/a51ecf18-2fb0-42cc-bbef-f5881c8064b3.pdf
# Searching for: Kalman Filters
# Downloaded: ../../../detect_ml_model_files/80baff79-afda-426a-8bb4-c09a75455664.pdf
# non-PDF content: https://www.researchgate.net/profile/Kaifan-Ji/publication/305871722_Kalman_Filter_and_Its_Application/links/6415a6a8a1b72772e408cc64/Kalman-Filter-and-Its-Application.pdf
# non-PDF content: https://www.academia.edu/download/81315221/kalman.pdf
# non-PDF content: https://www.intechopen.com/chapters/63164
# Error occurred while processing http://abel.math.harvard.edu/archive/116_fall_03/handouts/kalman.pdf: HTTPSConnectionPool(host='abel.math.harvard.edu', port=443): Max retries exceeded with url: /archive/116_fall_03/handouts/kalman.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Downloaded: ../../../detect_ml_model_files/488c7f95-6307-4142-8a05-efb5d3251af2.pdf
# non-PDF content: https://www.academia.edu/download/52484748/Kalman_CoursePack_08.pdf
# Downloaded: ../../../detect_ml_model_files/8129c6aa-69cb-42c3-9d32-9a3177227bd2.pdf
# non-PDF content: https://www.academia.edu/download/52364275/Kalman_filtering_using_Matlab.pdf
# Downloaded: ../../../detect_ml_model_files/6cf5bc12-83a7-4824-a414-09a87d84096d.pdf
# Downloaded: ../../../detect_ml_model_files/271fb436-6949-402a-be27-372514b57dfb.pdf
# Searching for: Conditional Random Fields
# Downloaded: ../../../detect_ml_model_files/d65c0c0d-237c-4773-8c7e-2e7a1e702dbd.pdf
# Downloaded: ../../../detect_ml_model_files/10bcd909-eda6-48b4-9965-be2ddd05eee7.pdf
# Downloaded: ../../../detect_ml_model_files/35c3aec3-a12d-459e-b171-4c6297641b11.pdf
# Downloaded: ../../../detect_ml_model_files/0af850d9-b151-42f7-a204-4d3c35bd53ca.pdf
# Downloaded: ../../../detect_ml_model_files/0f083eef-c3a9-4fcc-962f-6ac8bc585111.pdf
# Searching for: Graph Neural Networks
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S2666651021000012
# non-PDF content: https://ieeexplore.ieee.org/ielaam/5962385/9312808/9046288-aam.pdf
# Downloaded: ../../../detect_ml_model_files/3b52190c-9c33-4eca-a84e-05d2148b7413.pdf
# Downloaded: ../../../detect_ml_model_files/1d095495-a52d-42b0-b1f6-0447bd784d0e.pdf
# Downloaded: ../../../detect_ml_model_files/a88c1232-e0d4-49b3-878f-a273154049ab.pdf
# Downloaded: ../../../detect_ml_model_files/3ef2fd6e-44ab-4824-9881-81c622c3de02.pdf
# Downloaded: ../../../detect_ml_model_files/5ab6042c-4c18-40b4-9664-252bbcf48b3f.pdf
# Searching for: Graph Convolutional Networks
# non-PDF content: https://link.springer.com/article/10.1186/s40649-019-0069-y
# Downloaded: ../../../detect_ml_model_files/b453c98b-ef30-467d-bd64-9b5207ccc5fd.pdf
# Downloaded: ../../../detect_ml_model_files/4bca3954-c085-4ae6-8783-b1f233445430.pdf
# Downloaded: ../../../detect_ml_model_files/0739f519-3c5b-4edf-85f7-c9ce0d7ae7ea.pdf
# Downloaded: ../../../detect_ml_model_files/062f09ce-bb99-407d-90a0-9b308f8f8e2c.pdf
://journals.plos.org/plosone/article?id=10.1371/journal.pone.0156768
# Downloaded: ../../../detect_ml_model_files/a5b9390d-8202-4202-bc9a-4bbf29213837.pdf
# Searching for: Seasonal ARIMA
# Downloaded: ../../../detect_ml_model_files/28cd27a8-f4d8-4ab3-a0d7-73546ab57ab8.pdf
# non-PDF content: https://www.ias.ac.in/article/fulltext/jess/129/00/0149
# Downloaded: ../../../detect_ml_model_files/15c7a7df-7bda-4288-919a-ff5858ff9848.pdf
# non-PDF content: https://link.springer.com/article/10.1007/s12544-015-0170-8
# Downloaded: ../../../detect_ml_model_files/cfc8837a-31d0-4cca-88a2-6c95c3bac2f2.pdf
# non-PDF content: https://www.researchgate.net/profile/Jiakun-Liu-7/publication/30952666_Wireless_Traffic_Modeling_and_Prediction_Using_Seasonal_ARIMA_Models/links/5839079608aef00f3bfa3e10/Wireless-Traffic-Modeling-and-Prediction-Using-Seasonal-ARIMA-Models.pdf
# Downloaded: ../../../detect_ml_model_files/f66d8cc0-55bc-4913-b8c8-1804a4cc5277.pdf
# non-PDF content: https://www.academia.edu/download/4477613/07p.pdf
# Error occurred while processing https://scirp.org/html/59043_59043.htm: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Downloaded: ../../../detect_ml_model_files/ac476e2e-7c97-454d-b20a-edf9ed679203.pdf
# Searching for: Vector Autoregression
# non-PDF content: https://pubs.aeaweb.org/doi/pdf/10.1257/jep.15.4.101
# Downloaded: ../../../detect_ml_model_files/74f7526e-b15c-44cd-b298-dc8e738cf154.pdf
# Downloaded: ../../../detect_ml_model_files/b842e35f-8666-4901-ab3c-27dc8d87cbf7.pdf
# non-PDF content: https://journals.sagepub.com/doi/full/10.1177/1536867X1601600314
# Downloaded: ../../../detect_ml_model_files/be3bf1ea-a57b-4f8a-b3d9-f904981afe88.pdf
# Downloaded: ../../../detect_ml_model_files/174a8120-e7ba-4781-88bf-eec8954168ad.pdf
# Downloaded: ../../../detect_ml_model_files/acd324b8-a592-4d79-9ec2-ebf2ebd5e068.pdf
# Searching for: State-Space Models
# Downloaded: ../../../detect_ml_model_files/3742e904-8423-4fa3-a50f-8eae458209b7.pdf
# Downloaded: ../../../detect_ml_model_files/44ba1a9c-353a-4c7e-bc0a-c01481f11e8a.pdf
# non-PDF content: https://figshare.utas.edu.au/articles/journal_contribution/State-space_models_of_individual_animal_movement/22869671/1/files/40607345.pdf
# Downloaded: ../../../detect_ml_model_files/51afba14-d181-40d2-aee3-eb600d26f1c1.pdf
# Downloaded: ../../../detect_ml_model_files/e22840db-2e3a-4578-aa97-4b72ea196e8d.pdf
# non-PDF content: https://www.diva-portal.org/smash/get/diva2:650693/FULLTEXT01.pdf
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3712521/
# non-PDF content: https://www.researchgate.net/profile/Bart-De-Moor/publication/2688250_On-_and_Off-Line_Identification_of_Linear_State_Space_Models/links/56c471d408ae7fd4625a20d0/On-and-Off-Line-Identification-of-Linear-State-Space-Models.pdf
# Downloaded: ../../../detect_ml_model_files/75bfa041-8ac9-4262-8e1a-4cd30821e617.pdf
# Searching for: Prophet
# Downloaded: ../../../detect_ml_model_files/82830706-3a24-467d-af79-2c275441f898.pdf
# Downloaded: ../../../detect_ml_model_files/1774631d-137f-4bde-813b-36c89b6be88e.pdf
# non-PDF content: https://marxists.architexturez.net/francais/harman/1994/00/propheteproletariat.pdf
# non-PDF content: https://books.google.com/books?hl=en&lr=&id=L2AzAQAAMAAJ&oi=fnd&pg=PR34&dq=Prophet&ots=JiZY8Qyi2K&sig=pcWeI5EefS5o61Hr8HdKVcBlM8A
# Downloaded: ../../../detect_ml_model_files/17f9431b-c016-4871-91b1-ad76cee033f6.pdf
# Downloaded: ../../../detect_ml_model_files/ffd945ab-7b6b-4c84-a664-9597633e2a8d.pdf
# non-PDF content: https://classes.matthewjbrown.net/teaching-files/pragmatism/rorty-west.pdf
# non-PDF content: https://www.academia.edu/download/114611210/Prophet_MobileOPT.pdf
# Downloaded: ../../../detect_ml_model_files/3721b9a6-297c-455a-8934-bef40027d8da.pdf
# Searching for: Bagging
# Downloaded: ../../../detect_ml_model_files/10042c8b-c0f2-46c6-af6f-a3807978dbf8.pdf
# Downloaded: ../../../detect_ml_model_files/45de3cb9-9cd4-4a63-bce5-ad9983318d4a.pdf
# Downloaded: ../../../detect_ml_model_files/53565554-ef2e-4b26-8654-03b1b547f04d.pdf
# Downloaded: ../../../detect_ml_model_files/f06319e9-8aed-4ccb-b53e-8062928907ed.pdf
# non-PDF content: https://academic.oup.com/bioinformatics/article-pdf/19/9/1090/48904210/bioinformatics_19_9_1090.pdf
# Downloaded: ../../../detect_ml_model_files/31e2ecb6-170a-47e9-b58a-65f0a5169cc7.pdf
# Searching for: Boosting
# Downloaded: ../../../detect_ml_model_files/4012eea7-29a4-4c36-854c-1a2136987e4f.pdf
# Downloaded: ../../../detect_ml_model_files/4e91df36-3504-4a07-940c-91e0b0981b6a.pdf
# Downloaded: ../../../detect_ml_model_files/c5c393f3-68d2-45c7-a078-c316bb75e141.pdf
# Downloaded: ../../../detect_ml_model_files/56fe95fa-3f6b-4c67-970b-1a1b5a57f1c9.pdf
# Downloaded: ../../../detect_ml_model_files/3199504c-e1f8-422e-ab01-523167f4ec24.pdf
# Searching for: AdaBoost
# non-PDF content: http://rob.schapire.net/papers/explaining-adaboost.pdf
# Downloaded: ../../../detect_ml_model_files/f0aeb83e-636d-4188-8079-ba464458d802.pdf
# Downloaded: ../../../detect_ml_model_files/985c2907-6026-4ae8-81b2-e6a14c0a0d9a.pdf
# Downloaded: ../../../detect_ml_model_files/f4c81544-f120-4445-9adc-ba8817d053cc.pdf
# Downloaded: ../../../detect_ml_model_files/476d5c25-93e1-4308-8c2b-da4cc96bcfa4.pdf
# non-PDF content: https://www.researchgate.net/profile/Durga-Shrestha/publication/4116773_AdaBoostRT_A_boosting_algorithm_for_regression_problems/links/560b88ed08ae4d86bb14d019/AdaBoostRT-A-boosting-algorithm-for-regression-problems.pdf
# Downloaded: ../../../detect_ml_model_files/b63e1a66-c5e9-4a53-a7b5-276c30b55c2d.pdf
# Searching for: Gradient Boosting
# non-PDF content: https://www.frontiersin.org/articles/10.3389/fnbot.2013.00021/full
# Downloaded: ../../../detect_ml_model_files/d77947b6-8cdc-40e9-90a3-6327f3eefbeb.pdf
pdf
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2109050/pdf/390.pdf
# non-PDF content: https://www.academia.edu/download/53327743/Claude_1966_-_Collective_legitimization.pdf
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4549775/
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2108163/pdf/745.pdf
# Downloaded: ../../../detect_ml_model_files/51f882d4-cbe6-4619-bb22-9be9eb413ea5.pdf
# non-PDF content: https://www.cell.com/AJHG/fulltext/S0002-9297(07)63848-8
# non-PDF content: https://www.thelancet.com/journals/lanonc/article/PIIS1470-2045(11)70404-1/fulltext?_eventId\u003dlogin=
# non-PDF content: https://erc.bioscientifica.com/view/journals/erc/12/4/0121071.xml
# non-PDF content: https://jamanetwork.com/journals/jama/fullarticle/184706
# Downloaded: ../../../detect_ml_model_files/87327aba-0fb0-4de2-983f-0b81df459470.pdf
# Downloaded: ../../../detect_ml_model_files/88fa219b-e1d2-4436-bae1-bcf2e3e11684.pdf
# Downloaded: ../../../detect_ml_model_files/5df86ac6-995c-4eda-baf5-dc3542d4e967.pdf
# Searching for: LLaMA
# Downloaded: ../../../detect_ml_model_files/469b4e3d-f4dd-4b56-8b02-9df6de156361.pdf
# Downloaded: ../../../detect_ml_model_files/21c7ff7d-62a9-41b5-a546-3ec7d0f5e544.pdf
# Downloaded: ../../../detect_ml_model_files/60f35928-4d8d-4471-aa48-342833f9ddb9.pdf
# non-PDF content: https://www.academia.edu/download/97151133/Llama_constellation_ALL09_Zuidema_Urton.pdf
# Downloaded: ../../../detect_ml_model_files/0f4b8034-a5ce-4f2b-abd5-89e846a2a710.pdf
# Downloaded: ../../../detect_ml_model_files/2dab2d8d-fb02-4d1f-bff9-326a89ef304e.pdf
# Searching for: Contrastive Language-Image Pretraining
# Downloaded: ../../../detect_ml_model_files/83665925-0b01-46fb-949b-db1f615bcfc0.pdf
# Downloaded: ../../../detect_ml_model_files/d17bcb70-ea00-44b0-ad7e-1ca3b800818b.pdf
# Downloaded: ../../../detect_ml_model_files/4aaec827-febb-4f05-a718-64646428bdbb.pdf
# Downloaded: ../../../detect_ml_model_files/13205012-67a5-4c40-9ed0-5e29303f0ebc.pdf
# Downloaded: ../../../detect_ml_model_files/eb3019e2-2f74-417e-aa55-87920118742a.pdf
# Searching for: DALL-E
# Downloaded: ../../../detect_ml_model_files/dbf6f4a7-d190-4bab-95fb-009e90a45dbd.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S0300908415002977
# Downloaded: ../../../detect_ml_model_files/2cca562e-cc65-4ab0-8ea4-c961bbb7b787.pdf
# Downloaded: ../../../detect_ml_model_files/bfc5a9b5-cee0-4809-8939-82cd3c41b8cc.pdf
# non-PDF content: https://www.pnas.org/doi/full/10.1073/pnas.1300686110
# non-PDF content: https://www.academia.edu/download/38103019/1990_Phytoplankton_biomass_reduction_HYDROBIOLOGIA.pdf
# non-PDF content: https://www.academia.edu/download/46836054/Evaluation_of_toxicity_of_Calophyllum_br20160627-11991-1f1n5dw.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1751616116303204
# non-PDF content: https://www.nature.com/articles/ncomms14740
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1002/anie.201409135
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3253828/
# non-PDF content: https://academic.oup.com/plcell/article/30/3/686/6099146?versioned=true
# non-PDF content: https://pubs.acs.org/doi/full/10.1021/acscatal.7b01505
# Downloaded: ../../../detect_ml_model_files/a204b81b-a54e-44e7-bacd-8c363814e55e.pdf
# non-PDF content: https://www.jbc.org/article/S0021-9258(20)37206-9/abstract
# non-PDF content: https://www.jbc.org/article/S0021-9258(17)49963-7/abstract
# non-PDF content: https://www.nature.com/articles/srep12707
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1111/all.14481
# non-PDF content: https://www.jmir.org/2023/1/e43110/
# non-PDF content: https://pubs.acs.org/doi/full/10.1021/acs.analchem.9b03604
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1111/tpj.16458
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6572096/
# non-PDF content: https://www.jbc.org/article/S0021-9258(20)31024-3/abstract
# Downloaded: ../../../detect_ml_model_files/bfc4d64a-1bda-46c3-9b6c-22878a2f3ad0.pdf
# Searching for: Stable Diffusion
# Downloaded: ../../../detect_ml_model_files/0874bbf1-55fa-4df9-8a07-c6c15ac91c84.pdf
# Downloaded: ../../../detect_ml_model_files/e1e814fc-7dea-43b0-8049-928fee635bd7.pdf
# Downloaded: ../../../detect_ml_model_files/37f5b622-ff4e-4405-b63e-4d13c5738a88.pdf
# Downloaded: ../../../detect_ml_model_files/214899da-c78e-42d2-9a7d-0368daa239d6.pdf
# Downloaded: ../../../detect_ml_model_files/9efca518-66c0-464d-a678-8046ccad31da.pdf

# %%
# can do it in one line but is it easier to read?
# flattened_search_results = [paper for paper in papers for papers in search_results]
flattened_search_results = list()
for papers in search_results:
    for paper in papers:
        flattened_search_results.append(paper)

# %%
data_df = pd.DataFrame(flattened_search_results)

# %%
data_df
# Out:
#                                                  title  \
# 0    The history began from alexnet: A comprehensiv...
# 1    Visualizing and comparing AlexNet and VGG usin...
# 2    Inceptiontime: Finding alexnet for time series...
# 3    Feature extraction and image retrieval based o...
# 4    Modified Alexnet architecture for classificati...
# ..                                                 ...
# 531  Generated faces in the wild: Quantitative comp...
# 532  What the daam: Interpreting stable diffusion u...
# 533     Red-teaming the stable diffusion safety filter
# 534  Stable video diffusion: Scaling latent video d...
# 535  The stable signature: Rooting watermarks in la...
#
#                                               abstract  year  \
# 0    Deep learning has demonstrated tremendous succ...  2018
# 1    In Figure 6, we compare the process carried by...  2016
# 2    This paper brings deep learning at the forefro...  2020
# 3    Convolutional Neural Network is a hot research...  2016
# 4    CNN has different architectures like Le-Net, A...  2019
# ..                                                 ...   ...
# 531  popular systems including Stable Diffusion, Mi...  2022
# 532  We probe Stable Diffusion to provide insight i...  2022
# 533  We conclude that the Stable Diffusion safety f...  2022
# 534  We present Stable Video Diffusion — a latent v...  2023
# 535  Generative image modeling enables a wide range...  2023
#
#                                                    url  \
# 0    https://saulius-grazulis.lt/~saulius/paskaitos...
# 1    https://icmlviz.github.io/icmlviz2016/assets/p...
# 2                     https://arxiv.org/pdf/1909.04939
# 3
# 4
# ..                                                 ...
# 531                   https://arxiv.org/pdf/2210.00586
# 532     https://aclanthology.org/2023.acl-long.310.pdf
# 533                   https://arxiv.org/pdf/2210.04610
# 534                   https://arxiv.org/pdf/2311.15127
# 535  https://openaccess.thecvf.com/content/ICCV2023...
#
#                                              author_id             query  \
# 0                     [JU07ZEsAAAAJ, HcOrvg8AAAAJ, , ]           AlexNet
# 1    [x2qhqtwAAAAJ, g2gAY_0AAAAJ, iYMBoHwAAAAJ, DaK...           AlexNet
# 2           [oUrGNaoAAAAJ, Axtv4-kAAAAJ, QDtJYqkAAAAJ]           AlexNet
# 3                                                 [, ]           AlexNet
# 4                         [hD2nQ3MAAAAJ, Xu_v8kAAAAAJ]           AlexNet
# ..                                                 ...               ...
# 531                                     [7jTNT1IAAAAJ]  Stable Diffusion
# 532  [3icAgxMAAAAJ, tQU-BXIAAAAJ, G-2DepMAAAAJ, eJ5...  Stable Diffusion
# 533  [d_rilUYAAAAJ, 9e_KfoEAAAAJ, p_aH5fgAAAAJ, Au7...  Stable Diffusion
# 534         [vud0t5YAAAAJ, EtPn_v4AAAAJ, 1bYESBYAAAAJ]  Stable Diffusion
# 535         [osCX1YQAAAAJ, O1DeDyEAAAAJ, 1lcY2z4AAAAJ]  Stable Diffusion
#
#                                     file_name  \
# 0    d55f2f33-e0a2-43cd-999b-20f8b3cdf9f6.pdf
# 1    b5e4a3c0-105f-4e27-8206-93cfcdada0e5.pdf
# 2    e5286cab-0f74-4066-bbd7-90d2c09b682e.pdf
# 3
# 4
# ..                                        ...
# 531  0874bbf1-55fa-4df9-8a07-c6c15ac91c84.pdf
# 532  e1e814fc-7dea-43b0-8049-928fee635bd7.pdf
# 533  37f5b622-ff4e-4405-b63e-4d13c5738a88.pdf
# 534  214899da-c78e-42d2-9a7d-0368daa239d6.pdf
# 535  9efca518-66c0-464d-a678-8046ccad31da.pdf
#
#                                              file_path
# 0    ../../../detect_ml_model_files/d55f2f33-e0a2-4...
# 1    ../../../detect_ml_model_files/b5e4a3c0-105f-4...
# 2    ../../../detect_ml_model_files/e5286cab-0f74-4...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 531  ../../../detect_ml_model_files/0874bbf1-55fa-4...
# 532  ../../../detect_ml_model_files/e1e814fc-7dea-4...
# 533  ../../../detect_ml_model_files/37f5b622-ff4e-4...
# 534  ../../../detect_ml_model_files/214899da-c78e-4...
# 535  ../../../detect_ml_model_files/9efca518-66c0-4...
#
# [536 rows x 8 columns]

# %%
if merge_with_previous:
    data_df = pd.concat([saved_data_df, data_df], ignore_index=True)

# %%
data_df
# Out:
#                                                   title  \
# 0                                     Linear regression
# 1            Introduction to linear regression analysis
# 2                                     Linear regression
# 3                                     Linear regression
# 4                             Applied linear regression
# ...                                                 ...
# 1229  Generated faces in the wild: Quantitative comp...
# 1230  What the daam: Interpreting stable diffusion u...
# 1231     Red-teaming the stable diffusion safety filter
# 1232  Stable video diffusion: Scaling latent video d...
# 1233  The stable signature: Rooting watermarks in la...
#
#                                                abstract  year  \
# 0     Linear regression plays a fundamental role in ...  2012
# 1     Equation (1.2) is called a linear regression m...  2021
# 2     linear regression, a very simple approach for ...  2023
# 3     In linear regression the ordinary least square...  2012
# 4     Applied linear regression Applied linear regre...  2005
# ...                                                 ...   ...
# 1229  popular systems including Stable Diffusion, Mi...  2022
# 1230  We probe Stable Diffusion to provide insight i...  2022
# 1231  We conclude that the Stable Diffusion safety f...  2022
# 1232  We present Stable Video Diffusion — a latent v...  2023
# 1233  Generative image modeling enables a wide range...  2023
#
#                                                     url  \
# 0     https://www.cs.columbia.edu/~djhsu/coms4771-f2...
# 1     http://sutlib2.sut.ac.th/sut_contents/H133678.pdf
# 2          https://datamineaz.org/readings/ISL_chp3.pdf
# 3
# 4     https://www.stat.cmu.edu/~brian/valerie/617-20...
# ...                                                 ...
# 1229                   https://arxiv.org/pdf/2210.00586
# 1230     https://aclanthology.org/2023.acl-long.310.pdf
# 1231                   https://arxiv.org/pdf/2210.04610
# 1232                   https://arxiv.org/pdf/2311.15127
# 1233  https://openaccess.thecvf.com/content/ICCV2023...
#
#                                               author_id              query  \
# 0                        [wcgZZP8AAAAJ, , El-UNYoAAAAJ]  Linear Regression
# 1                        [5PboKNAAAAAJ, , y2eb6cQAAAAJ]  Linear Regression
# 2     [KUIjZqgAAAAJ, bHZf-c8AAAAJ, tQVe-fAAAAAJ, ZpG...  Linear Regression
# 3                                        [vBWC0XIAAAAJ]  Linear Regression
# 4                                        [wlu6jZQAAAAJ]  Linear Regression
# ...                                                 ...                ...
# 1229                                     [7jTNT1IAAAAJ]   Stable Diffusion
# 1230  [3icAgxMAAAAJ, tQU-BXIAAAAJ, G-2DepMAAAAJ, eJ5...   Stable Diffusion
# 1231  [d_rilUYAAAAJ, 9e_KfoEAAAAJ, p_aH5fgAAAAJ, Au7...   Stable Diffusion
# 1232         [vud0t5YAAAAJ, EtPn_v4AAAAJ, 1bYESBYAAAAJ]   Stable Diffusion
# 1233         [osCX1YQAAAAJ, O1DeDyEAAAAJ, 1lcY2z4AAAAJ]   Stable Diffusion
#
#                                      file_name  \
# 0     7cedd2b0-ac03-49fb-9ef1-398b1a5d7fe1.pdf
# 1     91374318-7135-4f51-a3bc-720ececd88de.pdf
# 2     6d3627b9-6b0b-423c-8898-3185837a7617.pdf
# 3
# 4     c7fed73c-8e13-4770-a589-67708aab0b7e.pdf
# ...                                        ...
# 1229  0874bbf1-55fa-4df9-8a07-c6c15ac91c84.pdf
# 1230  e1e814fc-7dea-43b0-8049-928fee635bd7.pdf
# 1231  37f5b622-ff4e-4405-b63e-4d13c5738a88.pdf
# 1232  214899da-c78e-42d2-9a7d-0368daa239d6.pdf
# 1233  9efca518-66c0-464d-a678-8046ccad31da.pdf
#
#                                               file_path
# 0     ../../../detect_ml_model_files/7cedd2b0-ac03-4...
# 1     ../../../detect_ml_model_files/91374318-7135-4...
# 2     ../../../detect_ml_model_files/6d3627b9-6b0b-4...
# 3                                                  None
# 4     ../../../detect_ml_model_files/c7fed73c-8e13-4...
# ...                                                 ...
# 1229  ../../../detect_ml_model_files/0874bbf1-55fa-4...
# 1230  ../../../detect_ml_model_files/e1e814fc-7dea-4...
# 1231  ../../../detect_ml_model_files/37f5b622-ff4e-4...
# 1232  ../../../detect_ml_model_files/214899da-c78e-4...
# 1233  ../../../detect_ml_model_files/9efca518-66c0-4...
#
# [1234 rows x 8 columns]

# %%
data_df.to_parquet(f'{DATA_FOLDER}detect_ml_models.parquet')
