# %% [markdown]
# This notebook attempts to download at least five pdf files which in english for each machine learning model term described in ML-Model-Categorization.ods.
#
# To do this:
# 1. Recover from previous run if required
# 2. Find papers matching the ML search term
# 3. Iterate through the search results and download files until five pdf files in the English language are collected
# 4. Save progress
#
# NOTE: Google Scholar limits how many search terms are accessed which could result in the search being blocked. In this case, the search should be resumed a few days later.

# %%
import pandas as pd

#import spacy
#from spacy.matcher import PhraseMatcher

from scholarly import scholarly
import time

import requests
import mimetypes
import os

import uuid

#import PyPDF2

# %%
ROOT_FOLDER = '../../../'

# %%
DATA_FOLDER = '../../../data/'

# %%
DETECT_ML_MODEL_FILES_FOLDER = '../../../detect_ml_model_files/'

# %%
model_df = pd.read_excel(f'{ROOT_FOLDER}ML-Model-Categorization.ods', sheet_name='Sheet1', usecols=['MODEL'])

# %%
model_df
# Out:
#                                       MODEL
# 0                         Linear Regression
# 1                     Polynomial Regression
# 2                          Ridge Regression
# 3                          Lasso Regression
# 4                    Elastic Net Regression
# ..                                      ...
# 97                                   Claude
# 98                                    LLaMA
# 99   Contrastive Language-Image Pretraining
# 100                                  DALL-E
# 101                        Stable Diffusion
#
# [102 rows x 1 columns]

# %%
models = model_df['MODEL'].values.tolist()

# %%
import PyPDF2
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException

def detect_language(file_path):
    if file_path is None:
        return None
    else:
        try:
            # Open the PDF file
            with open(file_path, 'rb') as pdf_file:
                reader = PyPDF2.PdfReader(pdf_file)
                text = ""
                
                # Extract text from each page
                for page in reader.pages:
                    text += page.extract_text()
                
                # Detect the language of the extracted text
                if text.strip():  # Ensure there's text to analyze
                    language = detect(text)
                    return language
                else:
                    print(f"No text found in {file_path}")
                    return None
        except LangDetectException:
            print(f"Language detection failed for {file_path}")
            return None
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
            return None

# %%
def search_and_download_papers(query, limit, output_dir):
    search_query = scholarly.search_pubs(query)
    papers = []
    counter = 0

    while(counter < limit):
        try:
            time.sleep(2)  # Introduce delay
            paper = next(search_query)
            paper_info = {
                "title": paper.get("bib", {}).get("title"),
                "abstract": paper.get("bib", {}).get("abstract"),
                "year": paper.get("bib", {}).get("pub_year"),
                "url": paper.get("eprint_url", ""),
                "author_id": paper.get("author_id", []),
                "query": query,
                "file_name": "",
                "file_path": None,
                "language": None
            }

            # lets download the file if the url exists
            if paper_info['url']:
                url = paper_info['url']
                try:
                    # Download the file if a link is available
                    response = requests.get(url, stream=True)
                    content_type = response.headers.get('Content-Type', '')
                    # Check if the content type is PDF
                    if 'application/pdf' in content_type or mimetypes.guess_extension(content_type) == '.pdf':
                        unique_filename = str(uuid.uuid4()) + '.pdf'
                        file_path = os.path.join(output_dir, unique_filename)

                        with open(file_path, "wb") as file:
                            for chunk in response.iter_content(chunk_size=8192):
                                file.write(chunk)
                        
                        print(f"Downloaded: {file_path}")                            

                        language = detect_language(file_path=file_path)
                        
                        paper_info['file_name'] = unique_filename
                        paper_info['file_path'] = file_path
                        paper_info['language'] = language

                        # the aim is to collect files that are in english
                        if language == 'en':
                            counter += 1
                    else:
                        print(f"non-PDF content: {url}")             
                except Exception as e:
                    print(f"Error occurred while processing {url}: {e}")                                
            papers.append(paper_info)
        except StopIteration:
            break
        except Exception as e:
            print(f"Error processing paper : {e}")
            continue

    return papers

# %%
merge_with_previous = False

if os.path.isfile(f'{DATA_FOLDER}detect_ml_models.parquet'):
    # recover from previous run
    
    saved_data_df = pd.read_parquet(f'{DATA_FOLDER}detect_ml_models.parquet')

    merge_with_previous = True    
    
    processed_models = saved_data_df['query'].unique().tolist()
    
    unprocessed_models = list()
    
    for model in models:
        if model not in processed_models:
            unprocessed_models.append(model)
else:
    unprocessed_models = models

# %%
unprocessed_models
# Out:
# ['Linear Regression',
#  'Polynomial Regression',
#  'Bayesian Linear Regression',
#  'Quantile Regression',
#  'Support Vector Regression',
#  'Decision Trees',
#  'LightGBM',
#  'Co-Training',
#  'LeNet',
#  'VGGNet',
#  'Kalman Filters',
#  'Vector Autoregression',
#  'Prophet',
#  'Stacking',
#  'ChatGPT',
#  'LLaMA']

# %%
search_results = list()
for model in unprocessed_models:
    print(f"Searching for: {model}")    
    papers = search_and_download_papers(query=model, limit=5, output_dir=DETECT_ML_MODEL_FILES_FOLDER)
    search_results.append(papers)
# Out:
# Searching for: Linear Regression
# Downloaded: ../../../detect_ml_model_files/4b55ea85-209f-4ff8-9657-5d6d08ed6ad2.pdf
# Downloaded: ../../../detect_ml_model_files/fcfc4d57-a217-4ba2-8cc9-eb7f40b92540.pdf
# No text found in ../../../detect_ml_model_files/fcfc4d57-a217-4ba2-8cc9-eb7f40b92540.pdf
# Downloaded: ../../../detect_ml_model_files/fba635a5-3044-4e07-b058-8e4d9f947c32.pdf
# Downloaded: ../../../detect_ml_model_files/b143697b-982f-42a3-91bb-8337dc5d9b50.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1877042813046429/pdf?md5=da62147e64e2f356bfe6696b4f8031c1&pid=1-s2.0-S1877042813046429-main.pdf&_valck=1
# Downloaded: ../../../detect_ml_model_files/d2c3221d-0479-4e05-95ca-f081d5b8fe09.pdf
# non-PDF content: https://www.ajodo.org/article/S0889-5406(15)01379-7/fulltext
# Downloaded: ../../../detect_ml_model_files/f8ef9814-9fd2-417d-afba-7c28bd6ac17b.pdf
# Searching for: Polynomial Regression
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1877705812046085/pdf?md5=e60c56375b4a69af5b4605c6ca1d0714&pid=1-s2.0-S1877705812046085-main.pdf&_valck=1
# Downloaded: ../../../detect_ml_model_files/0f056411-822a-47ab-b854-a9e81124dd16.pdf
# Downloaded: ../../../detect_ml_model_files/c558b54b-2bee-4a1d-a5b1-6675c5c19722.pdf
# No text found in ../../../detect_ml_model_files/c558b54b-2bee-4a1d-a5b1-6675c5c19722.pdf
# non-PDF content: https://www.researchgate.net/profile/Wei-Yin-Loh/publication/216300421_Piecewise-Polynomial_Regression_Trees/links/004635241a58930fd7000000/Piecewise-Polynomial-Regression-Trees.pdf
# non-PDF content: https://www.researchgate.net/profile/Edward-Carmines-2/publication/249693568_Interpreting_Polynomial_Regression/links/58b89e1492851c471d4a4688/Interpreting-Polynomial-Regression.pdf
# Downloaded: ../../../detect_ml_model_files/4fd6b043-a31c-4870-aef1-edbfa322350c.pdf
# non-PDF content: https://www.researchgate.net/profile/Eric-Heggestad-2/publication/225474954_Erratum_to_Polynomial_Regression_with_Response_Surface_Analysis_A_Powerful_Approach_for_Examining_Moderation_and_Overcoming_Limitations_of_Difference_Scores/links/5487b0c60cf2ef34478ecd3b/Erratum-to-Polynomial-Regression-with-Response-Surface-Analysis-A-Powerful-Approach-for-Examining-Moderation-and-Overcoming-Limitations-of-Difference-Scores.pdf
# Downloaded: ../../../detect_ml_model_files/781bcc26-b4e8-4782-95fb-00a323bb63cc.pdf
# Downloaded: ../../../detect_ml_model_files/4ff98d10-5907-49be-9f56-9dacddd0e904.pdf
# non-PDF content: https://www.researchgate.net/profile/Priyanka-Sinha-12/publication/264425037_Multivariate_Polynomial_Regression_in_Data_Mining_Methodology_Problems_and_Solutions/links/5d44d03aa6fdcc370a76b505/Multivariate-Polynomial-Regression-in-Data-Mining-Methodology-Problems-and-Solutions.pdf
# non-PDF content: https://www.researchgate.net/profile/Harold-Burkhart/publication/233658426_Segmented_Polynomial_Regression_Applied_to_Taper_Equations/links/0c96053774e894bee4000000/Segmented-Polynomial-Regression-Applied-to-Taper-Equations.pdf
# Downloaded: ../../../detect_ml_model_files/c44b76cf-d5f9-4e83-8b03-3b9a1ceb5975.pdf
# Searching for: Bayesian Linear Regression
# Downloaded: ../../../detect_ml_model_files/f5176414-a0e6-42dd-acd3-3ae40631ae4c.pdf
# Downloaded: ../../../detect_ml_model_files/b38a4849-404c-4843-8b2b-133111d6d0ed.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/am/pii/S0888327020301564
# Error occurred while processing https://www2.stat.duke.edu/courses/Fall05/sta395/joelucas1.pdf: HTTPSConnectionPool(host='www2.stat.duke.edu', port=443): Max retries exceeded with url: /courses/Fall05/sta395/joelucas1.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Downloaded: ../../../detect_ml_model_files/52fda1ff-f0bc-4f16-bd0d-635da4bf6648.pdf
# Downloaded: ../../../detect_ml_model_files/cbbbe9b0-2502-405b-b89d-4a6ebe1d8512.pdf
# No text found in ../../../detect_ml_model_files/cbbbe9b0-2502-405b-b89d-4a6ebe1d8512.pdf
# Error occurred while processing https://www.stat.washington.edu/~raftery/Research/PDF/rmh1997.pdf: HTTPSConnectionPool(host='www.stat.washington.edu', port=443): Max retries exceeded with url: /~raftery/Research/PDF/rmh1997.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1877050918315126/pdf?md5=ec517e4276d8db72140f45b0328e0499&pid=1-s2.0-S1877050918315126-main.pdf
# non-PDF content: https://link.springer.com/article/10.3758/s13428-021-01552-2
# Downloaded: ../../../detect_ml_model_files/380f3038-bbb0-46c4-b5a6-046cd30cf507.pdf
# Downloaded: ../../../detect_ml_model_files/e5a9347a-bbe3-4662-9fbf-2fff234f0163.pdf
# Searching for: Quantile Regression
# non-PDF content: https://pubs.aeaweb.org/doi/pdf/10.1257/jep.15.4.143
# Downloaded: ../../../detect_ml_model_files/0cec8115-515a-4e2f-a6fc-404551728af2.pdf
# Downloaded: ../../../detect_ml_model_files/ba523370-9351-40d8-b21b-8bf74acf3899.pdf
# Downloaded: ../../../detect_ml_model_files/bb8ddf24-7b86-442b-a4b1-13189057f4b2.pdf
# non-PDF content: https://academic.oup.com/aje/article/180/3/330/2739270
# Downloaded: ../../../detect_ml_model_files/c10dd3a0-d937-4b21-996a-167ea60a849a.pdf
# non-PDF content: https://www.sebastianbuhai.com/papers/publications/quantile_regressions.pdf
# Downloaded: ../../../detect_ml_model_files/36e6d292-c6cf-4fa0-abaa-1c7c60cf23a3.pdf
# Searching for: Support Vector Regression
# non-PDF content: https://link.springer.com/chapter/10.1007/978-1-4302-5990-9_4
# Downloaded: ../../../detect_ml_model_files/944c46d6-6d4d-467b-8eab-76017c0987ad.pdf
# non-PDF content: https://www.researchgate.net/profile/Mohamed-Mourad-Lafifi/post/Hi-could-anyone-tell-how-the-Epsilon-SVR-perform-the-regression-in-Support-Vector-Machines-SVM/attachment/59d6467c79197b80779a181a/AS%3A458289034076160%401486276028968/download/Review+Support+Vector+Regression.pdf
# Downloaded: ../../../detect_ml_model_files/d76dbb91-1d7c-4da7-8eb0-e5f984bac84f.pdf
# Downloaded: ../../../detect_ml_model_files/8a5f0243-63a4-4fe7-b0d5-77155da27cf3.pdf
# Downloaded: ../../../detect_ml_model_files/80bb016a-0511-4418-b25a-91b0f63d4f25.pdf
# non-PDF content: https://www.academia.edu/download/3247560/SVR_WellingsNote.pdf
# Downloaded: ../../../detect_ml_model_files/30665792-464f-48b3-a535-0bd84b8bda05.pdf
# non-PDF content: https://www.academia.edu/download/30840516/newsvr.pdf
# non-PDF content: https://www.academia.edu/download/70889833/s0925-2312_2803_2900380-120211001-22175-1tqk9hp.pdf
# non-PDF content: https://link.springer.com/chapter/10.1007/978-3-030-89010-0_9
# non-PDF content: https://www.academia.edu/download/41761513/Travel-Time_Prediction_With_Support_Vect20160129-18106-qik78o.pdf
# Downloaded: ../../../detect_ml_model_files/5c59bebc-b951-43e3-b922-ccd7f3e72cd1.pdf
# Searching for: Decision Trees
# Downloaded: ../../../detect_ml_model_files/a913b1a2-054a-4b58-aaa2-baba352ae169.pdf
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2701298/
# Downloaded: ../../../detect_ml_model_files/99eb0366-4527-46f3-b7b8-7ccedf5e5e1b.pdf
# Downloaded: ../../../detect_ml_model_files/d025dafe-33ae-4e04-a255-693432808a9b.pdf
# non-PDF content: https://www.academia.edu/download/49483887/Decision_Trees_for_Decision_Making.pdf
# Downloaded: ../../../detect_ml_model_files/4ae0b6da-ab40-4e86-94f0-dc0880f0bfc3.pdf
# No text found in ../../../detect_ml_model_files/4ae0b6da-ab40-4e86-94f0-dc0880f0bfc3.pdf
# Downloaded: ../../../detect_ml_model_files/eb7f935d-8afa-4bfa-8230-a164c2f95793.pdf
# Downloaded: ../../../detect_ml_model_files/24e1a90f-cdc8-48f8-a6b8-2263690676ce.pdf
# Searching for: LightGBM
# Downloaded: ../../../detect_ml_model_files/55c9771d-8796-4826-844e-e6d955a045ef.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/am/pii/S016974391930262X
# non-PDF content: https://link.springer.com/article/10.1186/s13059-021-02492-y
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/09284642.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S0960077922001977
# non-PDF content: https://authors.library.caltech.edu/105910/1/09210509.pdf
# non-PDF content: https://www.mdpi.com/2075-4418/11/9/1714
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/08653826.pdf
# non-PDF content: https://journals.plos.org/digitalhealth/article?id=10.1371/journal.pdig.0000299
# non-PDF content: https://www.mdpi.com/2073-8994/12/9/1458
# non-PDF content: https://www.mdpi.com/2227-7390/8/5/765
# non-PDF content: https://www.mdpi.com/2077-1312/9/5/496
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2019/3761203
# Downloaded: ../../../detect_ml_model_files/45ead717-912a-4ec1-8fd4-6fe5e82b50ec.pdf
# non-PDF content: https://www.mdpi.com/2076-3417/10/9/3227
# Downloaded: ../../../detect_ml_model_files/b42f8b96-3e57-4fa3-98c8-622571f34c67.pdf
# non-PDF content: https://ietresearch.onlinelibrary.wiley.com/doi/full/10.1049/iet-its.2020.0396
# non-PDF content: https://www.degruyter.com/document/doi/10.1515/jisys-2022-0036/html
# non-PDF content: https://www.mdpi.com/2075-5309/12/9/1309
# Downloaded: ../../../detect_ml_model_files/b427a414-0574-4d95-b64a-e2ca4ae450db.pdf
# non-PDF content: https://academic.oup.com/bioinformatics/article/37/8/1135/5942084
# non-PDF content: https://xuebao.neu.edu.cn/natural/EN/article/downloadArticleFile.do?attachType=PDF&id=11623
# non-PDF content: https://www.mdpi.com/1996-1073/13/4/807
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2021/8128879
# non-PDF content: https://www.mdpi.com/2227-9717/12/1/221
# Downloaded: ../../../detect_ml_model_files/7b78d9c7-0517-4be6-82e3-08610f5cd5a1.pdf
# Error processing ../../../detect_ml_model_files/7b78d9c7-0517-4be6-82e3-08610f5cd5a1.pdf: EOF marker not found
# non-PDF content: https://www.researchgate.net/profile/Mouhammd-Alkasassbeh/publication/342683052_LightGBM_Algorithm_for_Malware_Detection/links/60069bafa6fdccdcb8645cb0/LightGBM-Algorithm-for-Malware-Detection.pdf
# non-PDF content: https://iopscience.iop.org/article/10.1088/1742-6596/1754/1/012187/pdf
# non-PDF content: https://www.mdpi.com/1424-8220/21/8/2722
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S2352484722004541
# non-PDF content: https://www.mdpi.com/1424-8220/19/4/947
# non-PDF content: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4395575
# non-PDF content: https://www.researchgate.net/profile/Mohamed-Saber-30/publication/354236626_Examining_LightGBM_and_CatBoost_Models_for_Wadi_Flash_Flood_Susceptibility_Prediction/links/65700cb4fd4c91437ba88124/Examining-LightGBM-and-CatBoost-Models-for-Wadi-Flash-Flood-Susceptibility-Prediction.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/10063850.pdf
# non-PDF content: https://www.mdpi.com/2076-3417/12/11/5565
# non-PDF content: https://www.researchgate.net/profile/Mohammad-Ahsan-2/publication/370448126_LightGBM_empowered_by_whale_optimization_for_thyroid_disease_detection/links/654db886b86a1d521bc8a614/LightGBM-empowered-by-whale-optimization-for-thyroid-disease-detection.pdf
# non-PDF content: https://www.scielo.br/j/cta/a/ggTSffrd3WgYQygWJ8CP7mc/
# Downloaded: ../../../detect_ml_model_files/ba9118e7-6c68-4b12-952e-3d7b9cabb65b.pdf
# Searching for: Co-Training
# non-PDF content: https://www.researchgate.net/profile/Xin-Ning-9/publication/350194568_A_review_of_research_on_co-training/links/605709cc299bf17367595145/A-review-of-research-on-co-training.pdf
# Downloaded: ../../../detect_ml_model_files/be48ec90-ff40-476a-b248-cdfd43428399.pdf
# Error occurred while processing https://cs.nju.edu.cn/zhouzh/zhouzh.files/publication/icml10.pdf: HTTPSConnectionPool(host='cs.nju.edu.cn', port=443): Max retries exceeded with url: /zhouzh/zhouzh.files/publication/icml10.pdf (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] ssl/tls alert handshake failure (_ssl.c:1000)')))
# Downloaded: ../../../detect_ml_model_files/e5b951dd-70b1-4ebf-bc90-2af0af4b6786.pdf
# Error processing ../../../detect_ml_model_files/e5b951dd-70b1-4ebf-bc90-2af0af4b6786.pdf: Missed the stop code in LZWDecode!
# Downloaded: ../../../detect_ml_model_files/956101f9-a4d2-49ad-9be5-d843e9199cf3.pdf
# Downloaded: ../../../detect_ml_model_files/2d7135bc-9341-443c-80c4-a8706933d070.pdf
# Downloaded: ../../../detect_ml_model_files/ea261e76-36b4-4331-b146-e86d731bb706.pdf
# Downloaded: ../../../detect_ml_model_files/57b6ae3b-62b0-4d1c-911e-c73f9ebf91cb.pdf
# Searching for: LeNet
# non-PDF content: https://www.researchgate.net/profile/Md-Islam-491/publication/350801178_Detection_of_COVID_19_from_CT_Image_by_The_Novel_LeNet-5_CNN_Architecture/links/60e6ba7930e8e50c01ec28e7/Detection-of-COVID-19-from-CT-Image-by-The-Novel-LeNet-5-CNN-Architecture.pdf
# non-PDF content: https://www.ccis2k.org/iajit/PDF/vol.6,no.3/15.pdf
# non-PDF content: https://www.mdpi.com/1424-8220/19/1/217
# non-PDF content: https://journals.lww.com/annalsofsurgery/fulltext/2021/07000/Intraoperative_Red_Blood_Cell_Transfusion.19.aspx
# non-PDF content: https://www.academia.edu/download/48922102/00004770-200011000-0000520160917-30548-1lord3b.pdf
# non-PDF content: https://journals.lww.com/annalsofsurgery/fulltext/2023/03000/should_cell_salvage_be_used_in_liver_resection_and.17.aspx
# non-PDF content: https://link.springer.com/article/10.1186/s13017-022-00423-1
# non-PDF content: https://www.researchgate.net/profile/Ahmed-Anter/publication/340237897_Classification_of_Garments_from_Fashion_MNIST_Dataset_Using_CNN_LeNet-5_Architecture/links/5eef3071a6fdcc73be909495/Classification-of-Garments-from-Fashion-MNIST-Dataset-Using-CNN-LeNet-5-Architecture.pdf
# non-PDF content: https://www.mdpi.com/2075-4418/13/17/2746
# Downloaded: ../../../detect_ml_model_files/2177c3f9-d52d-4027-8d59-50db4a0ff717.pdf
# non-PDF content: https://onlinelibrary.wiley.com/doi/full/10.1155/2022/1636203
# non-PDF content: https://www.mdpi.com/2313-433X/9/10/197
# Downloaded: ../../../detect_ml_model_files/a3e11c60-defb-4fa0-8cc5-33f104caef51.pdf
# non-PDF content: https://jamanetwork.com/journals/jamanetworkopen/fullarticle/2813421
# non-PDF content: https://www.jacc.org/doi/full/10.1016/j.jacc.2018.12.042
# non-PDF content: https://peerj.com/articles/7731/
# Downloaded: ../../../detect_ml_model_files/0340deb8-2285-471f-aab2-fbd9d71f58d3.pdf
# Downloaded: ../../../detect_ml_model_files/419dce7c-9419-4107-97bf-c16ce5efa97c.pdf
# non-PDF content: https://www.academia.edu/download/89076721/s00500-019-04307-620220728-1-93nujn.pdf
# non-PDF content: https://www.mdpi.com/1424-8220/20/6/1693
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/9312710/09631287.pdf
# Downloaded: ../../../detect_ml_model_files/2d427cb2-9f74-4bec-8e44-38058cea08fa.pdf
# non-PDF content: https://www.academia.edu/download/95651652/19393555.2020.179724820221212-1-6utvla.pdf
# non-PDF content: https://journals.lww.com/annalsofsurgery/fulltext/2022/03000/a_systematic_review_and_meta_analysis_of.9.aspx
# Downloaded: ../../../detect_ml_model_files/efb598ac-1736-480a-87ce-ef70a435be0f.pdf
# Searching for: VGGNet
# Downloaded: ../../../detect_ml_model_files/b4c60874-7e11-4acd-bebf-835a405114fe.pdf
# non-PDF content: https://www.researchgate.net/profile/Shahbaz-Pervez/publication/329315021_Pre-trained_VGGNet_Architecture_for_Remote-Sensing_Image_Scene_Classification/links/5c3a4097299bf12be3c3c65f/Pre-trained-VGGNet-Architecture-for-Remote-Sensing-Image-Scene-Classification.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/09515947.pdf
# non-PDF content: https://www.researchgate.net/profile/Bmg-Prasad/publication/363891123_CNN_Architectures_Alex_Net_Le_Net_VGG_Google_Net_Res_Net/links/66ee8a306b101f6fa4f8a886/CNN-Architectures-Alex-Net-Le-Net-VGG-Google-Net-Res-Net.pdf
# non-PDF content: https://iopscience.iop.org/article/10.1088/1742-6596/1774/1/012043/pdf
# non-PDF content: https://ietresearch.onlinelibrary.wiley.com/doi/full/10.1049/iet-ipr.2018.6656
# non-PDF content: https://www.researchgate.net/profile/Xiaofeng-Gao-3/publication/361472279_Deep_convolutional_neural_networks_for_construction_and_demolition_waste_classification_VGGNet_structures_cyclical_learning_rate_and_knowledge_transfer/links/62b5befd6ec05339cca01396/Deep-convolutional-neural-networks-for-construction-and-demolition-waste-classification-VGGNet-structures-cyclical-learning-rate-and-knowledge-transfer.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S1319157821001300
# Downloaded: ../../../detect_ml_model_files/382b1b8c-ebd1-45d7-8319-a96a6a618124.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/08305463.pdf
# non-PDF content: https://iopscience.iop.org/article/10.1088/1742-6596/2040/1/012001/pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/10162199.pdf
# non-PDF content: https://www.frontiersin.org/articles/10.3389/fonc.2022.944859/full
# non-PDF content: http://joces.nudt.edu.cn/EN/article/downloadArticleFile.do?attachType=PDF&id=16301
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/10044107.pdf
# Downloaded: ../../../detect_ml_model_files/d6c16721-06c3-4b69-a02c-ec6bc0ea4d3d.pdf
# non-PDF content: https://www.frontiersin.org/articles/10.3389/fenvs.2022.1043843/full
# Downloaded: ../../../detect_ml_model_files/dc05e1bd-3a56-4cbe-8a87-1286b49b40ea.pdf
# Downloaded: ../../../detect_ml_model_files/ef41be6b-f7de-4b70-9c4d-ef06013f7010.pdf
# non-PDF content: https://ieeexplore.ieee.org/iel7/6287639/6514899/09447751.pdf
# non-PDF content: https://www.researchgate.net/profile/Kishor-Bhangale/publication/354509314_Multi-view_Multi-pose_Robust_Face_Recognition_Based_on_VGGNet/links/613dc4464e1df271062f2268/Multi-view-Multi-pose-Robust-Face-Recognition-Based-on-VGGNet.pdf
# non-PDF content: https://www.frontiersin.org/articles/10.3389/fncom.2022.1001803/full
# non-PDF content: https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0208497
# non-PDF content: https://www.mdpi.com/2079-9292/12/15/3370
# non-PDF content: https://www.mdpi.com/2072-4292/14/23/5939
# Downloaded: ../../../detect_ml_model_files/ffa4d7ce-e09d-48a0-b974-217434d87101.pdf
# Searching for: Kalman Filters
# Downloaded: ../../../detect_ml_model_files/51dd5eeb-c800-45af-b57d-6a9cc2fe6d07.pdf
# non-PDF content: https://www.researchgate.net/profile/Kaifan-Ji/publication/305871722_Kalman_Filter_and_Its_Application/links/6415a6a8a1b72772e408cc64/Kalman-Filter-and-Its-Application.pdf
# non-PDF content: https://www.academia.edu/download/81315221/kalman.pdf
# non-PDF content: https://www.intechopen.com/chapters/63164
# Error occurred while processing http://abel.math.harvard.edu/archive/116_fall_03/handouts/kalman.pdf: HTTPSConnectionPool(host='abel.math.harvard.edu', port=443): Max retries exceeded with url: /archive/116_fall_03/handouts/kalman.pdf (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
# Downloaded: ../../../detect_ml_model_files/09bbf18a-eb17-4536-b12b-469c9c5d6c75.pdf
# FloatObject (b'145.4927.471') invalid; use 0.0 instead
# FloatObject (b'122.5144..673') invalid; use 0.0 instead
# FloatObject (b'1418147.8804.673') invalid; use 0.0 instead
# FloatObject (b'146.21128.543') invalid; use 0.0 instead
# FloatObject (b'144.7421128.543') invalid; use 0.0 instead
# FloatObject (b'125.9144.888') invalid; use 0.0 instead
# FloatObject (b'15.631.489') invalid; use 0.0 instead
# FloatObject (b'147.82.884') invalid; use 0.0 instead
# FloatObject (b'141.4147.65') invalid; use 0.0 instead
# FloatObject (b'147.28.043754') invalid; use 0.0 instead
# FloatObject (b'6.6.745') invalid; use 0.0 instead
# FloatObject (b'3147.319785.174') invalid; use 0.0 instead
# FloatObject (b'14.319785.174') invalid; use 0.0 instead
# FloatObject (b'147.488824.888') invalid; use 0.0 instead
# FloatObject (b'130.7688837.248') invalid; use 0.0 instead
# FloatObject (b'147.65.72941.99') invalid; use 0.0 instead
# FloatObject (b'147.65.7793141.4147.65.77931416') invalid; use 0.0 instead
# FloatObject (b'147.5345.77931416') invalid; use 0.0 instead
# FloatObject (b'147.3915.77931418') invalid; use 0.0 instead
# FloatObject (b'113.043755.39') invalid; use 0.0 instead
# FloatObject (b'47.24853121.068') invalid; use 0.0 instead
# FloatObject (b'128.0434613017.211') invalid; use 0.0 instead
# FloatObject (b'144.6613017.211') invalid; use 0.0 instead
# FloatObject (b'125838.5.174') invalid; use 0.0 instead
# FloatObject (b'.0437528868.174') invalid; use 0.0 instead
# FloatObject (b'.043752897.211') invalid; use 0.0 instead
# FloatObject (b'1430.7656.08475') invalid; use 0.0 instead
# FloatObject (b'1430.7656.15640.117') invalid; use 0.0 instead
# FloatObject (b'1430.7656.29943') invalid; use 0.0 instead
# FloatObject (b'5.317.65883') invalid; use 0.0 instead
# FloatObject (b'12.037.82') invalid; use 0.0 instead
# FloatObject (b'128.04346138.745') invalid; use 0.0 instead
# FloatObject (b'12.2.24262.51') invalid; use 0.0 instead
# FloatObject (b'147.62.231') invalid; use 0.0 instead
# FloatObject (b'1.62.01') invalid; use 0.0 instead
# FloatObject (b'12.0.13') invalid; use 0.0 instead
# FloatObject (b'12.0.1347.6138.9') invalid; use 0.0 instead
# FloatObject (b'12.0.13') invalid; use 0.0 instead
# FloatObject (b'12.577347.613444') invalid; use 0.0 instead
# FloatObject (b'61.516281471752162.51') invalid; use 0.0 instead
# FloatObject (b'12.0.13') invalid; use 0.0 instead
# FloatObject (b'12.0.1347.6310181491') invalid; use 0.0 instead
# FloatObject (b'62.088141144.673') invalid; use 0.0 instead
# FloatObject (b'139.037347.61301128147.884.6130871492174') invalid; use 0.0 instead
# FloatObject (b'61.5871499.037347.6135871499..247') invalid; use 0.0 instead
# FloatObject (b'5.9361.5162814') invalid; use 0.0 instead
# FloatObject (b'347.53461.5162814') invalid; use 0.0 instead
# FloatObject (b'144.661.602068') invalid; use 0.0 instead
# FloatObject (b'147.8262.01') invalid; use 0.0 instead
# FloatObject (b'147.847.62.231') invalid; use 0.0 instead
# FloatObject (b'147.8262.5172814') invalid; use 0.0 instead
# FloatObject (b'144.662.5172814') invalid; use 0.0 instead
# FloatObject (b'871.342.2.24') invalid; use 0.0 instead
# FloatObject (b'1430.7662.303') invalid; use 0.0 instead
# FloatObject (b'147.262.51') invalid; use 0.0 instead
# FloatObject (b'147.62.58975') invalid; use 0.0 instead
# FloatObject (b'1430.7662.80375') invalid; use 0.0 instead
# FloatObject (b'1430.7662.94640.117') invalid; use 0.0 instead
# FloatObject (b'12.037.82') invalid; use 0.0 instead
# FloatObject (b'147.263151.489') invalid; use 0.0 instead
# FloatObject (b'142.2.24') invalid; use 0.0 instead
# FloatObject (b'149.037316.787319') invalid; use 0.0 instead
# FloatObject (b'.471162.0941.99') invalid; use 0.0 instead
# FloatObject (b'.471162.307.211') invalid; use 0.0 instead
# FloatObject (b'147.662.52') invalid; use 0.0 instead
# FloatObject (b'141.4147.82') invalid; use 0.0 instead
# FloatObject (b'147.662.7362814') invalid; use 0.0 instead
# FloatObject (b'5.9362.7362814') invalid; use 0.0 instead
# FloatObject (b'62.378141144.673') invalid; use 0.0 instead
# FloatObject (b'147.826.7591') invalid; use 0.0 instead
# FloatObject (b'149.147.82') invalid; use 0.0 instead
# FloatObject (b'149.47.2486.7237.211') invalid; use 0.0 instead
# FloatObject (b'140.631805.174') invalid; use 0.0 instead
# FloatObject (b'140.6.7791') invalid; use 0.0 instead
# FloatObject (b'140.6.7791') invalid; use 0.0 instead
# FloatObject (b'1.12.2.24223') invalid; use 0.0 instead
# FloatObject (b'147.75..247') invalid; use 0.0 instead
# FloatObject (b'47.22216041.99') invalid; use 0.0 instead
# FloatObject (b'147.22216041.947175273') invalid; use 0.0 instead
# FloatObject (b'11430.7622.927') invalid; use 0.0 instead
# FloatObject (b'5.9312.81') invalid; use 0.0 instead
# FloatObject (b'1144.6247391499..247') invalid; use 0.0 instead
# FloatObject (b'13.7.82747.85') invalid; use 0.0 instead
# FloatObject (b'47.225.6') invalid; use 0.0 instead
# FloatObject (b'47.2255.317419') invalid; use 0.0 instead
# FloatObject (b'147.2255.3174147.884') invalid; use 0.0 instead
# FloatObject (b'12255.3174147547.') invalid; use 0.0 instead
# FloatObject (b'10.9312.62') invalid; use 0.0 instead
# FloatObject (b'15.317.625.6') invalid; use 0.0 instead
# FloatObject (b'91415.317.73') invalid; use 0.0 instead
# FloatObject (b'15.317.628') invalid; use 0.0 instead
# FloatObject (b'891.342.2.24628') invalid; use 0.0 instead
# FloatObject (b'114746347.255.31741147463') invalid; use 0.0 instead
# FloatObject (b'15.317.628') invalid; use 0.0 instead
# FloatObject (b'891.345.317.628') invalid; use 0.0 instead
# FloatObject (b'117.625.46475') invalid; use 0.0 instead
# FloatObject (b'1430.7625.7575') invalid; use 0.0 instead
# FloatObject (b'1430.76213.8') invalid; use 0.0 instead
# FloatObject (b'147.2213.8') invalid; use 0.0 instead
# FloatObject (b'10.93164148.73') invalid; use 0.0 instead
# FloatObject (b'19..247') invalid; use 0.0 instead
# FloatObject (b'19.147.222125') invalid; use 0.0 instead
# FloatObject (b'13.7.827476') invalid; use 0.0 instead
# FloatObject (b'.287.8745') invalid; use 0.0 instead
# FloatObject (b'1144.428710.068') invalid; use 0.0 instead
# FloatObject (b'11430.7626.03975') invalid; use 0.0 instead
# FloatObject (b'11430.7626..885') invalid; use 0.0 instead
# FloatObject (b'147.79.7541.91') invalid; use 0.0 instead
# FloatObject (b'1.29.541.91') invalid; use 0.0 instead
# FloatObject (b'12.037.82') invalid; use 0.0 instead
# FloatObject (b'0371.287.8745') invalid; use 0.0 instead
# FloatObject (b'461.287.8745') invalid; use 0.0 instead
# FloatObject (b'577347.287.8745') invalid; use 0.0 instead
# FloatObject (b'181.6291499.405') invalid; use 0.0 instead
# FloatObject (b'181.9741.99') invalid; use 0.0 instead
# FloatObject (b'2591415.317.683') invalid; use 0.0 instead
# FloatObject (b'144.48474031499.405') invalid; use 0.0 instead
# FloatObject (b'114147.685.2685') invalid; use 0.0 instead
# FloatObject (b'12.9041.814905') invalid; use 0.0 instead
# FloatObject (b'12.9041.814476') invalid; use 0.0 instead
# FloatObject (b'114847.68145481.9471752684753174147547.') invalid; use 0.0 instead
# FloatObject (b'12.9041.89') invalid; use 0.0 instead
# FloatObject (b'12.9041.89') invalid; use 0.0 instead
# FloatObject (b'12.2.54389') invalid; use 0.0 instead
# FloatObject (b'12.46347.89') invalid; use 0.0 instead
# FloatObject (b'19..247') invalid; use 0.0 instead
# FloatObject (b'1761499.31.0681') invalid; use 0.0 instead
# FloatObject (b'1761499.047.') invalid; use 0.0 instead
# FloatObject (b'8145481.99.047.') invalid; use 0.0 instead
# FloatObject (b'8145481.99.') invalid; use 0.0 instead
# FloatObject (b'5.938145481.99.347.5348145481.99.144.4855.62') invalid; use 0.0 instead
# FloatObject (b'139.47.828470.8') invalid; use 0.0 instead
# FloatObject (b'139.47.8284754.068') invalid; use 0.0 instead
# FloatObject (b'1144.684754.068') invalid; use 0.0 instead
# FloatObject (b'12.2.24') invalid; use 0.0 instead
# FloatObject (b'11430.768145481.91430.782') invalid; use 0.0 instead
# FloatObject (b'11430.7685.2685') invalid; use 0.0 instead
# FloatObject (b'11430.7685.835') invalid; use 0.0 instead
# FloatObject (b'11430.7685.9781.91430.782') invalid; use 0.0 instead
# FloatObject (b'12.037.82') invalid; use 0.0 instead
# FloatObject (b'147.287.98') invalid; use 0.0 instead
# FloatObject (b'147.287.6225') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'12.2.24') invalid; use 0.0 instead
# FloatObject (b'19.047.') invalid; use 0.0 instead
# FloatObject (b'147.28940541.99') invalid; use 0.0 instead
# FloatObject (b'147.28942671.19') invalid; use 0.0 instead
# FloatObject (b'147.689.5531.19') invalid; use 0.0 instead
# FloatObject (b'147.689.7681.99.') invalid; use 0.0 instead
# FloatObject (b'5.9389.7681.99.147.') invalid; use 0.0 instead
# FloatObject (b'189.7681.99.47.82894625') invalid; use 0.0 instead
# FloatObject (b'89.41141144.673') invalid; use 0.0 instead
# FloatObject (b'19.147.82') invalid; use 0.0 instead
# FloatObject (b'12847.8287.9081.99.144.489') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'12831.06845.85') invalid; use 0.0 instead
# FloatObject (b'87.9081.99.147.2887051') invalid; use 0.0 instead
# FloatObject (b'19.147.2887051') invalid; use 0.0 instead
# FloatObject (b'19876371.95.388') invalid; use 0.0 instead
# FloatObject (b'12.9041.9942095') invalid; use 0.0 instead
# FloatObject (b'12.037..9942095') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'19.147.4994137') invalid; use 0.0 instead
# FloatObject (b'19.347.534987781419.047.') invalid; use 0.0 instead
# FloatObject (b'147.299.564') invalid; use 0.0 instead
# FloatObject (b'147.299.135') invalid; use 0.0 instead
# FloatObject (b'12.2.24') invalid; use 0.0 instead
# FloatObject (b'147.200.7825') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'147.201.4265') invalid; use 0.0 instead
# FloatObject (b'19.047.') invalid; use 0.0 instead
# FloatObject (b'19.3105201.9275') invalid; use 0.0 instead
# FloatObject (b'19.147.202.075') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.147.202.6425') invalid; use 0.0 instead
# FloatObject (b'19.147.202.6425') invalid; use 0.0 instead
# FloatObject (b'12.2.24') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'202.7141.99') invalid; use 0.0 instead
# FloatObject (b'1144.673201.9981.99') invalid; use 0.0 instead
# FloatObject (b'144.201.4265') invalid; use 0.0 instead
# FloatObject (b'201.0681.99.47.8200.7825') invalid; use 0.0 instead
# FloatObject (b'144.82200.4065') invalid; use 0.0 instead
# FloatObject (b'19.147.200.9255') invalid; use 0.0 instead
# FloatObject (b'19.147.200.9255') invalid; use 0.0 instead
# FloatObject (b'12.2.241') invalid; use 0.0 instead
# FloatObject (b'825203.6581.99..247203.6581.94724') invalid; use 0.0 instead
# FloatObject (b'6581.92.2.242047431.91430.720142881.91430.782205.291.91430.72047717411457732047717414724') invalid; use 0.0 instead
# FloatObject (b'5.920471471.99') invalid; use 0.0 instead
# FloatObject (b'5.9205.7885') invalid; use 0.0 instead
# FloatObject (b'19.147.82210.8675') invalid; use 0.0 instead
# FloatObject (b'19.1105210.7065') invalid; use 0.0 instead
# FloatObject (b'147.210.7245') invalid; use 0.0 instead
# FloatObject (b'12.537.') invalid; use 0.0 instead
# FloatObject (b'5.920945081.99.147.8220945081.99.405') invalid; use 0.0 instead
# FloatObject (b'19..317') invalid; use 0.0 instead
# FloatObject (b'144.206.07174147819') invalid; use 0.0 instead
# FloatObject (b'14731.9209..925') invalid; use 0.0 instead
# FloatObject (b'19.147.209..925') invalid; use 0.0 instead
# FloatObject (b'19.147.82209..925') invalid; use 0.0 instead
# FloatObject (b'207.1481.99.144.207.2915') invalid; use 0.0 instead
# FloatObject (b'15.7.392087292') invalid; use 0.0 instead
# FloatObject (b'15.30.7208.364') invalid; use 0.0 instead
# FloatObject (b'144.211.225') invalid; use 0.0 instead
# FloatObject (b'12.2.24') invalid; use 0.0 instead
# FloatObject (b'147.212.0125') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'147.212.6555') invalid; use 0.0 instead
# FloatObject (b'19.047.') invalid; use 0.0 instead
# FloatObject (b'19.1105213.0845') invalid; use 0.0 instead
# FloatObject (b'19.147.213.2995') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.147.213.81.99.147.213.81.947819') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.147.2147372') invalid; use 0.0 instead
# FloatObject (b'1144.6212.941') invalid; use 0.0 instead
# FloatObject (b'144.212.6555') invalid; use 0.0 instead
# FloatObject (b'212.2981.99.47.8211.945') invalid; use 0.0 instead
# FloatObject (b'144.82211.6545') invalid; use 0.0 instead
# FloatObject (b'19.147.211.7975') invalid; use 0.0 instead
# FloatObject (b'19.147.211.8681.99.147.82211.945') invalid; use 0.0 instead
# FloatObject (b'19.147.212.0835') invalid; use 0.0 instead
# FloatObject (b'19.147.212.0835') invalid; use 0.0 instead
# FloatObject (b'12.2.241') invalid; use 0.0 instead
# FloatObject (b'19.144.21940925') invalid; use 0.0 instead
# FloatObject (b'19.147.8221940925') invalid; use 0.0 instead
# FloatObject (b'19.147.2187592') invalid; use 0.0 instead
# FloatObject (b'12.537.8221284625') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.147.21284625') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'219.0181.99.147.82219.') invalid; use 0.0 instead
# FloatObject (b'12.2.24218702') invalid; use 0.0 instead
# FloatObject (b'15.147.') invalid; use 0.0 instead
# FloatObject (b'1631.91430.7218') invalid; use 0.0 instead
# FloatObject (b'1631.91430.7218') invalid; use 0.0 instead
# FloatObject (b'15.316.21873775') invalid; use 0.0 instead
# FloatObject (b'12.037.') invalid; use 0.0 instead
# FloatObject (b'19.144.219445') invalid; use 0.0 instead
# FloatObject (b'1142.24221.5245') invalid; use 0.0 instead
# FloatObject (b'114247.221.31') invalid; use 0.0 instead
# FloatObject (b'114247.220.4515') invalid; use 0.0 instead
# FloatObject (b'114847.220.594') invalid; use 0.0 instead
# FloatObject (b'121175.221.5245') invalid; use 0.0 instead
# FloatObject (b'1142.39222.0965') invalid; use 0.0 instead
# FloatObject (b'19..247222.0965') invalid; use 0.0 instead
# FloatObject (b'19.4.6221.0955') invalid; use 0.0 instead
# FloatObject (b'220.3081.99') invalid; use 0.0 instead
# FloatObject (b'19.3105220.0225') invalid; use 0.0 instead
# FloatObject (b'1217471220.3081.9217471') invalid; use 0.0 instead
# FloatObject (b'19..247220.594') invalid; use 0.0 instead
# FloatObject (b'5.9220.594') invalid; use 0.0 instead
# FloatObject (b'19.144.220.8091.99.47.8221.0245') invalid; use 0.0 instead
# FloatObject (b'19.47.8221.524') invalid; use 0.0 instead
# FloatObject (b'19.144.221.524') invalid; use 0.0 instead
# FloatObject (b'19..247') invalid; use 0.0 instead
# FloatObject (b'21948717415.147.220.2371.95.30.7220.594') invalid; use 0.0 instead
# FloatObject (b'15.30.7221.31') invalid; use 0.0 instead
# FloatObject (b'15.147.221.5965') invalid; use 0.0 instead
# FloatObject (b'15.30.7221.8825') invalid; use 0.0 instead
# FloatObject (b'15.30.7222.025') invalid; use 0.0 instead
# FloatObject (b'15.30.7222.3115') invalid; use 0.0 instead
# FloatObject (b'15.30.7222.597') invalid; use 0.0 instead
# FloatObject (b'114037.82222.597') invalid; use 0.0 instead
# FloatObject (b'15.147.223.0265') invalid; use 0.0 instead
# FloatObject (b'15.147.222.597') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'19.0373223.9565') invalid; use 0.0 instead
# FloatObject (b'19.147.22410995') invalid; use 0.0 instead
# FloatObject (b'19.147.822241242') invalid; use 0.0 instead
# FloatObject (b'19.147.22413145') invalid; use 0.0 instead
# FloatObject (b'19.147.22415281.99.147.8222417431.99') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.47.8225.301') invalid; use 0.0 instead
# FloatObject (b'19.47.8223.67') invalid; use 0.0 instead
# FloatObject (b'19.147.82223.67') invalid; use 0.0 instead
# FloatObject (b'19.47.8222.955') invalid; use 0.0 instead
# FloatObject (b'144.222.6695') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.147.222.8835') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'147.223.0985') invalid; use 0.0 instead
# FloatObject (b'147.223.0985') invalid; use 0.0 instead
# FloatObject (b'1142.24232.115') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.825233.045') invalid; use 0.0 instead
# FloatObject (b'19.825231.681') invalid; use 0.0 instead
# FloatObject (b'145147.231.681') invalid; use 0.0 instead
# FloatObject (b'1142.39232.1815') invalid; use 0.0 instead
# FloatObject (b'15.30.7232.8965') invalid; use 0.0 instead
# FloatObject (b'15.30.7') invalid; use 0.0 instead
# FloatObject (b'15.30.723412555') invalid; use 0.0 instead
# FloatObject (b'19.147.232.539') invalid; use 0.0 instead
# FloatObject (b'144.232.8965') invalid; use 0.0 instead
# FloatObject (b'144.82233.3975') invalid; use 0.0 instead
# FloatObject (b'19.144.233.469') invalid; use 0.0 instead
# FloatObject (b'19..247233.469') invalid; use 0.0 instead
# FloatObject (b'19..317') invalid; use 0.0 instead
# FloatObject (b'19..317') invalid; use 0.0 instead
# FloatObject (b'19.47.8') invalid; use 0.0 instead
# FloatObject (b'19.47.8235.9725') invalid; use 0.0 instead
# FloatObject (b'19.147.23417565') invalid; use 0.0 instead
# FloatObject (b'15.147.235.9725') invalid; use 0.0 instead
# FloatObject (b'15.316.235.7575') invalid; use 0.0 instead
# FloatObject (b'15.316.235.1715') invalid; use 0.0 instead
# FloatObject (b'1142.24235.3995') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.316.235.3995') invalid; use 0.0 instead
# FloatObject (b'15.316.23140425') invalid; use 0.0 instead
# FloatObject (b'15.316.23144715') invalid; use 0.0 instead
# FloatObject (b'15.30.7235.7575') invalid; use 0.0 instead
# FloatObject (b'15.30.7') invalid; use 0.0 instead
# FloatObject (b'15.30.723217517415.147.23217517412.537.8223217517412.967.') invalid; use 0.0 instead
# FloatObject (b'12187.235.185') invalid; use 0.0 instead
# FloatObject (b'.247235.185') invalid; use 0.0 instead
# FloatObject (b'19.47.823145865') invalid; use 0.0 instead
# FloatObject (b'19.47.823212585') invalid; use 0.0 instead
# FloatObject (b'19.144.236.4015') invalid; use 0.0 instead
# FloatObject (b'19..317') invalid; use 0.0 instead
# FloatObject (b'19..317') invalid; use 0.0 instead
# FloatObject (b'18760.8239.9755') invalid; use 0.0 instead
# FloatObject (b'239.2591.99.47.8239.1161.99.47.8239.1161.99.144.82239.474') invalid; use 0.0 instead
# FloatObject (b'19.144.') invalid; use 0.0 instead
# FloatObject (b'12.537.') invalid; use 0.0 instead
# FloatObject (b'15.30.7238.0465') invalid; use 0.0 instead
# FloatObject (b'15.30.7') invalid; use 0.0 instead
# FloatObject (b'15.30.7238.69') invalid; use 0.0 instead
# FloatObject (b'114037.82238.0465') invalid; use 0.0 instead
# FloatObject (b'19.144.') invalid; use 0.0 instead
# FloatObject (b'19.144.') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'19..317') invalid; use 0.0 instead
# FloatObject (b'19.144.243.0535') invalid; use 0.0 instead
# FloatObject (b'19.147.82243.0535') invalid; use 0.0 instead
# FloatObject (b'19.147.242.552') invalid; use 0.0 instead
# FloatObject (b'121175.242.3385') invalid; use 0.0 instead
# FloatObject (b'114537.82241.6945') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'5.9241.6225') invalid; use 0.0 instead
# FloatObject (b'19.147.241.6225') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'241.9081.99') invalid; use 0.0 instead
# FloatObject (b'241.9081.99') invalid; use 0.0 instead
# FloatObject (b'240.6211.99') invalid; use 0.0 instead
# FloatObject (b'240.6211.99') invalid; use 0.0 instead
# FloatObject (b'19.147.82241.193') invalid; use 0.0 instead
# FloatObject (b'12187.241.837') invalid; use 0.0 instead
# FloatObject (b'1142.24241.985') invalid; use 0.0 instead
# FloatObject (b'15.147.') invalid; use 0.0 instead
# FloatObject (b'15.30.7242.1235') invalid; use 0.0 instead
# FloatObject (b'15.30.7242.195') invalid; use 0.0 instead
# FloatObject (b'15.30.7242.2665') invalid; use 0.0 instead
# FloatObject (b'15.316.242.3385') invalid; use 0.0 instead
# FloatObject (b'114037.82243.1965') invalid; use 0.0 instead
# FloatObject (b'19..247') invalid; use 0.0 instead
# FloatObject (b'19.144.243.41') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'1142.39216.057') invalid; use 0.0 instead
# FloatObject (b'.247216.057') invalid; use 0.0 instead
# FloatObject (b'19.825213.9835') invalid; use 0.0 instead
# FloatObject (b'19.1195213.9835') invalid; use 0.0 instead
# FloatObject (b'19.047.') invalid; use 0.0 instead
# FloatObject (b'147.884245.054') invalid; use 0.0 instead
# FloatObject (b'12187.245.555') invalid; use 0.0 instead
# FloatObject (b'19.047.') invalid; use 0.0 instead
# FloatObject (b'19..247215.555') invalid; use 0.0 instead
# FloatObject (b'5.9245.555') invalid; use 0.0 instead
# FloatObject (b'19.144.245.7691.99.47.8215.1845') invalid; use 0.0 instead
# FloatObject (b'19.47.821144855') invalid; use 0.0 instead
# FloatObject (b'19.144.24144855') invalid; use 0.0 instead
# FloatObject (b'19..247') invalid; use 0.0 instead
# FloatObject (b'15.147.215.1975') invalid; use 0.0 instead
# FloatObject (b'15.30.7245.555') invalid; use 0.0 instead
# FloatObject (b'15.30.7241427') invalid; use 0.0 instead
# FloatObject (b'15.147.21144855') invalid; use 0.0 instead
# FloatObject (b'15.30.724148425') invalid; use 0.0 instead
# FloatObject (b'15.30.72414914') invalid; use 0.0 instead
# FloatObject (b'15.30.724472715') invalid; use 0.0 instead
# FloatObject (b'15.30.72147557') invalid; use 0.0 instead
# FloatObject (b'15.147.2147.155') invalid; use 0.0 instead
# FloatObject (b'15.147.21475575') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'19.047.249.9165') invalid; use 0.0 instead
# FloatObject (b'19.147.21870595') invalid; use 0.0 instead
# FloatObject (b'19.147.8224872035') invalid; use 0.0 instead
# FloatObject (b'19.147.21872745') invalid; use 0.0 instead
# FloatObject (b'19.147.21874895') invalid; use 0.0 instead
# FloatObject (b'19.147.8224876325') invalid; use 0.0 instead
# FloatObject (b'19.147.2187775') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.47.821876325') invalid; use 0.0 instead
# FloatObject (b'19.825219.9165') invalid; use 0.0 instead
# FloatObject (b'19.47.8219.43') invalid; use 0.0 instead
# FloatObject (b'19.147.82249.43') invalid; use 0.0 instead
# FloatObject (b'19.47.82147.155') invalid; use 0.0 instead
# FloatObject (b'19.144.24475575') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.147.822447.155') invalid; use 0.0 instead
# FloatObject (b'19.147.219.0585') invalid; use 0.0 instead
# FloatObject (b'19.147.219.0585') invalid; use 0.0 instead
# FloatObject (b'15.7.39') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'259..155') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.147.259.2155') invalid; use 0.0 instead
# FloatObject (b'15.147.') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'19.47.81') invalid; use 0.0 instead
# FloatObject (b'19.47.82587287') invalid; use 0.0 instead
# FloatObject (b'19.144.822587287') invalid; use 0.0 instead
# FloatObject (b'19.147.25872165') invalid; use 0.0 instead
# FloatObject (b'19.147.25870735') invalid; use 0.0 instead
# FloatObject (b'19.047.259.4295') invalid; use 0.0 instead
# FloatObject (b'121647.259.2155') invalid; use 0.0 instead
# FloatObject (b'16.547.') invalid; use 0.0 instead
# FloatObject (b'15.147.25215715') invalid; use 0.0 instead
# FloatObject (b'15.147.25211425') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.147.259.8615') invalid; use 0.0 instead
# FloatObject (b'15.3.24259.503') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.3.24260.5055') invalid; use 0.0 instead
# FloatObject (b'15.147.260.5055') invalid; use 0.0 instead
# FloatObject (b'19.047.') invalid; use 0.0 instead
# FloatObject (b'19.1195260.934') invalid; use 0.0 instead
# FloatObject (b'19.147.261.1485') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.147.261.6495') invalid; use 0.0 instead
# FloatObject (b'19.147.261.6495') invalid; use 0.0 instead
# FloatObject (b'15.3.24261.506') invalid; use 0.0 instead
# FloatObject (b'15.3.24261.225') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.147.262.2215') invalid; use 0.0 instead
# FloatObject (b'19.825261.434') invalid; use 0.0 instead
# FloatObject (b'19.144.260.5055') invalid; use 0.0 instead
# FloatObject (b'19.47.8259.789') invalid; use 0.0 instead
# FloatObject (b'19.144.822597503') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.147.259.7185') invalid; use 0.0 instead
# FloatObject (b'19.147.') invalid; use 0.0 instead
# FloatObject (b'19.147.259.932') invalid; use 0.0 instead
# FloatObject (b'19.147.259.932') invalid; use 0.0 instead
# FloatObject (b'19..247262.865') invalid; use 0.0 instead
# FloatObject (b'1142.24263.5095') invalid; use 0.0 instead
# FloatObject (b'15.30.7265.367') invalid; use 0.0 instead
# FloatObject (b'15.30.7') invalid; use 0.0 instead
# FloatObject (b'15.30.7265.797') invalid; use 0.0 instead
# FloatObject (b'5.9265.225') invalid; use 0.0 instead
# FloatObject (b'15.3.24263.5095') invalid; use 0.0 instead
# FloatObject (b'5.9263.8665') invalid; use 0.0 instead
# FloatObject (b'12187.265.225') invalid; use 0.0 instead
# FloatObject (b'15.3.24265.4385') invalid; use 0.0 instead
# FloatObject (b'19..317') invalid; use 0.0 instead
# FloatObject (b'19.147.8226978745') invalid; use 0.0 instead
# FloatObject (b'19.147.26978035') invalid; use 0.0 instead
# FloatObject (b'19.147.2687515') invalid; use 0.0 instead
# FloatObject (b'19.147.822687515') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'19.144.26871585') invalid; use 0.0 instead
# FloatObject (b'19.147.264787') invalid; use 0.0 instead
# FloatObject (b'19.147.82264787') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'19.144.26472985') invalid; use 0.0 instead
# FloatObject (b'15.147.') invalid; use 0.0 instead
# FloatObject (b'15.7.39269.3715') invalid; use 0.0 instead
# FloatObject (b'15.30.7') invalid; use 0.0 instead
# FloatObject (b'15.30.7269.4425') invalid; use 0.0 instead
# FloatObject (b'15.7.39269.1855') invalid; use 0.0 instead
# FloatObject (b'15.147.') invalid; use 0.0 instead
# FloatObject (b'15.147.') invalid; use 0.0 instead
# FloatObject (b'15.7.3926970165') invalid; use 0.0 instead
# FloatObject (b'15.30.7') invalid; use 0.0 instead
# FloatObject (b'15.30.726971595') invalid; use 0.0 instead
# FloatObject (b'15.7.3926972315') invalid; use 0.0 instead
# FloatObject (b'15.147.') invalid; use 0.0 instead
# FloatObject (b'19.144.270.303') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'19..3171') invalid; use 0.0 instead
# FloatObject (b'15.147.271.0195') invalid; use 0.0 instead
# FloatObject (b'15.3.24270.7325') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.7.391') invalid; use 0.0 instead
# FloatObject (b'15.3.24') invalid; use 0.0 instead
# FloatObject (b'15.147.271.662') invalid; use 0.0 instead
# FloatObject (b'19.047.') invalid; use 0.0 instead
# FloatObject (b'19.1195272.143') invalid; use 0.0 instead
# FloatObject (b'19.147.272.3785') invalid; use 0.0 instead
# ...
# FloatObject (b'3845225225.401.') invalid; use 0.0 instead
# FloatObject (b'384951.2214887.') invalid; use 0.0 instead
# FloatObject (b'.1073152247817.') invalid; use 0.0 instead
# FloatObject (b'.107096.') invalid; use 0.0 instead
# FloatObject (b'.384379.2264388.') invalid; use 0.0 instead
# FloatObject (b'38488.2274461.') invalid; use 0.0 instead
# FloatObject (b'.1073152284462.') invalid; use 0.0 instead
# FloatObject (b'107239.2284534.') invalid; use 0.0 instead
# FloatObject (b'.384164.2284033') invalid; use 0.0 instead
# FloatObject (b'.384021.') invalid; use 0.0 instead
# FloatObject (b'.39.878.2284033') invalid; use 0.0 instead
# FloatObject (b'.39.664.2284319.') invalid; use 0.0 instead
# FloatObject (b'39.664.') invalid; use 0.0 instead
# FloatObject (b'.39.664.2294034.') invalid; use 0.0 instead
# FloatObject (b'384021.2294249.') invalid; use 0.0 instead
# FloatObject (b'2834821..364519.2834464.') invalid; use 0.0 instead
# FloatObject (b'364662.2834464.') invalid; use 0.0 instead
# FloatObject (b'39.02.2834178') invalid; use 0.0 instead
# FloatObject (b'39.02.') invalid; use 0.0 instead
# FloatObject (b'.39.02.282.892..364805.') invalid; use 0.0 instead
# FloatObject (b'282.892..36444852834178') invalid; use 0.0 instead
# FloatObject (b'364376.2834392..364376.') invalid; use 0.0 instead
# FloatObject (b'.036.') invalid; use 0.0 instead
# FloatObject (b'.394.') invalid; use 0.0 instead
# FloatObject (b'.68.') invalid; use 0.0 instead
# FloatObject (b'39.95.') invalid; use 0.0 instead
# FloatObject (b'285.109.') invalid; use 0.0 instead
# FloatObject (b'.465.') invalid; use 0.0 instead
# FloatObject (b'.465.') invalid; use 0.0 instead
# FloatObject (b'.608.') invalid; use 0.0 instead
# FloatObject (b'11.689.') invalid; use 0.0 instead
# FloatObject (b'11.8125285.486.') invalid; use 0.0 instead
# FloatObject (b'.894.') invalid; use 0.0 instead
# FloatObject (b'.894.') invalid; use 0.0 instead
# FloatObject (b'11.689.') invalid; use 0.0 instead
# FloatObject (b'.894.') invalid; use 0.0 instead
# FloatObject (b'11.526.285.5385') invalid; use 0.0 instead
# FloatObject (b'11.689.') invalid; use 0.0 instead
# FloatObject (b'117885.3384036.') invalid; use 0.0 instead
# FloatObject (b'11.885.3384036.') invalid; use 0.0 instead
# FloatObject (b'11.689.') invalid; use 0.0 instead
# FloatObject (b'11.526.3374965.') invalid; use 0.0 instead
# FloatObject (b'.39.807.33647495') invalid; use 0.0 instead
# FloatObject (b'.39.807.3364534.') invalid; use 0.0 instead
# FloatObject (b'39.878.3364534.') invalid; use 0.0 instead
# FloatObject (b'384164.3364534.') invalid; use 0.0 instead
# FloatObject (b'384379.3364391.') invalid; use 0.0 instead
# FloatObject (b'384379.3314891.') invalid; use 0.0 instead
# FloatObject (b'39.807.3364325') invalid; use 0.0 instead
# FloatObject (b'.39.5925') invalid; use 0.0 instead
# FloatObject (b'384308.3374965.') invalid; use 0.0 instead
# FloatObject (b'117885.3394181.') invalid; use 0.0 instead
# FloatObject (b'117598.3107254.') invalid; use 0.0 instead
# FloatObject (b'39.878.3384895') invalid; use 0.0 instead
# FloatObject (b'.384808.') invalid; use 0.0 instead
# FloatObject (b'384236.3114755.') invalid; use 0.0 instead
# FloatObject (b'394452.3117541.') invalid; use 0.0 instead
# FloatObject (b'11.81253117541.') invalid; use 0.0 instead
# FloatObject (b'11.8125312.7575') invalid; use 0.0 instead
# FloatObject (b'11.689.312.7575') invalid; use 0.0 instead
# FloatObject (b'1349.692.') invalid; use 0.0 instead
# FloatObject (b'117598.3164118.') invalid; use 0.0 instead
# FloatObject (b'11.168.315.489') invalid; use 0.0 instead
# FloatObject (b'315.046.') invalid; use 0.0 instead
# FloatObject (b'117885.315.475.') invalid; use 0.0 instead
# FloatObject (b'.11.955') invalid; use 0.0 instead
# FloatObject (b'.11.955') invalid; use 0.0 instead
# FloatObject (b'.11424.') invalid; use 0.0 instead
# FloatObject (b'39.878.3434329.') invalid; use 0.0 instead
# FloatObject (b'39.878.342.971') invalid; use 0.0 instead
# FloatObject (b'39.878.34') invalid; use 0.0 instead
# FloatObject (b'384308.314.259') invalid; use 0.0 instead
# FloatObject (b'315.475.') invalid; use 0.0 instead
# FloatObject (b'315.546.') invalid; use 0.0 instead
# FloatObject (b'.384236.315.489') invalid; use 0.0 instead
# FloatObject (b'.384021.') invalid; use 0.0 instead
# FloatObject (b'.374878.345.546.') invalid; use 0.0 instead
# FloatObject (b'374878.345.1895') invalid; use 0.0 instead
# FloatObject (b'.384236.') invalid; use 0.0 instead
# FloatObject (b'117741.319.477') invalid; use 0.0 instead
# FloatObject (b'117885.319.692.') invalid; use 0.0 instead
# FloatObject (b'117885.3184836.') invalid; use 0.0 instead
# FloatObject (b'11.885.3184836.') invalid; use 0.0 instead
# FloatObject (b'11.689.') invalid; use 0.0 instead
# FloatObject (b'11.526.3184765.') invalid; use 0.0 instead
# FloatObject (b'374878.349.692.') invalid; use 0.0 instead
# FloatObject (b'374878.349.406') invalid; use 0.0 instead
# FloatObject (b'.39.807.') invalid; use 0.0 instead
# FloatObject (b'.39.735') invalid; use 0.0 instead
# FloatObject (b'.39.735') invalid; use 0.0 instead
# FloatObject (b'.39.807.1') invalid; use 0.0 instead
# FloatObject (b'374878.348455.') invalid; use 0.0 instead
# FloatObject (b'374878.348455.') invalid; use 0.0 instead
# FloatObject (b'384236.318455.') invalid; use 0.0 instead
# FloatObject (b'.394881.') invalid; use 0.0 instead
# FloatObject (b'394881.3194409.') invalid; use 0.0 instead
# FloatObject (b'107167.3507195.') invalid; use 0.0 instead
# FloatObject (b'.107096.') invalid; use 0.0 instead
# FloatObject (b'11.81253517268.') invalid; use 0.0 instead
# FloatObject (b'11.741.3517268.') invalid; use 0.0 instead
# FloatObject (b'11.24.3517268.') invalid; use 0.0 instead
# FloatObject (b'11.168.3517268.') invalid; use 0.0 instead
# FloatObject (b'61.9456.') invalid; use 0.0 instead
# Error processing ../../../detect_ml_model_files/09bbf18a-eb17-4536-b12b-469c9c5d6c75.pdf: list index out of range
# non-PDF content: https://www.academia.edu/download/52484748/Kalman_CoursePack_08.pdf
# Downloaded: ../../../detect_ml_model_files/1eccd87a-3d78-4094-9a34-763bdc12bd20.pdf
# non-PDF content: https://www.academia.edu/download/52364275/Kalman_filtering_using_Matlab.pdf
# Downloaded: ../../../detect_ml_model_files/cd8540f6-d543-4bb5-8890-c69181c06ce4.pdf
# Downloaded: ../../../detect_ml_model_files/3d129e04-de6d-4a8a-bb63-d4074926f968.pdf
# Downloaded: ../../../detect_ml_model_files/a5ebfcd7-8863-4490-8ac2-9d99e8de4f02.pdf
# No text found in ../../../detect_ml_model_files/a5ebfcd7-8863-4490-8ac2-9d99e8de4f02.pdf
# Downloaded: ../../../detect_ml_model_files/bef412b7-6e2a-4188-8dea-40d3f33f999e.pdf
# Downloaded: ../../../detect_ml_model_files/92a12e97-b2fa-4c03-9864-756ebbe575e3.pdf
# Searching for: Vector Autoregression
# non-PDF content: https://pubs.aeaweb.org/doi/pdf/10.1257/jep.15.4.101
# Downloaded: ../../../detect_ml_model_files/e2bc2e48-e5d2-49a6-96c2-3516e34b3d3b.pdf
# Downloaded: ../../../detect_ml_model_files/a8a13812-ae4c-45fd-b912-60afb02b6606.pdf
# non-PDF content: https://journals.sagepub.com/doi/full/10.1177/1536867X1601600314
# Downloaded: ../../../detect_ml_model_files/96b263c2-5bcc-4133-afd8-d72bcbe959f2.pdf
# Downloaded: ../../../detect_ml_model_files/450cfaec-afde-4d84-99df-2421770a6e82.pdf
# /home/reza/miniconda3/envs/ml-lncRNA/lib/python3.12/site-packages/PyPDF2/_cmap.py:142: PdfReadWarning: Advanced encoding /UniGB-UTF16-H not implemented yet
#   warnings.warn(
# Downloaded: ../../../detect_ml_model_files/7e835186-822f-41a4-9582-436bd07f021a.pdf
# Downloaded: ../../../detect_ml_model_files/7ef6e5d6-fd77-456f-9da4-96b4395fe610.pdf
# Searching for: Prophet
# Downloaded: ../../../detect_ml_model_files/f2b7be36-ce2a-4242-9fa5-51f9cdeabf9e.pdf
# Downloaded: ../../../detect_ml_model_files/d04a8869-9754-4265-92dc-739ec3a23a50.pdf
# Downloaded: ../../../detect_ml_model_files/9ed433e8-d53c-4868-8746-f6a8409430f4.pdf
# non-PDF content: https://marxists.architexturez.net/francais/harman/1994/00/propheteproletariat.pdf
# non-PDF content: https://books.google.com/books?hl=en&lr=&id=L2AzAQAAMAAJ&oi=fnd&pg=PR34&dq=Prophet&ots=JiZY9RrmYN&sig=ZerdjpO0hVBGhcro3er195KrwPM
# Downloaded: ../../../detect_ml_model_files/7bd8e37c-23ff-4f66-aaf8-335171ac036d.pdf
# No text found in ../../../detect_ml_model_files/7bd8e37c-23ff-4f66-aaf8-335171ac036d.pdf
# Downloaded: ../../../detect_ml_model_files/2cef7b22-1e52-43cf-a6c0-0dab614fccff.pdf
# non-PDF content: https://classes.matthewjbrown.net/teaching-files/pragmatism/rorty-west.pdf
# non-PDF content: https://www.academia.edu/download/114611210/Prophet_MobileOPT.pdf
# Downloaded: ../../../detect_ml_model_files/932f8a34-207d-4b45-97ea-432a0f76f807.pdf
# Searching for: Stacking
# Downloaded: ../../../detect_ml_model_files/ffc7286a-7397-4368-8ba2-f80511c81564.pdf
# No text found in ../../../detect_ml_model_files/ffc7286a-7397-4368-8ba2-f80511c81564.pdf
# Downloaded: ../../../detect_ml_model_files/299b5e42-19bb-4751-978a-bf77df1e122b.pdf
# Downloaded: ../../../detect_ml_model_files/7545e598-aff5-4d7b-b907-2dd3ad3f230d.pdf
# Downloaded: ../../../detect_ml_model_files/5db67baf-4298-4994-bf56-55af2fe65100.pdf
# Downloaded: ../../../detect_ml_model_files/a66f04b6-b78f-442f-bf24-5c355dcd2eb5.pdf
# Error occurred while processing https://pubs.rsc.org/en/content/getauthorversionpdf/d0cp05039c: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# non-PDF content: https://cdn.videocardz.com/1/2014/05/HBM.pdf
# non-PDF content: https://www.researchgate.net/profile/Rommert-Dekker/publication/226468887_Advanced_methods_for_container_stacking/links/0046353b217eaa30be000000/Advanced-methods-for-container-stacking.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S0021925818985996/pdf?md5=66143d2292b1d1e9905f22dd83981aa3&pid=1-s2.0-S0021925818985996-main.pdf
# Downloaded: ../../../detect_ml_model_files/5098bf09-8f52-40fd-9b65-aaab5dee02da.pdf
# Searching for: ChatGPT
# non-PDF content: https://www.researchgate.net/profile/Som-Biswas-2/publication/369269117_Role_of_Chat_GPT_in_Public_Health/links/6412c5a792cfd54f84044415/Role-of-Chat-GPT-in-Public-Health.pdf?trk=public_post_comment-text
# non-PDF content: https://www.ltimindtree.com/wp-content/uploads/2023/02/ChatGPT-An-AI-NLP-Model-POV.pdf
# non-PDF content: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4402499
# non-PDF content: https://osf.io/9ge8m/download
# non-PDF content: https://www.ieee-jas.net/en/article/doi/10.1109/JAS.2023.123618
# non-PDF content: https://www.mdpi.com/2227-7102/13/4/410
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S156625352300177X
# Downloaded: ../../../detect_ml_model_files/9588dca8-7064-4c69-b161-5c518f86acdc.pdf
# non-PDF content: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4405389
# non-PDF content: https://www.researchgate.net/profile/William-Castillo-Gonzalez/publication/373185669_Chat_GPT_a_promising_tool_for_academic_editing/links/6529b5292e1ba453041ea237/Chat-GPT-a-promising-tool-for-academic-editing.pdf
# Downloaded: ../../../detect_ml_model_files/bfcf8ec9-4542-4fef-a7a3-504695648aac.pdf
# non-PDF content: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4480551
# non-PDF content: https://www.frontiersin.org/articles/10.3389/fpsyg.2023.1181712/full
# non-PDF content: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4405391
# non-PDF content: https://www.researchgate.net/profile/Som-Biswas-2/publication/368856220_Prospective_Role_of_Chat_GPT_in_the_Military_According_to_ChatGPT/links/65791796cbd2c535ea1c0cba/Prospective-Role-of-Chat-GPT-in-the-Military-According-to-ChatGPT.pdf
# non-PDF content: https://www.mdpi.com/1999-5903/15/6/192
# non-PDF content: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4333415
# non-PDF content: https://www.researchgate.net/profile/Velibor-Bozic-2/publication/369926506_Chat_GPT_and_education/links/64350844ad9b6d17dc4d3a79/Chat-GPT-and-education.pdf
# Downloaded: ../../../detect_ml_model_files/a7ac924f-886c-4869-b5a6-e91158bff76a.pdf
# non-PDF content: https://www.researchgate.net/profile/Luis-Chauca-Huete/publication/373949976_Exploring_the_ethical_considerations_of_using_Chat_GPT_in_university_education/links/6504f02a9fdf0c69dfd0553f/Exploring-the-ethical-considerations-of-using-Chat-GPT-in-university-education.pdf
# non-PDF content: https://papers.ssrn.com/sol3/Delivery.cfm?abstractid=4308687
# non-PDF content: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10002821/
# non-PDF content: https://www.frontiersin.org/articles/10.3389/feduc.2023.1166682/full
# Downloaded: ../../../detect_ml_model_files/139a85e5-d5d2-4f25-af60-be53b1c0b37e.pdf
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S2667345223000317
# non-PDF content: https://pubs.acs.org/doi/full/10.1021/acs.est.3c01818
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S295016282300022X
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S266734522300024X
# non-PDF content: https://dergipark.org.tr/en/doi/10.61969/jai.1337500
# non-PDF content: https://www.mdpi.com/2227-9032/11/6/887
# non-PDF content: https://www.sciencedirect.com/science/article/pii/S2666920X23000590
# Downloaded: ../../../detect_ml_model_files/fa7a7206-d7b6-4e3a-bb5f-55e7f16f1106.pdf
# Downloaded: ../../../detect_ml_model_files/6eed5846-2614-4aef-b0b5-52aebbf056bf.pdf
# Searching for: LLaMA
# Downloaded: ../../../detect_ml_model_files/535ca623-e366-4ebd-ab52-8e7e585033a0.pdf
# Downloaded: ../../../detect_ml_model_files/038acdd4-821d-4213-9da6-5ef4ce5a7bdf.pdf
# Downloaded: ../../../detect_ml_model_files/c8ef7cfa-e015-4948-9f18-0032914cf9f6.pdf
# non-PDF content: https://www.academia.edu/download/97151133/Llama_constellation_ALL09_Zuidema_Urton.pdf
# Downloaded: ../../../detect_ml_model_files/ac90818f-187d-41a0-bb7c-eabaee69e829.pdf
# Downloaded: ../../../detect_ml_model_files/6ff37a4a-125d-46b2-853c-de2dfc8951e8.pdf
# Downloaded: ../../../detect_ml_model_files/9e4c7b49-2d76-4202-9bfa-3629b3227bfd.pdf
# Downloaded: ../../../detect_ml_model_files/32e0de91-d683-44e4-97eb-06326120a7fd.pdf
# Downloaded: ../../../detect_ml_model_files/6a090e6f-d8e0-4667-8f54-be4cf3489cb9.pdf
# non-PDF content: https://www.researchgate.net/profile/Osiris-Quezada/publication/333660094_El_Templo_Mayor_de_Tenochtitlan_sistemas3/links/5cfb3940a6fdccd1308a6be1/El-Templo-Mayor-de-Tenochtitlan-sistemas3.pdf#page=312
# non-PDF content: http://www.scielo.org.co/scielo.php?pid=S0120-81602018000100079&script=sci_arttext
# Downloaded: ../../../detect_ml_model_files/927466f3-11db-4836-bcb2-ea4b4c4695f5.pdf
# Downloaded: ../../../detect_ml_model_files/3b96923f-fd1a-485c-a4a2-cce732c26886.pdf
# non-PDF content: https://www.researchgate.net/profile/Jane-Wheeler/publication/28057641_A_measure_of_loss_Prehispanic_Llama_and_Alpaca_breeds/links/57bf129608ae2f5eb32e783f/A-measure-of-loss-Prehispanic-Llama-and-Alpaca-breeds.pdf
# Downloaded: ../../../detect_ml_model_files/c205654d-1721-4a94-9b42-85fe97eab963.pdf
# Downloaded: ../../../detect_ml_model_files/161d11f8-fdb1-445e-8cbe-1ab7cda13195.pdf
# non-PDF content: http://www.scielo.org.pe/scielo.php?pid=S1609-91172016000200001&script=sci_arttext&tlng=en
# Downloaded: ../../../detect_ml_model_files/2764e547-0f23-4c05-94c2-fe8bbea346fc.pdf
# Downloaded: ../../../detect_ml_model_files/094c84c1-c9d6-4302-a100-311f513862da.pdf
# non-PDF content: https://www.researchgate.net/profile/Dino-Giussani/publication/10666988_The_Fetal_Llama_versus_the_Fetal_Sheep_Different_Strategies_to_Withstand_Hypoxia/links/568e657308aeaa1481b0164c/The-Fetal-Llama-versus-the-Fetal-Sheep-Different-Strategies-to-Withstand-Hypoxia.pdf
# Downloaded: ../../../detect_ml_model_files/dff07229-a282-469e-a7ae-63a74bc6f911.pdf
# non-PDF content: http://www.scielo.org.ar/scielo.php?pid=S1851-17322009000200004&script=sci_arttext
# non-PDF content: http://www.scielo.org.pe/scielo.php?pid=S1609-91172014000200001&script=sci_arttext&tlng=pt
# Downloaded: ../../../detect_ml_model_files/e8b85264-2cac-4c48-81f4-6180297047df.pdf
# Downloaded: ../../../detect_ml_model_files/123fb0f1-66c6-4aca-be6c-4ac275a094db.pdf
# non-PDF content: https://www.scielo.cl/scielo.php?pid=S0716-078X2007000200001&script=sci_arttext
# Downloaded: ../../../detect_ml_model_files/06cbe5c2-80d8-4390-b53a-8ab259e30e44.pdf

# %%
# can do it in one line but is it easier to read?
# flattened_search_results = [paper for paper in papers for papers in search_results]
flattened_search_results = list()
for papers in search_results:
    for paper in papers:
        flattened_search_results.append(paper)

# %%
data_df = pd.DataFrame(flattened_search_results)

# %%
data_df
# Out:
#                                                  title  \
# 0                                    Linear regression
# 1           Introduction to linear regression analysis
# 2                                    Linear regression
# 3                            Applied linear regression
# 4                                    Linear regression
# ..                                                 ...
# 387  Características de canal, calidad de carne y c...
# 388  Características físico-químicas del charqui de...
# 389  Antología de la prensa periódica isabelina esc...
# 390  Sistemática, taxonomía y domesticación de alpa...
# 391  Huatuo: Tuning llama model with chinese medica...
#
#                                               abstract  year  \
# 0    Linear regression plays a fundamental role in ...  2012
# 1    Equation (1.2) is called a linear regression m...  2021
# 2    linear regression, a very simple approach for ...  2023
# 3    Applied linear regression Applied linear regre...  2005
# 4    In linear regression the ordinary least square...  2012
# ..                                                 ...   ...
# 387  La carne de llama presenta un alto nivel prote...  2014
# 388                                                     2011
# 389  "Antología de la prensa periódica isabelina es...  2001
# 390  , grouping guanaco with llama and vicuña with ...  2007
# 391  Large Language Models (LLMs), such as the LLaM...  2023
#
#                                                    url  \
# 0    https://www.cs.columbia.edu/~djhsu/coms4771-f2...
# 1    http://sutlib2.sut.ac.th/sut_contents/H133678.pdf
# 2         https://datamineaz.org/readings/ISL_chp3.pdf
# 3    https://www.stat.cmu.edu/~brian/valerie/617-20...
# 4
# ..                                                 ...
# 387  http://www.scielo.org.pe/scielo.php?pid=S1609-...
# 388  https://www.redalyc.org/pdf/3718/371838943002.pdf
# 389  https://rodin.uca.es/bitstream/handle/10498/26...
# 390  https://www.scielo.cl/scielo.php?pid=S0716-078...
# 391                   https://arxiv.org/pdf/2304.06975
#
#                                              author_id              query  \
# 0                       [wcgZZP8AAAAJ, , El-UNYoAAAAJ]  Linear Regression
# 1                       [5PboKNAAAAAJ, , y2eb6cQAAAAJ]  Linear Regression
# 2    [KUIjZqgAAAAJ, bHZf-c8AAAAJ, tQVe-fAAAAAJ, ZpG...  Linear Regression
# 3                                       [wlu6jZQAAAAJ]  Linear Regression
# 4                                       [vBWC0XIAAAAJ]  Linear Regression
# ..                                                 ...                ...
# 387                                             [, , ]              LLaMA
# 388                                               [, ]              LLaMA
# 389                                                 []              LLaMA
# 390                   [, , zTlcXB4AAAAJ, AcJZnfEAAAAJ]              LLaMA
# 391  [olOglGgAAAAJ, abmQYmYAAAAJ, 6jFEal4AAAAJ, , Z...              LLaMA
#
#                                     file_name  \
# 0    4b55ea85-209f-4ff8-9657-5d6d08ed6ad2.pdf
# 1    fcfc4d57-a217-4ba2-8cc9-eb7f40b92540.pdf
# 2    fba635a5-3044-4e07-b058-8e4d9f947c32.pdf
# 3    b143697b-982f-42a3-91bb-8337dc5d9b50.pdf
# 4
# ..                                        ...
# 387
# 388  e8b85264-2cac-4c48-81f4-6180297047df.pdf
# 389  123fb0f1-66c6-4aca-be6c-4ac275a094db.pdf
# 390
# 391  06cbe5c2-80d8-4390-b53a-8ab259e30e44.pdf
#
#                                              file_path language
# 0    ../../../detect_ml_model_files/4b55ea85-209f-4...       en
# 1    ../../../detect_ml_model_files/fcfc4d57-a217-4...     None
# 2    ../../../detect_ml_model_files/fba635a5-3044-4...       en
# 3    ../../../detect_ml_model_files/b143697b-982f-4...       en
# 4                                                 None     None
# ..                                                 ...      ...
# 387                                               None     None
# 388  ../../../detect_ml_model_files/e8b85264-2cac-4...       es
# 389  ../../../detect_ml_model_files/123fb0f1-66c6-4...       es
# 390                                               None     None
# 391  ../../../detect_ml_model_files/06cbe5c2-80d8-4...       en
#
# [392 rows x 9 columns]

# %%
if merge_with_previous:
    data_df = pd.concat([saved_data_df, data_df], ignore_index=True)

# %%
data_df
# Out:
#                                                   title  \
# 0                                      Ridge regression
# 1                          Ridge regression in practice
# 2             New ridge parameters for ridge regression
# 3     Ridge regression: applications to nonorthogona...
# 4                     Lecture notes on ridge regression
# ...                                                 ...
# 1324  Características de canal, calidad de carne y c...
# 1325  Características físico-químicas del charqui de...
# 1326  Antología de la prensa periódica isabelina esc...
# 1327  Sistemática, taxonomía y domesticación de alpa...
# 1328  Huatuo: Tuning llama model with chinese medica...
#
#                                                abstract  year  \
# 0     Ridge regression is a popular parameter estima...  2009
# 1     In regular use of ridge regression we display ...  1975
# 2     In ridge regression, ridge parameter plays an ...  2014
# 3     This paper is an exposition of the use of ridg...  1970
# 4     well-known results on ridge regression. The cu...  2015
# ...                                                 ...   ...
# 1324  La carne de llama presenta un alto nivel prote...  2014
# 1325                                                     2011
# 1326  "Antología de la prensa periódica isabelina es...  2001
# 1327  , grouping guanaco with llama and vicuña with ...  2007
# 1328  Large Language Models (LLMs), such as the LLaM...  2023
#
#                                                     url  \
# 0
# 1     https://www.researchgate.net/profile/David-Boo...
# 2     https://www.sciencedirect.com/science/article/...
# 3     https://scholar.archive.org/work/zedzhecp75hdj...
# 4                      https://arxiv.org/pdf/1509.09169
# ...                                                 ...
# 1324  http://www.scielo.org.pe/scielo.php?pid=S1609-...
# 1325  https://www.redalyc.org/pdf/3718/371838943002.pdf
# 1326  https://rodin.uca.es/bitstream/handle/10498/26...
# 1327  https://www.scielo.cl/scielo.php?pid=S0716-078...
# 1328                   https://arxiv.org/pdf/2304.06975
#
#                                               author_id             query  \
# 0                                        [i-68VW8AAAAJ]  Ridge Regression
# 1                                      [, SelQvxgAAAAJ]  Ridge Regression
# 2                                                    []  Ridge Regression
# 3                                                  [, ]  Ridge Regression
# 4                                        [qglWXEQAAAAJ]  Ridge Regression
# ...                                                 ...               ...
# 1324                                             [, , ]             LLaMA
# 1325                                               [, ]             LLaMA
# 1326                                                 []             LLaMA
# 1327                   [, , zTlcXB4AAAAJ, AcJZnfEAAAAJ]             LLaMA
# 1328  [olOglGgAAAAJ, abmQYmYAAAAJ, 6jFEal4AAAAJ, , Z...             LLaMA
#
#                                      file_name  \
# 0
# 1
# 2
# 3     520946c9-4f85-4fd1-bfe5-2305c315cb1b.pdf
# 4     7f813b9f-7b00-4610-b3fe-30b85ad26b51.pdf
# ...                                        ...
# 1324
# 1325  e8b85264-2cac-4c48-81f4-6180297047df.pdf
# 1326  123fb0f1-66c6-4aca-be6c-4ac275a094db.pdf
# 1327
# 1328  06cbe5c2-80d8-4390-b53a-8ab259e30e44.pdf
#
#                                               file_path language
# 0                                                  None     None
# 1                                                  None     None
# 2                                                  None     None
# 3     ../../../detect_ml_model_files/520946c9-4f85-4...       en
# 4     ../../../detect_ml_model_files/7f813b9f-7b00-4...       en
# ...                                                 ...      ...
# 1324                                               None     None
# 1325  ../../../detect_ml_model_files/e8b85264-2cac-4...       es
# 1326  ../../../detect_ml_model_files/123fb0f1-66c6-4...       es
# 1327                                               None     None
# 1328  ../../../detect_ml_model_files/06cbe5c2-80d8-4...       en
#
# [1329 rows x 9 columns]

# %% [markdown]
# Do some basic checks to see if there are exactly five files in the english language for each model

# %%
check_df = data_df.dropna()

# %%
check_df
# Out:
#                                                   title  \
# 3     Ridge regression: applications to nonorthogona...
# 4                     Lecture notes on ridge regression
# 5           A critique of some ridge regression methods
# 6     Ridge regression learning algorithm in dual va...
# 7     Ridge regression: Biased estimation for nonort...
# ...                                                 ...
# 1318        Code llama: Open foundation models for code
# 1321                Los días de llamas de la revolución
# 1325  Características físico-químicas del charqui de...
# 1326  Antología de la prensa periódica isabelina esc...
# 1328  Huatuo: Tuning llama model with chinese medica...
#
#                                                abstract  year  \
# 3     This paper is an exposition of the use of ridg...  1970
# 4     well-known results on ridge regression. The cu...  2015
# 5     These techniques are consequently all subject ...  1980
# 6     of the Ridge Regression procedure. It allows u...  1998
# 7     For this reason, estimation and analysis built...  1970
# ...                                                 ...   ...
# 1318  from Llama 2 to Code Llama in  Llama models cl...  2023
# 1321  Ya a la altura del verano de 1938, cuando el f...  2003
# 1325                                                     2011
# 1326  "Antología de la prensa periódica isabelina es...  2001
# 1328  Large Language Models (LLMs), such as the LLaM...  2023
#
#                                                     url  \
# 3     https://scholar.archive.org/work/zedzhecp75hdj...
# 4                      https://arxiv.org/pdf/1509.09169
# 5     http://economics-files.pomona.edu/garysmith/pa...
# 6     https://eprints.soton.ac.uk/258942/1/Dualrr_IC...
# 7     https://mineracaodedados.wordpress.com/wp-cont...
# ...                                                 ...
# 1318                   https://arxiv.org/pdf/2308.12950
# 1321  https://ifc.dpz.es/recursos/publicaciones/24/8...
# 1325  https://www.redalyc.org/pdf/3718/371838943002.pdf
# 1326  https://rodin.uca.es/bitstream/handle/10498/26...
# 1328                   https://arxiv.org/pdf/2304.06975
#
#                                               author_id             query  \
# 3                                                  [, ]  Ridge Regression
# 4                                        [qglWXEQAAAAJ]  Ridge Regression
# 5                                      [8CzBuBYAAAAJ, ]  Ridge Regression
# 6            [OEd0rvkAAAAJ, uoWoR4gAAAAJ, GJE29ekAAAAJ]  Ridge Regression
# 7                                                  [, ]  Ridge Regression
# ...                                                 ...               ...
# 1318  [6vht2iwAAAAJ, jOwTwm4AAAAJ, , UAx_woYAAAAJ, T...             LLaMA
# 1321                                     [frwKQH4AAAAJ]             LLaMA
# 1325                                               [, ]             LLaMA
# 1326                                                 []             LLaMA
# 1328  [olOglGgAAAAJ, abmQYmYAAAAJ, 6jFEal4AAAAJ, , Z...             LLaMA
#
#                                      file_name  \
# 3     520946c9-4f85-4fd1-bfe5-2305c315cb1b.pdf
# 4     7f813b9f-7b00-4610-b3fe-30b85ad26b51.pdf
# 5     5ed3ef6d-6030-47a6-9ddf-363a2f09571c.pdf
# 6     0acd09a1-4322-48eb-907d-b48498c2d89c.pdf
# 7     578f8b95-0643-4dcf-8565-00c5d655caa2.pdf
# ...                                        ...
# 1318  094c84c1-c9d6-4302-a100-311f513862da.pdf
# 1321  dff07229-a282-469e-a7ae-63a74bc6f911.pdf
# 1325  e8b85264-2cac-4c48-81f4-6180297047df.pdf
# 1326  123fb0f1-66c6-4aca-be6c-4ac275a094db.pdf
# 1328  06cbe5c2-80d8-4390-b53a-8ab259e30e44.pdf
#
#                                               file_path language
# 3     ../../../detect_ml_model_files/520946c9-4f85-4...       en
# 4     ../../../detect_ml_model_files/7f813b9f-7b00-4...       en
# 5     ../../../detect_ml_model_files/5ed3ef6d-6030-4...       en
# 6     ../../../detect_ml_model_files/0acd09a1-4322-4...       en
# 7     ../../../detect_ml_model_files/578f8b95-0643-4...       en
# ...                                                 ...      ...
# 1318  ../../../detect_ml_model_files/094c84c1-c9d6-4...       en
# 1321  ../../../detect_ml_model_files/dff07229-a282-4...       es
# 1325  ../../../detect_ml_model_files/e8b85264-2cac-4...       es
# 1326  ../../../detect_ml_model_files/123fb0f1-66c6-4...       es
# 1328  ../../../detect_ml_model_files/06cbe5c2-80d8-4...       en
#
# [514 rows x 9 columns]

# %%
check_df = check_df.query('language=="en"').groupby(['query'])['query'].count().reset_index(name='count')

# %%
check_df
# Out:
#                                           query  count
# 0                           Actor-Critic Models      5
# 1                                      AdaBoost      5
# 2                        Advantage Actor-Critic      5
# 3                                       AlexNet      5
# 4                             Apriori Algorithm      5
# ..                                          ...    ...
# 94                          Vision Transformers      5
# 95                                      XGBoost      5
# 96                           k-Means Clustering      5
# 97                          k-Nearest Neighbors      5
# 98  t-Distributed Stochastic Neighbor Embedding      5
#
# [99 rows x 2 columns]

# %%
check_df.query('count != 5')
# Out:
# Empty DataFrame
# Columns: [query, count]
# Index: []

# %% [markdown]
# So all search terms have five files associated with them

# %%
data_df.to_parquet(f'{DATA_FOLDER}detect_ml_models.parquet')
